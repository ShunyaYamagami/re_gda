# %%
# %reset -f
# !rm -fr __pycache__
# !rm -fr */__pycache__

# %%
from z_common import *

# ファイル特有変数
CUDA_DIR = 0
N_CUDA = 1

# %%
# %%time
# PARENT = 'Digit'
# DATA_DOMAIN_LIST = [
  # 'svhn_mnist',
  # 'svhn_synth',
  # 'svhn_synth_mnist',
  # 'svhn_synth_mnist_mnistm',
# ]
PARENT = 'Office31'
DATA_DOMAIN_LIST = [
  # 'amazon_dslr_webcam',
  'dslr_webcam',
  # 'amazon_dslr',
  # 'webcam_amazon',
]

spread_message = LOG_TEXT + "__new_test"
NUM_LAPS = 2
log_dir_opt = ''
# log_dir_opt += '__new_test'
log_dir_opt += '__new_test'

counter=0
for DATA_DOMAIN in DATA_DOMAIN_LIST:
  config, CONFIG_FILE, log_dir = config_to_execute(DATA_DOMAIN, PARENT, CUDA_DIR, log_dir_opt)
  # log_dir += f'__{counter}'
  # counter += 1

  # !rm -fr */__pycache__
  # !CUDA_VISIBLE_DEVICES=$N_CUDA python3 -B main.py --config=$CONFIG_FILE  --log_dir=$log_dir  --spread_message=$spread_message  --cuda_dir=$CUDA_DIR
# Out:
# Running on: cuda
#
# ...
#     ============== dslr_webcam ==============
# ...
#     ---------------------------------------------------------
#         cuda_dir: 0
#         batch_size: 256,	 epochs: 300,	 model: encoder,
#         log_dir: record/Office31/CUDA0/dw__new_test
#         spread_message: __new_test
#     ---------------------------------------------------------
#
#   [dslr] 398
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  52 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=4)]: Done 352 tasks      | elapsed:    8.7s
# [Parallel(n_jobs=4)]: Done 391 out of 398 | elapsed:    9.6s remaining:    0.2s
# [Parallel(n_jobs=4)]: Done 398 out of 398 | elapsed:    9.7s finished
#   [dslr] 100
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  76 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=4)]: Done 100 out of 100 | elapsed:    2.2s finished
#   [webcam] 636
# ...

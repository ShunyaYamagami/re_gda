# %%
# %reset -f
# !rm -fr __pycache__
# !rm -fr */__pycache__

# %% [markdown]
# # Domain Estimation

# %%
from z_common import *

# ファイル特有変数
CUDA_DIR = 3
N_CUDA = 2
spread_message = LOG_TEXT

# %%
# %%time
# PARENT = 'Digit'
# DATA_DOMAIN_LIST = [
#   'svhn_mnist',
#   'svhn_synth',
#   'svhn_synth_mnist',
#   'svhn_synth_mnist_mnistm',
# ]
PARENT = 'Office31'
DATA_DOMAIN_LIST = [
  # 'amazon_dslr_webcam',
  # 'dslr_webcam',
  # 'amazon_dslr',
  'webcam_amazon',
  'webcam_amazon',
  'webcam_amazon',
]


LAP = 1
NUM_LAPS = 2
log_dir_opt = ''
# log_dir_opt += '__record'
# log_dir_opt += '__douse'


for DATA_DOMAIN in DATA_DOMAIN_LIST:
  config, CONFIG_FILE, log_dir = config_to_execute(DATA_DOMAIN, PARENT, CUDA_DIR, log_dir_opt)

  # !rm -fr */__pycache__
  # !CUDA_VISIBLE_DEVICES=$N_CUDA python3 -B run.py --config=$CONFIG_FILE  --log_dir=$log_dir  --num_laps=$NUM_LAPS  --spread_message=$spread_message  --cuda_dir=$CUDA_DIR
# Out:
# ===============================================
# ==============  webcam_amazon  ==============
# ===============================================
# Please install apex for mixed precision training from: https://github.com/NVIDIA/apex
#     ---------------------------------------------------------
#         batch_size: 256,  epochs: 100
#         SSL: simclr,  base_model: encoder
#         jigsaw: True,  fourier: True,  grid: 3
#         num_laps: 2
#     ---------------------------------------------------------
#
#
# =================  1/2周目  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  68 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    4.9s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 216 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=4)]: Done 2616 tasks      | elapsed:    6.9s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    7.6s finished
# Running on: cuda
# Epoch:0/100(0) loss:5.395840644836426
# Epoch:3/100(50) loss:4.9388203620910645
# Epoch:7/100(100) loss:4.914524078369141
# Epoch:10/100(150) loss:4.844066619873047
# Epoch:14/100(200) loss:4.852801322937012
# Epoch:17/100(250) loss:4.796119689941406
# Epoch:21/100(300) loss:4.814425945281982
# Epoch:25/100(350) loss:4.788549423217773
# Epoch:28/100(400) loss:4.794632434844971
# Epoch:32/100(450) loss:4.828190326690674
# Epoch:35/100(500) loss:4.783171653747559
# Epoch:39/100(550) loss:4.774781227111816
# Epoch:42/100(600) loss:4.7621026039123535
# Epoch:46/100(650) loss:4.816781997680664
# Epoch:50/100(700) loss:4.770751953125
# Epoch:53/100(750) loss:4.734493255615234
# Epoch:57/100(800) loss:4.7879414558410645
# Epoch:60/100(850) loss:4.720378398895264
# Epoch:64/100(900) loss:4.75703239440918
# Epoch:67/100(950) loss:4.757938861846924
# Epoch:71/100(1000) loss:4.724372863769531
# Epoch:75/100(1050) loss:4.723596572875977
# Epoch:78/100(1100) loss:4.727919101715088
# Epoch:82/100(1150) loss:4.778357028961182
# Epoch:85/100(1200) loss:4.754328727722168
# Epoch:89/100(1250) loss:4.7161736488342285
# Epoch:92/100(1300) loss:4.692383766174316
# Epoch:96/100(1350) loss:4.706205368041992
# =================  Clustering 1/2  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  44 tasks      | elapsed:    3.9s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    7.9s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    8.7s finished
#   -----  Load Model from record/Office31/CUDA3/wa_encoder for clustering  -----
#   -----  Load NMI File from record/Office31/CUDA3/wa_encoder  -----
# nmi:0.2670946332286156
# nmi class:0.19113516785396384
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 168 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    4.9s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    8.4s finished
#   -----  Load Model from record/Office31/CUDA3/wa_encoder for clustering  -----
#   -----  Load NMI File from record/Office31/CUDA3/wa_encoder  -----
# nmi:0.25226192826329624
# nmi class:0.1947515082370084
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 168 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    4.7s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=4)]: Done 2680 tasks      | elapsed:    8.1s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    8.5s finished
#   -----  Load Model from record/Office31/CUDA3/wa_encoder for clustering  -----
#   -----  Load NMI File from record/Office31/CUDA3/wa_encoder  -----
# nmi:0.2565798517664267
# nmi class:0.19195798997035401
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 176 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    4.8s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 184 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=4)]: Done 2584 tasks      | elapsed:    7.5s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    8.1s finished
#   -----  Load Model from record/Office31/CUDA3/wa_encoder for clustering  -----
#   -----  Load NMI File from record/Office31/CUDA3/wa_encoder  -----
# nmi:0.2419605999489229
# nmi class:0.19064425267516172
# ===============================================
# ==============  webcam_amazon  ==============
# ===============================================
# Please install apex for mixed precision training from: https://github.com/NVIDIA/apex
#     ---------------------------------------------------------
#         batch_size: 256,  epochs: 100
#         SSL: simclr,  base_model: encoder
#         jigsaw: True,  fourier: True,  grid: 3
#         num_laps: 2
#     ---------------------------------------------------------
#
#
# =================  1/2周目  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  48 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    6.4s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=4)]: Done 2680 tasks      | elapsed:    6.9s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    7.4s finished
# Running on: cuda
# Epoch:0/100(0) loss:5.455454349517822
# Epoch:3/100(50) loss:4.918806552886963
# Epoch:7/100(100) loss:4.941572189331055
# Epoch:10/100(150) loss:4.85859489440918
# Epoch:14/100(200) loss:4.8455986976623535
# Epoch:17/100(250) loss:4.826347351074219
# Epoch:21/100(300) loss:4.808032035827637
# Epoch:25/100(350) loss:4.794355869293213

# %%
# from clustering import run_clustering
# from dataset import get_datasets
# from simclr import SimCLR
# from log_functions import *
# config.config_path = CONFIG_FILE
# config.log_dir = log_dir
# config.num_laps = 2
# config.spread_message = ""
# config.cuda_dir = CUDA_DIR
# config.lap = 1

# run_clustering(config)

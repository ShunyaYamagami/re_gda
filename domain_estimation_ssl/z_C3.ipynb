# %%
# %reset -f
# !rm -fr __pycache__
# !rm -fr */__pycache__

# %%
from z_common import *

# ファイル特有変数
CUDA_DIR = 3
N_CUDA = 2

# %%
# %%time
# PARENT = 'Digit'
# DATA_DOMAIN_LIST = [
  # 'svhn_mnist',
  # 'svhn_synth',
  # 'svhn_synth_mnist',
  # 'svhn_synth_mnist_mnistm',
# ]
PARENT = 'Office31'
DATA_DOMAIN_LIST = [
  # 'amazon_dslr_webcam',
  'dslr_webcam',
  'amazon_dslr',
  'webcam_amazon',
]

spread_message = LOG_TEXT + "__augs"
NUM_LAPS = 3
log_dir_opt = ''
log_dir_opt += f'__augs'

counter=0
for exec_num in range(3):
  for DATA_DOMAIN in DATA_DOMAIN_LIST:
    config, CONFIG_FILE, log_dir = config_to_execute(DATA_DOMAIN, PARENT, CUDA_DIR, log_dir_opt)
    log_dir += f'__1_{exec_num}'

    # !rm -fr */__pycache__
    # !CUDA_VISIBLE_DEVICES=$N_CUDA python3 -B run.py --config=$CONFIG_FILE  --log_dir=$log_dir  --num_laps=$NUM_LAPS  --spread_message=$spread_message  --cuda_dir=$CUDA_DIR
# Out:
# Please install apex for mixed precision training from: https://github.com/NVIDIA/apex
# Running on: cuda
#
# ...
#     ==============  dslr_webcam  ==============
# ...
#     ---------------------------------------------------------
#         cuda_dir: 3
#         train    batch_size: 256,  epochs: 100
#         model    SSL: simclr,  base_model: encoder,  out_dim: 64,
#         dataset  grid: 3,  sampling_num: -1
#         other    num_laps: 3,  test_counter: 0
#         log_dir: record/Office31/CUDA3/dw__augs__1_0
#         spread_message: __augs
#     ---------------------------------------------------------
#
#
# =================  Training 1/3周目  =================
#   read dslr 498
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    4.2s
# [Parallel(n_jobs=4)]: Done 252 tasks      | elapsed:   11.3s
# [Parallel(n_jobs=4)]: Done 491 out of 498 | elapsed:   20.4s remaining:    0.3s
# ...

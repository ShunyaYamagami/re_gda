# %%
# %reset -f
# !rm -fr __pycache__
# !rm -fr */__pycache__

# %% [markdown]
# # Domain Estimation

# %%
from z_common import *

# ファイル特有変数
CUDA_DIR = 3
N_CUDA = 2
spread_message = LOG_TEXT

# %%
# PARENT = 'Digit'
# DATA_DOMAIN_LIST = [
#   'svhn_mnist',
#   'svhn_synth',
#   'svhn_synth_mnist',
#   'svhn_synth_mnist_mnistm',
# ]
PARENT = 'Office31'
DATA_DOMAIN_LIST = [
  # 'amazon_dslr_webcam',
  # 'dslr_webcam',
  # 'amazon_dslr',
  'webcam_amazon',
  'webcam_amazon',
  'webcam_amazon',
]


LAP = 1
NUM_LAPS = 2
log_dir_opt = ''
# log_dir_opt += '__record'
# log_dir_opt += '__douse'


for DATA_DOMAIN in DATA_DOMAIN_LIST:
  config, CONFIG_FILE, log_dir = config_to_execute(DATA_DOMAIN, PARENT, CUDA_DIR, log_dir_opt)

  # !rm -fr */__pycache__
  # !CUDA_VISIBLE_DEVICES=$N_CUDA python3 -B run.py --config=$CONFIG_FILE  --log_dir=$log_dir  --num_laps=$NUM_LAPS  --spread_message=$spread_message  --cuda_dir=$CUDA_DIR
# Out:
# ===============================================
# ==============  webcam_amazon  ==============
# ===============================================
# Please install apex for mixed precision training from: https://github.com/NVIDIA/apex
#     ---------------------------------------------------------
#         cuda_dir: 3
#         batch_size: 256,  epochs: 100
#         SSL: simclr,  base_model: encoder
#         jigsaw: True,  fourier: True,  grid: 3
#         num_laps: 2,
#     ---------------------------------------------------------
#
#
# =================  1/2周目  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  68 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    5.4s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=4)]: Done 2680 tasks      | elapsed:    6.5s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    6.7s finished
# Running on: cuda
# Epoch:0/100(0) loss:5.367345333099365
# Epoch:3/100(50) loss:4.888370513916016
# Epoch:7/100(100) loss:4.817718982696533
# Epoch:10/100(150) loss:4.776613712310791
# Epoch:14/100(200) loss:4.760190486907959
# Epoch:17/100(250) loss:4.768660068511963
# Epoch:21/100(300) loss:4.774611949920654
# Epoch:25/100(350) loss:4.738287448883057
# Epoch:28/100(400) loss:4.737488269805908
# Epoch:32/100(450) loss:4.797824382781982
# Epoch:35/100(500) loss:4.73587703704834
# Epoch:39/100(550) loss:4.710094451904297
# Epoch:42/100(600) loss:4.7315473556518555
# Epoch:46/100(650) loss:4.721107482910156
# Epoch:50/100(700) loss:4.736023426055908
# Epoch:53/100(750) loss:4.72336483001709
# Epoch:57/100(800) loss:4.731750965118408
# Epoch:60/100(850) loss:4.688852310180664
# Epoch:64/100(900) loss:4.711512565612793
# Epoch:67/100(950) loss:4.7062883377075195
# Epoch:71/100(1000) loss:4.691491603851318
# Epoch:75/100(1050) loss:4.710827350616455
# Epoch:78/100(1100) loss:4.703512668609619
# Epoch:82/100(1150) loss:4.769965648651123
# Epoch:85/100(1200) loss:4.703211784362793
# Epoch:89/100(1250) loss:4.694779396057129
# Epoch:92/100(1300) loss:4.655842304229736
# Epoch:96/100(1350) loss:4.6944684982299805
# =================  Clustering 1/2  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  68 tasks      | elapsed:    2.9s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    5.8s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=4)]: Done 2680 tasks      | elapsed:    7.3s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    7.7s finished
#   -----  Load Model from record/Office31/CUDA3/wa_encoder for clustering  -----
# nmi:0.18356537154022204
# nmi class:0.23603227435883845
# domain_accuracy:0.679125138427464
# class_accuracy:0.026854928017718716
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 168 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    4.2s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=4)]: Done 2680 tasks      | elapsed:    7.3s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    7.7s finished
#   -----  Load Model from record/Office31/CUDA3/wa_encoder for clustering  -----
# nmi:0.18356537154022204
# nmi class:0.23284504627528643
# domain_accuracy:0.679125138427464
# class_accuracy:0.05675526024363234
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    3.5s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    6.7s finished
#   -----  Load Model from record/Office31/CUDA3/wa_encoder for clustering  -----
# nmi:0.18399640748876067
# nmi class:0.23147318443161954
# domain_accuracy:0.32032115171650055
# class_accuracy:0.024363233665559248
# ===============================================
# ==============  webcam_amazon  ==============
# ===============================================
# Please install apex for mixed precision training from: https://github.com/NVIDIA/apex
#     ---------------------------------------------------------
#         cuda_dir: 3
#         batch_size: 256,  epochs: 100
#         SSL: simclr,  base_model: encoder
#         jigsaw: True,  fourier: True,  grid: 3
#         num_laps: 2,
#     ---------------------------------------------------------
#
#
# =================  1/2周目  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  56 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    5.2s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    7.7s finished
# Running on: cuda
# Epoch:0/100(0) loss:5.367345333099365
# Epoch:3/100(50) loss:4.885722637176514
# Epoch:7/100(100) loss:4.819008827209473
# Epoch:10/100(150) loss:4.779736518859863
# Epoch:14/100(200) loss:4.756978988647461
# Epoch:17/100(250) loss:4.767250061035156
# Epoch:21/100(300) loss:4.77300500869751
# Epoch:25/100(350) loss:4.736140727996826
# Epoch:28/100(400) loss:4.736916542053223
# Epoch:32/100(450) loss:4.805383205413818
# Epoch:35/100(500) loss:4.736482620239258
# Epoch:39/100(550) loss:4.711958885192871
# Epoch:42/100(600) loss:4.731637477874756
# Epoch:46/100(650) loss:4.720016956329346
# Epoch:50/100(700) loss:4.736819267272949
# Epoch:53/100(750) loss:4.719900131225586
# Epoch:57/100(800) loss:4.735468864440918
# Epoch:60/100(850) loss:4.684432029724121
# Epoch:64/100(900) loss:4.713667869567871
# Epoch:67/100(950) loss:4.703974723815918
# Epoch:71/100(1000) loss:4.6917805671691895
# Epoch:75/100(1050) loss:4.711019039154053
# Epoch:78/100(1100) loss:4.706616401672363
# Epoch:82/100(1150) loss:4.772982597351074
# Epoch:85/100(1200) loss:4.703615665435791
# Epoch:89/100(1250) loss:4.692107677459717
# Epoch:92/100(1300) loss:4.652942657470703
# Epoch:96/100(1350) loss:4.694820880889893
# =================  Clustering 1/2  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  68 tasks      | elapsed:    3.2s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    6.2s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=4)]: Done 2680 tasks      | elapsed:    7.1s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    7.5s finished
#   -----  Load Model from record/Office31/CUDA3/wa_encoder for clustering  -----
# nmi:0.19817084032965554
# nmi class:0.2268561634071584
# domain_accuracy:0.32059800664451826
# class_accuracy:0.03737541528239203
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    3.9s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=4)]: Done 2680 tasks      | elapsed:    7.0s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    7.4s finished
#   -----  Load Model from record/Office31/CUDA3/wa_encoder for clustering  -----
# nmi:0.19817084032965554
# nmi class:0.23631887764872206
# domain_accuracy:0.32059800664451826
# class_accuracy:0.03599114064230343
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    3.7s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=4)]: Done 2680 tasks      | elapsed:    6.9s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    7.1s finished
#   -----  Load Model from record/Office31/CUDA3/wa_encoder for clustering  -----
# nmi:0.19817084032965554
# nmi class:0.23346418491253837
# domain_accuracy:0.32059800664451826
# class_accuracy:0.023255813953488372
# ===============================================
# ==============  webcam_amazon  ==============
# ===============================================
# Please install apex for mixed precision training from: https://github.com/NVIDIA/apex
#     ---------------------------------------------------------
#         cuda_dir: 3
#         batch_size: 256,  epochs: 100
#         SSL: simclr,  base_model: encoder
#         jigsaw: True,  fourier: True,  grid: 3
#         num_laps: 2,
#     ---------------------------------------------------------
#
#
# =================  1/2周目  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  88 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    4.2s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    6.6s finished
# Running on: cuda
# Epoch:0/100(0) loss:5.367345333099365
# Epoch:3/100(50) loss:4.889045715332031
# Epoch:7/100(100) loss:4.8164191246032715
# Epoch:10/100(150) loss:4.7775726318359375
# Epoch:14/100(200) loss:4.7621917724609375
# Epoch:17/100(250) loss:4.765780925750732
# Epoch:21/100(300) loss:4.774807453155518
# Epoch:25/100(350) loss:4.7376933097839355
# Epoch:28/100(400) loss:4.739435195922852
# Epoch:32/100(450) loss:4.798256874084473
# Epoch:35/100(500) loss:4.738646984100342
# Epoch:39/100(550) loss:4.709648609161377
# Epoch:42/100(600) loss:4.7351789474487305
# Epoch:46/100(650) loss:4.716791152954102
# Epoch:50/100(700) loss:4.737218856811523
# Epoch:53/100(750) loss:4.723891735076904
# Epoch:57/100(800) loss:4.734302520751953
# Epoch:60/100(850) loss:4.689681053161621
# Epoch:64/100(900) loss:4.716505527496338
# Epoch:67/100(950) loss:4.70631217956543
# Epoch:71/100(1000) loss:4.690756797790527
# Epoch:75/100(1050) loss:4.7087483406066895
# Epoch:78/100(1100) loss:4.707701683044434
# Epoch:82/100(1150) loss:4.762228965759277
# Epoch:85/100(1200) loss:4.7022013664245605
# Epoch:89/100(1250) loss:4.691372871398926
# Epoch:92/100(1300) loss:4.650091648101807
# Epoch:96/100(1350) loss:4.692039966583252
# =================  Clustering 1/2  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  62 tasks      | elapsed:    2.9s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    6.4s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    7.8s finished
#   -----  Load Model from record/Office31/CUDA3/wa_encoder for clustering  -----
# nmi:0.2029555616629776
# nmi class:0.22897252086664377
# domain_accuracy:0.31589147286821706
# class_accuracy:0.036544850498338874
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 200 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    4.0s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    7.8s finished
#   -----  Load Model from record/Office31/CUDA3/wa_encoder for clustering  -----
# nmi:0.2029555616629776
# nmi class:0.24243374847827814
# domain_accuracy:0.6841085271317829
# class_accuracy:0.023255813953488372
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    3.8s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=4)]: Done 2680 tasks      | elapsed:    7.7s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    8.1s finished
#   -----  Load Model from record/Office31/CUDA3/wa_encoder for clustering  -----
# nmi:0.2029555616629776
# nmi class:0.23184633335434066
# domain_accuracy:0.31589147286821706
# class_accuracy:0.03211517165005537

# %% [markdown]
# jigsawのみ

# %%
# from clustering import run_clustering
# from dataset import get_datasets
# from simclr import SimCLR
# from log_functions import *
# config.config_path = CONFIG_FILE
# config.log_dir = log_dir
# config.num_laps = 2

# config.lap = 1
# run_clustering(config)
# run_clustering(config)
# run_clustering(config)
# run_clustering(config)
# run_clustering(config)

# config.lap = 2
# # config.edls = pd.read_csv(os.path.join(config.log_dir, 'cluster_pca_gmm.csv'), names=['domain_label'], dtype=int).domain_label.values
# # config.log_dir__old = config.log_dir  # simclrのdoes_load_modelだけのために設けた．
# # config.log_dir += f'__{config.lap}'

# # dataset = get_datasets(config, 'train')
# # simclr = SimCLR(dataset, config)
# # simclr.train(does_load_model=True)

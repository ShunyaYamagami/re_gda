# %%
# %reset -f
# !rm -fr __pycache__
# !rm -fr */__pycache__

# %% [markdown]
# # Domain Estimation

# %%
from z_common import *

# ファイル特有変数
CUDA_DIR = 3
N_CUDA = 2
spread_message = LOG_TEXT

# %%
# %%time
# PARENT = 'Digit'
# DATA_DOMAIN_LIST = [
#   'svhn_mnist',
#   'svhn_synth',
#   'svhn_synth_mnist',
#   'svhn_synth_mnist_mnistm',
# ]
PARENT = 'Office31'
DATA_DOMAIN_LIST = [
  # 'amazon_dslr_webcam',
  'dslr_webcam',
  # 'amazon_dslr',
  # 'webcam_amazon',
]


LAP = 1
NUM_LAPS = 3
log_dir_opt = ''
# log_dir_opt += '__record'


for DATA_DOMAIN in DATA_DOMAIN_LIST:
  config, CONFIG_FILE, log_dir = config_to_execute(DATA_DOMAIN, PARENT, CUDA_DIR, log_dir_opt)

  # !rm -fr */__pycache__
  # !CUDA_VISIBLE_DEVICES=$N_CUDA python3 -B run.py --config=$CONFIG_FILE  --log_dir=$log_dir  --num_laps=$NUM_LAPS  --spread_message=$spread_message
# Out:
# ===============================================
# ==============  dslr_webcam  ==============
# ===============================================
# Please install apex for mixed precision training from: https://github.com/NVIDIA/apex
#     ---------------------------------------------------------
#         batch_size: 256,  epochs: 100
#         SSL: simclr,  base_model: encoder
#         jigsaw: True,  fourier: False,  grid: 3
#         num_laps: 3
#     ---------------------------------------------------------
#
# =================  2/3周目  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  68 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=4)]: Done 498 out of 498 | elapsed:    5.9s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    2.7s finished
# Running on: cuda
#   ----- Loaded pre-trained model from record/Office31/CUDA3/dw_encoder for SSL  -----
# Epoch:0/100(0) loss:4.66499137878418
# Epoch:10/100(50) loss:4.6300435066223145
# Epoch:20/100(100) loss:4.628852367401123
# Epoch:30/100(150) loss:4.624342441558838
# Epoch:40/100(200) loss:4.61300802230835
# Epoch:50/100(250) loss:4.6326823234558105
# Epoch:60/100(300) loss:4.605280876159668
# Epoch:70/100(350) loss:4.5921783447265625
# Epoch:80/100(400) loss:4.572651386260986
# Epoch:90/100(450) loss:4.603309631347656
# =================  Clustering 2/3  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 200 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=4)]: Done 498 out of 498 | elapsed:    3.8s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 216 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    2.5s finished
#   -----  Load Model from record/Office31/CUDA3/dw_encoder__2 for clustering  -----
#   -----  Load NMI File from record/Office31/CUDA3/dw_encoder__2  -----
# nmi:0.5417455121314851
# nmi class:0.40001463441489776
# =================  3/3周目  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 120 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=4)]: Done 498 out of 498 | elapsed:    6.5s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    2.9s finished
# Running on: cuda
#   ----- Loaded pre-trained model from record/Office31/CUDA3/dw_encoder__2 for SSL  -----
# Epoch:0/100(0) loss:4.651364326477051
# Epoch:10/100(50) loss:4.564364910125732
# Epoch:20/100(100) loss:4.5941643714904785
# Epoch:30/100(150) loss:4.557788848876953
# Epoch:40/100(200) loss:4.563116073608398
# Epoch:50/100(250) loss:4.560647487640381
# Epoch:60/100(300) loss:4.517648696899414
# Epoch:70/100(350) loss:4.557269096374512
# Epoch:80/100(400) loss:4.535992622375488
# Epoch:90/100(450) loss:4.521492004394531
# =================  Clustering 3/3  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 128 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=4)]: Done 498 out of 498 | elapsed:    3.9s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    2.2s finished
#   -----  Load Model from record/Office31/CUDA3/dw_encoder__2__3 for clustering  -----
#   -----  Load NMI File from record/Office31/CUDA3/dw_encoder__2__3  -----
# nmi:0.5334394510158377
# nmi class:0.3950226556113783
# CPU times: user 1.89 s, sys: 255 ms, total: 2.15 s
# Wall time: 6min 12s

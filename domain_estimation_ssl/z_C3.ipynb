# %%
# %reset -f
# !rm -fr __pycache__
# !rm -fr */__pycache__

# %% [markdown]
# # Domain Estimation

# %%
from z_common import *

# ファイル特有変数
CUDA_DIR = 2
N_CUDA = 2
spread_message = LOG_TEXT

# %%
# %%time
# PARENT = 'Digit'
# DATA_DOMAIN_LIST = [
#   'svhn_mnist',
#   'svhn_synth',
#   'svhn_synth_mnist',
#   'svhn_synth_mnist_mnistm',
# ]
PARENT = 'Office31'
DATA_DOMAIN_LIST = [
  # 'amazon_dslr_webcam',
  'dslr_webcam',
  'amazon_dslr',
  'webcam_amazon',
]


LAP = 1
NUM_LAPS = 1
log_dir_opt = ''
# log_dir_opt += '__record'


for DATA_DOMAIN in DATA_DOMAIN_LIST:
  config, CONFIG_FILE, log_dir = config_to_execute(DATA_DOMAIN, PARENT, CUDA_DIR, log_dir_opt)

  # !rm -fr */__pycache__
  # !CUDA_VISIBLE_DEVICES=$N_CUDA python3 -B run.py --config=$CONFIG_FILE  --log_dir=$log_dir  --num_laps=$NUM_LAPS  --spread_message=$spread_message
# Out:
# ===============================================
# ==============  dslr_webcam  ==============
# ===============================================
# Please install apex for mixed precision training from: https://github.com/NVIDIA/apex
#       ---------------------------------------------------------
#                 batch_size: 256,  epochs: 150
#                 SSL: simclr,  base_model: encoder
#                 jigsaw: True,  fourier: False,  grid: 3
#                 num_laps: 1
#         ---------------------------------------------------------
#
# =================  1/1周目  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  88 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=4)]: Done 498 out of 498 | elapsed:    4.0s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    1.9s finished
# Running on: cuda
# Epoch:0/150(0) loss:5.353387832641602
# Epoch:10/150(50) loss:4.897282123565674
# Epoch:20/150(100) loss:4.836430072784424
# Epoch:30/150(150) loss:4.826368808746338
# Epoch:40/150(200) loss:4.765522480010986
# Epoch:50/150(250) loss:4.7792863845825195
# Epoch:60/150(300) loss:4.763559341430664
# Epoch:70/150(350) loss:4.750976085662842
# Epoch:80/150(400) loss:4.748203754425049
# Epoch:90/150(450) loss:4.745126247406006
# Epoch:100/150(500) loss:4.728851318359375
# Epoch:110/150(550) loss:4.690087795257568
# Epoch:120/150(600) loss:4.6925153732299805
# Epoch:130/150(650) loss:4.764217853546143
# Epoch:140/150(700) loss:4.743034839630127
# =================  Clustering 1/1  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 200 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=4)]: Done 498 out of 498 | elapsed:    3.0s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    2.1s finished
#   -----  Load Model from record/Office31/CUDA2/dw_encoder for clustering  -----
#   -----  Load NMI File from record/Office31/CUDA2/dw_encoder  -----
# nmi:0.6496992083699336
# nmi class:0.3781898579019778
# ===============================================
# ==============  amazon_dslr  ==============
# ===============================================
# Please install apex for mixed precision training from: https://github.com/NVIDIA/apex
#       ---------------------------------------------------------
#                 batch_size: 256,  epochs: 150
#                 SSL: simclr,  base_model: encoder
#                 jigsaw: True,  fourier: False,  grid: 3
#                 num_laps: 1
#         ---------------------------------------------------------
#
# =================  1/1周目  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  88 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=4)]: Done 2810 out of 2817 | elapsed:    6.1s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    6.2s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 200 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=4)]: Done 498 out of 498 | elapsed:    2.9s finished
# Running on: cuda
# Epoch:0/150(0) loss:5.460473537445068
# Epoch:4/150(50) loss:4.92885160446167
# Epoch:8/150(100) loss:4.8813371658325195
# Epoch:12/150(150) loss:4.828617572784424
# Epoch:16/150(200) loss:4.8176727294921875
# Epoch:20/150(250) loss:4.805953025817871
# Epoch:25/150(300) loss:4.840078830718994
# Epoch:29/150(350) loss:4.773025989532471
# Epoch:33/150(400) loss:4.78611421585083
# Epoch:37/150(450) loss:4.781526565551758
# Epoch:41/150(500) loss:4.771510601043701
# Epoch:45/150(550) loss:4.786863803863525
# Epoch:50/150(600) loss:4.724342346191406
# Epoch:54/150(650) loss:4.735366344451904
# Epoch:58/150(700) loss:4.7360615730285645
# Epoch:62/150(750) loss:4.752829074859619
# Epoch:66/150(800) loss:4.76013708114624
# Epoch:70/150(850) loss:4.744215488433838
# Epoch:75/150(900) loss:4.737183570861816
# Epoch:79/150(950) loss:4.750445365905762
# Epoch:83/150(1000) loss:4.781380653381348
# Epoch:87/150(1050) loss:4.7416090965271
# Epoch:91/150(1100) loss:4.759096622467041
# Epoch:95/150(1150) loss:4.726992607116699
# Epoch:100/150(1200) loss:4.707968235015869
# Epoch:104/150(1250) loss:4.7067179679870605
# Epoch:108/150(1300) loss:4.71328067779541
# Epoch:112/150(1350) loss:4.702630996704102
# Epoch:116/150(1400) loss:4.7125372886657715
# Epoch:120/150(1450) loss:4.738770484924316
# Epoch:125/150(1500) loss:4.703640460968018
# Epoch:129/150(1550) loss:4.689030170440674
# Epoch:133/150(1600) loss:4.721829414367676
# Epoch:137/150(1650) loss:4.734909534454346
# Epoch:141/150(1700) loss:4.7104973793029785
# Epoch:145/150(1750) loss:4.753623962402344
# =================  Clustering 1/1  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    5.8s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 200 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=4)]: Done 498 out of 498 | elapsed:    2.8s finished
#   -----  Load Model from record/Office31/CUDA2/ad_encoder for clustering  -----
#   -----  Load NMI File from record/Office31/CUDA2/ad_encoder  -----
# nmi:0.8603417663800578
# nmi class:0.18801334712455695
# send_email
# ===============================================
# ==============  webcam_amazon  ==============
# ===============================================
# Please install apex for mixed precision training from: https://github.com/NVIDIA/apex
#       ---------------------------------------------------------
#                 batch_size: 256,  epochs: 150
#                 SSL: simclr,  base_model: encoder
#                 jigsaw: True,  fourier: True,  grid: 3
#                 num_laps: 1
#         ---------------------------------------------------------
#
# =================  1/1周目  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  52 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=4)]: Done 352 tasks      | elapsed:    8.5s
# [Parallel(n_jobs=4)]: Done 788 out of 795 | elapsed:   17.6s remaining:    0.2s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:   17.7s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  76 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=4)]: Done 376 tasks      | elapsed:    7.7s
# [Parallel(n_jobs=4)]: Done 876 tasks      | elapsed:   18.0s

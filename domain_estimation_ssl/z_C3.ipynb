# %%
# %reset -f
# !rm -fr __pycache__
# !rm -fr */__pycache__

# %%
from z_common import *

# ファイル特有変数
CUDA_DIR = 3
N_CUDA = 2
spread_message = LOG_TEXT

# %%
# %%time
PARENT = 'Digit'
DATA_DOMAIN_LIST = [
  # 'svhn_mnist',
  'svhn_synth',
  'svhn_synth',
  'svhn_synth',
  # 'svhn_synth_mnist',
  # 'svhn_synth_mnist_mnistm',
]
# PARENT = 'Office31'
# DATA_DOMAIN_LIST = [
  # 'amazon_dslr_webcam',
  # 'dslr_webcam',
  # 'amazon_dslr',
  # 'webcam_amazon',
# ]


NUM_LAPS = 2
log_dir_opt = ''
# log_dir_opt += '__record'

counter=0
for DATA_DOMAIN in DATA_DOMAIN_LIST:
  config, CONFIG_FILE, log_dir = config_to_execute(DATA_DOMAIN, PARENT, CUDA_DIR, log_dir_opt)
  log_dir += f'__{counter}'
  counter += 1

  # !rm -fr */__pycache__
  # !CUDA_VISIBLE_DEVICES=$N_CUDA python3 -B run.py --config=$CONFIG_FILE  --log_dir=$log_dir  --num_laps=$NUM_LAPS  --spread_message=$spread_message  --cuda_dir=$CUDA_DIR
# Out:
# ===============================================
# ==============  svhn_synth  ==============
# ===============================================
# Please install apex for mixed precision training from: https://github.com/NVIDIA/apex
#
#     ===============================================
#     =============== svhn_synth ===================
#     ===============================================
#     ---------------------------------------------------------
#         cuda_dir: 3
#         batch_size: 256,  epochs: 50
#         SSL: simclr,  base_model: encoder
#         jigsaw: True,  fourier: False,  grid: 3
#         num_laps: 2, sampling_num: 3000
#         log_dir: record/Digit/CUDA3/svhn_synth_encoder__0
#     ---------------------------------------------------------
#
#
# =================  1/2周目  =================
#   ----- get dataset svhn -----
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  88 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=4)]: Done 3000 out of 3000 | elapsed:    5.3s finished
#   ----- get dataset synth -----
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 128 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=4)]: Done 728 tasks      | elapsed:    9.6s
# [Parallel(n_jobs=4)]: Done 1728 tasks      | elapsed:   23.9s
# [Parallel(n_jobs=4)]: Done 3000 out of 3000 | elapsed:   54.4s finished
# Running on: cuda
# Epoch:0/50(0) loss:6.497880935668945
# Epoch:2/50(50) loss:6.270092010498047
# Epoch:4/50(100) loss:5.947163105010986
# Epoch:6/50(150) loss:5.9867143630981445
# Epoch:8/50(200) loss:5.627287864685059
# Epoch:10/50(250) loss:5.541701316833496
# Epoch:13/50(300) loss:5.531801700592041
# Epoch:15/50(350) loss:5.496505260467529
# Epoch:17/50(400) loss:5.454334735870361
# Epoch:19/50(450) loss:5.343681812286377
# Epoch:21/50(500) loss:5.332745552062988
# Epoch:23/50(550) loss:5.329308032989502
# Epoch:26/50(600) loss:5.297298908233643
# Epoch:28/50(650) loss:5.363211154937744
# Epoch:30/50(700) loss:5.221660137176514
# Epoch:32/50(750) loss:5.309901237487793
# Epoch:34/50(800) loss:5.260922908782959
# Epoch:36/50(850) loss:5.205179691314697
# Epoch:39/50(900) loss:5.122604846954346
# Epoch:41/50(950) loss:5.158334732055664
# Epoch:43/50(1000) loss:5.159985065460205
# Epoch:45/50(1050) loss:5.132894992828369
# Epoch:47/50(1100) loss:5.139840126037598
# =================  Clustering 1/2  =================
#   ----- get dataset svhn -----
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  88 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=4)]: Done 3000 out of 3000 | elapsed:    8.6s finished
#   ----- get dataset synth -----
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 200 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=4)]: Done 1400 tasks      | elapsed:   11.3s
# [Parallel(n_jobs=4)]: Done 3000 out of 3000 | elapsed:   24.0s finished
#   -----  Load Model from record/Digit/CUDA3/svhn_synth_encoder__0/checkpoints/model.pth for clustering  -----
# nmi:0.304216436447552
# nmi class:0.025435323375230304
# domain_accuracy:0.8058333333333333
#   ----- get dataset svhn -----
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=4)]: Done 3000 out of 3000 | elapsed:    5.5s finished
#   ----- get dataset synth -----
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 128 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=4)]: Done 728 tasks      | elapsed:    9.4s
# [Parallel(n_jobs=4)]: Done 1728 tasks      | elapsed:   22.9s
# [Parallel(n_jobs=4)]: Done 3000 out of 3000 | elapsed:   38.6s finished
#   -----  Load Model from record/Digit/CUDA3/svhn_synth_encoder__0/checkpoints/model.pth for clustering  -----
# nmi:0.3082859017717067
# nmi class:0.023424480671590604
# domain_accuracy:0.8068333333333333
#   ----- get dataset svhn -----
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=4)]: Done 2288 tasks      | elapsed:   21.1s
# [Parallel(n_jobs=4)]: Done 2788 tasks      | elapsed:   29.3s
# [Parallel(n_jobs=4)]: Done 3000 out of 3000 | elapsed:   32.8s finished
#   ----- get dataset synth -----
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  76 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=4)]: Done 512 tasks      | elapsed:    8.3s
# [Parallel(n_jobs=4)]: Done 1512 tasks      | elapsed:   21.8s
# [Parallel(n_jobs=4)]: Done 3000 out of 3000 | elapsed:   32.0s finished
#   -----  Load Model from record/Digit/CUDA3/svhn_synth_encoder__0/checkpoints/model.pth for clustering  -----
# nmi:0.33161350093422304
# nmi class:0.02521300170263171
# domain_accuracy:0.8166666666666667
# ===============================================
# ==============  svhn_synth  ==============
# ===============================================
# Please install apex for mixed precision training from: https://github.com/NVIDIA/apex
#
#     ===============================================
#     =============== svhn_synth ===================
#     ===============================================
#     ---------------------------------------------------------
#         cuda_dir: 3
#         batch_size: 256,  epochs: 50
#         SSL: simclr,  base_model: encoder
#         jigsaw: True,  fourier: False,  grid: 3
#         num_laps: 2, sampling_num: 3000
#         log_dir: record/Digit/CUDA3/svhn_synth_encoder__1
#     ---------------------------------------------------------
#
#
# =================  1/2周目  =================
#   ----- get dataset svhn -----
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  80 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=4)]: Done 1032 tasks      | elapsed:    8.2s
# [Parallel(n_jobs=4)]: Done 2983 tasks      | elapsed:   19.6s
# [Parallel(n_jobs=4)]: Done 3000 out of 3000 | elapsed:   19.7s finished
#   ----- get dataset synth -----
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 200 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=4)]: Done 1400 tasks      | elapsed:   10.6s
# [Parallel(n_jobs=4)]: Done 3000 out of 3000 | elapsed:   21.5s finished
# Running on: cuda
# Epoch:0/50(0) loss:6.558482646942139
# Epoch:2/50(50) loss:6.236676216125488
# Epoch:4/50(100) loss:6.048569679260254
# Epoch:6/50(150) loss:6.03011417388916
# Epoch:8/50(200) loss:5.767730712890625
# Epoch:10/50(250) loss:5.758114814758301
# Epoch:13/50(300) loss:5.622668266296387
# Epoch:15/50(350) loss:5.610916614532471
# Epoch:17/50(400) loss:5.458585262298584
# Epoch:19/50(450) loss:5.409801959991455
# Epoch:21/50(500) loss:5.385648250579834
# Epoch:23/50(550) loss:5.408353805541992
# Epoch:26/50(600) loss:5.546280384063721
# Epoch:28/50(650) loss:5.306169509887695
# Epoch:30/50(700) loss:5.330479621887207
# Epoch:32/50(750) loss:5.286470890045166
# Epoch:34/50(800) loss:5.170021057128906
# Epoch:36/50(850) loss:5.212871551513672
# Epoch:39/50(900) loss:5.178093433380127
# Epoch:41/50(950) loss:5.148787021636963
# Epoch:43/50(1000) loss:5.165375709533691
# Epoch:45/50(1050) loss:5.1892924308776855
# Epoch:47/50(1100) loss:5.146824836730957
# =================  Clustering 1/2  =================
#   ----- get dataset svhn -----
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  71 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=4)]: Done 3000 out of 3000 | elapsed:    8.3s finished
#   ----- get dataset synth -----
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=4)]: Done 3000 out of 3000 | elapsed:    6.6s finished
#   -----  Load Model from record/Digit/CUDA3/svhn_synth_encoder__1/checkpoints/model.pth for clustering  -----
# nmi:0.34062360361861865
# nmi class:0.02808505945737489
# domain_accuracy:0.8211666666666667
#   ----- get dataset svhn -----
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=4)]: Done 3000 out of 3000 | elapsed:    5.7s finished
#   ----- get dataset synth -----
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=4)]: Done 2680 tasks      | elapsed:    9.7s
# [Parallel(n_jobs=4)]: Done 3000 out of 3000 | elapsed:   10.7s finished
#   -----  Load Model from record/Digit/CUDA3/svhn_synth_encoder__1/checkpoints/model.pth for clustering  -----
# nmi:0.3171695272299547
# nmi class:0.024411677102977487
# domain_accuracy:0.814
#   ----- get dataset svhn -----
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=4)]: Done 2680 tasks      | elapsed:    8.3s
# [Parallel(n_jobs=4)]: Done 3000 out of 3000 | elapsed:    9.2s finished
#   ----- get dataset synth -----
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=4)]: Done 2680 tasks      | elapsed:    6.3s
# [Parallel(n_jobs=4)]: Done 3000 out of 3000 | elapsed:    7.1s finished
#   -----  Load Model from record/Digit/CUDA3/svhn_synth_encoder__1/checkpoints/model.pth for clustering  -----
# nmi:0.3236851338399348
# nmi class:0.02364750542688979
# domain_accuracy:0.8145
# ===============================================
# ==============  svhn_synth  ==============
# ===============================================
# Please install apex for mixed precision training from: https://github.com/NVIDIA/apex
#
#     ===============================================
#     =============== svhn_synth ===================
#     ===============================================
#     ---------------------------------------------------------
#         cuda_dir: 3
#         batch_size: 256,  epochs: 50
#         SSL: simclr,  base_model: encoder
#         jigsaw: True,  fourier: False,  grid: 3
#         num_laps: 2, sampling_num: 3000
#         log_dir: record/Digit/CUDA3/svhn_synth_encoder__2
#     ---------------------------------------------------------
#
#
# =================  1/2周目  =================
#   ----- get dataset svhn -----
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 102 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=4)]: Done 2440 tasks      | elapsed:    8.1s
# [Parallel(n_jobs=4)]: Done 3000 out of 3000 | elapsed:    9.1s finished
#   ----- get dataset synth -----
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=4)]: Done 3000 out of 3000 | elapsed:    6.7s finished
# Running on: cuda
# Epoch:0/50(0) loss:6.586655139923096
# Epoch:2/50(50) loss:6.185650825500488
# Epoch:4/50(100) loss:5.904252052307129
# Epoch:6/50(150) loss:5.8556694984436035
# Epoch:8/50(200) loss:5.6449761390686035
# Epoch:10/50(250) loss:5.569814205169678
# Epoch:13/50(300) loss:5.5845723152160645
# Epoch:15/50(350) loss:5.497176170349121
# Epoch:17/50(400) loss:5.488814830780029
# Epoch:19/50(450) loss:5.401540279388428
# Epoch:21/50(500) loss:5.597804069519043
# Epoch:23/50(550) loss:5.358273029327393
# Epoch:26/50(600) loss:5.393640518188477
# Epoch:28/50(650) loss:5.322073936462402
# Epoch:30/50(700) loss:5.296717166900635
# Epoch:32/50(750) loss:5.260583400726318
# Epoch:34/50(800) loss:5.194098949432373
# Epoch:36/50(850) loss:5.261859893798828
# Epoch:39/50(900) loss:5.188640594482422
# Epoch:41/50(950) loss:5.120549201965332
# Epoch:43/50(1000) loss:5.144363880157471
# Epoch:45/50(1050) loss:5.177735328674316
# Epoch:47/50(1100) loss:5.121541500091553
# =================  Clustering 1/2  =================
#   ----- get dataset svhn -----
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 102 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=4)]: Done 2440 tasks      | elapsed:    8.0s
# [Parallel(n_jobs=4)]: Done 3000 out of 3000 | elapsed:    9.2s finished
#   ----- get dataset synth -----
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=4)]: Done 3000 out of 3000 | elapsed:    7.0s finished
#   -----  Load Model from record/Digit/CUDA3/svhn_synth_encoder__2/checkpoints/model.pth for clustering  -----
# nmi:0.28354922844864944
# nmi class:0.014909428682033177
# domain_accuracy:0.7966666666666666
#   ----- get dataset svhn -----
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=4)]: Done 2680 tasks      | elapsed:    7.4s
# [Parallel(n_jobs=4)]: Done 3000 out of 3000 | elapsed:    8.1s finished
#   ----- get dataset synth -----
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=4)]: Done 2680 tasks      | elapsed:    5.8s
# [Parallel(n_jobs=4)]: Done 3000 out of 3000 | elapsed:    6.5s finished
#   -----  Load Model from record/Digit/CUDA3/svhn_synth_encoder__2/checkpoints/model.pth for clustering  -----
# nmi:0.2835724252853237
# nmi class:0.016097837445763947
# domain_accuracy:0.794
#   ----- get dataset svhn -----
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=4)]: Done 3000 out of 3000 | elapsed:    5.2s finished
#   ----- get dataset synth -----
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=4)]: Done 3000 out of 3000 | elapsed:    6.2s finished
#   -----  Load Model from record/Digit/CUDA3/svhn_synth_encoder__2/checkpoints/model.pth for clustering  -----
# nmi:0.28258648547472126
# nmi class:0.015879898047107748
# domain_accuracy:0.7916666666666666
# CPU times: user 10.6 s, sys: 1.22 s, total: 11.8 s
# Wall time: 32min 5s

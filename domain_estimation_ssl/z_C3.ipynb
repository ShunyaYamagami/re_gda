# %%
# %reset -f
# !rm -fr __pycache__
# !rm -fr */__pycache__

# %%
from z_common import *

# ファイル特有変数
CUDA_DIR = 3
N_CUDA = 2
spread_message = LOG_TEXT

# %%
# %%time
# PARENT = 'Digit'
# DATA_DOMAIN_LIST = [
#   'svhn_mnist',
#   'svhn_synth',
#   'svhn_synth_mnist',
#   'svhn_synth_mnist_mnistm',
# ]
PARENT = 'Office31'
DATA_DOMAIN_LIST = [
  # 'amazon_dslr_webcam',
  # 'dslr_webcam',
  # 'dslr_webcam',
  # 'dslr_webcam',
  # 'amazon_dslr',
  'amazon_dslr',
  'amazon_dslr',
  'webcam_amazon',
  'webcam_amazon',
  'webcam_amazon',
]


LAP = 1
NUM_LAPS = 2
log_dir_opt = ''
# log_dir_opt += '__record'
# log_dir_opt += '__douse'

counter=0
for DATA_DOMAIN in DATA_DOMAIN_LIST:
  config, CONFIG_FILE, log_dir = config_to_execute(DATA_DOMAIN, PARENT, CUDA_DIR, log_dir_opt)
  log_dir += f'__{counter}'
  counter += 1

  # !rm -fr */__pycache__
  # !CUDA_VISIBLE_DEVICES=$N_CUDA python3 -B run.py --config=$CONFIG_FILE  --log_dir=$log_dir  --num_laps=$NUM_LAPS  --spread_message=$spread_message  --cuda_dir=$CUDA_DIR
# Out:
# ===============================================
# ==============  amazon_dslr  ==============
# ===============================================
# Please install apex for mixed precision training from: https://github.com/NVIDIA/apex
#     ---------------------------------------------------------
#         cuda_dir: 3
#         batch_size: 256,  epochs: 100
#         SSL: simclr,  base_model: encoder
#         jigsaw: True,  fourier: True,  grid: 3
#         num_laps: 2,
#         log_dir: record/Office31/CUDA3/ad_encoder__0
#     ---------------------------------------------------------
#
#
# =================  1/2周目  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  71 tasks      | elapsed:    4.0s
# [Parallel(n_jobs=4)]: Done 2380 tasks      | elapsed:   11.7s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:   13.1s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 128 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=4)]: Done 498 out of 498 | elapsed:    8.8s finished
# Running on: cuda
# Epoch:0/100(0) loss:5.488835334777832
# Epoch:4/100(50) loss:4.902169227600098
# Epoch:8/100(100) loss:4.812788009643555
# Epoch:12/100(150) loss:4.837246894836426
# Epoch:16/100(200) loss:4.817259788513184
# Epoch:20/100(250) loss:4.795149803161621
# Epoch:25/100(300) loss:4.808515548706055
# Epoch:29/100(350) loss:4.799412250518799
# Epoch:33/100(400) loss:4.796893119812012
# Epoch:37/100(450) loss:4.796646595001221
# Epoch:41/100(500) loss:4.760350227355957
# Epoch:45/100(550) loss:4.797336578369141
# Epoch:50/100(600) loss:4.778137683868408
# Epoch:54/100(650) loss:4.763246536254883
# Epoch:58/100(700) loss:4.761958122253418
# Epoch:62/100(750) loss:4.78176736831665
# Epoch:66/100(800) loss:4.772884368896484
# Epoch:70/100(850) loss:4.748858451843262
# Epoch:75/100(900) loss:4.734368324279785
# Epoch:79/100(950) loss:4.729424476623535
# Epoch:83/100(1000) loss:4.737038612365723
# Epoch:87/100(1050) loss:4.694671630859375
# Epoch:91/100(1100) loss:4.7542595863342285
# Epoch:95/100(1150) loss:4.734428405761719
# =================  Clustering 1/2  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  48 tasks      | elapsed:    4.2s
# [Parallel(n_jobs=4)]: Done 2260 tasks      | elapsed:   10.7s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:   12.3s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  76 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=4)]: Done 376 tasks      | elapsed:    7.4s
# [Parallel(n_jobs=4)]: Done 491 out of 498 | elapsed:    9.4s remaining:    0.1s
# [Parallel(n_jobs=4)]: Done 498 out of 498 | elapsed:    9.5s finished
#   -----  Load Model from record/Office31/CUDA3/ad_encoder__0 for clustering  -----
# nmi:0.3223784430984719
# nmi class:0.1812359499561906
# domain_accuracy:0.7822021116138763
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=4)]: Done 2680 tasks      | elapsed:    7.8s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    8.2s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 128 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=4)]: Done 491 out of 498 | elapsed:    8.4s remaining:    0.1s
# [Parallel(n_jobs=4)]: Done 498 out of 498 | elapsed:    8.5s finished
#   -----  Load Model from record/Office31/CUDA3/ad_encoder__0 for clustering  -----
# nmi:0.36888952002094266
# nmi class:0.18526456095793042
# domain_accuracy:0.8193061840120663
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=4)]: Done 2680 tasks      | elapsed:    8.1s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    8.4s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  76 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=4)]: Done 498 out of 498 | elapsed:    9.0s finished
#   -----  Load Model from record/Office31/CUDA3/ad_encoder__0 for clustering  -----
# nmi:0.31966411346527696
# nmi class:0.18605375919761022
# domain_accuracy:0.779788838612368
# ===============================================
# ==============  amazon_dslr  ==============
# ===============================================
# Please install apex for mixed precision training from: https://github.com/NVIDIA/apex
#     ---------------------------------------------------------
#         cuda_dir: 3
#         batch_size: 256,  epochs: 100
#         SSL: simclr,  base_model: encoder
#         jigsaw: True,  fourier: True,  grid: 3
#         num_laps: 2,
#         log_dir: record/Office31/CUDA3/ad_encoder__1
#     ---------------------------------------------------------
#
#
# =================  1/2周目  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  68 tasks      | elapsed:    4.0s
# [Parallel(n_jobs=4)]: Done 2810 out of 2817 | elapsed:   11.9s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:   11.9s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 128 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=4)]: Done 491 out of 498 | elapsed:    8.6s remaining:    0.1s
# [Parallel(n_jobs=4)]: Done 498 out of 498 | elapsed:    8.7s finished
# Running on: cuda
# Epoch:0/100(0) loss:5.482549667358398
# Epoch:4/100(50) loss:4.910977363586426
# Epoch:8/100(100) loss:4.837794303894043
# Epoch:12/100(150) loss:4.85623025894165
# Epoch:16/100(200) loss:4.816319942474365
# Epoch:20/100(250) loss:4.796276092529297
# Epoch:25/100(300) loss:4.811583995819092
# Epoch:29/100(350) loss:4.779365539550781
# Epoch:33/100(400) loss:4.7941999435424805
# Epoch:37/100(450) loss:4.793978691101074
# Epoch:41/100(500) loss:4.765168190002441
# Epoch:45/100(550) loss:4.78970193862915
# Epoch:50/100(600) loss:4.782336711883545
# Epoch:54/100(650) loss:4.753142833709717
# Epoch:58/100(700) loss:4.74517822265625
# Epoch:62/100(750) loss:4.779107570648193
# Epoch:66/100(800) loss:4.760756015777588
# Epoch:70/100(850) loss:4.723230361938477
# Epoch:75/100(900) loss:4.733716011047363
# Epoch:79/100(950) loss:4.7400689125061035
# Epoch:83/100(1000) loss:4.7295331954956055
# Epoch:87/100(1050) loss:4.71008825302124
# Epoch:91/100(1100) loss:4.763620376586914
# Epoch:95/100(1150) loss:4.738816738128662
# =================  Clustering 1/2  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  68 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=4)]: Done 2380 tasks      | elapsed:    9.5s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:   10.3s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 128 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=4)]: Done 498 out of 498 | elapsed:    6.5s finished
#   -----  Load Model from record/Office31/CUDA3/ad_encoder__1 for clustering  -----
# nmi:0.36930900786596754
# nmi class:0.19122047793997918
# domain_accuracy:0.8196078431372549
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    6.8s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 128 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=4)]: Done 498 out of 498 | elapsed:    6.5s finished
#   -----  Load Model from record/Office31/CUDA3/ad_encoder__1 for clustering  -----
# nmi:0.3598452929927617
# nmi class:0.19104944225945986
# domain_accuracy:0.8126696832579186
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=4)]: Done 2680 tasks      | elapsed:    6.0s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    6.3s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 128 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=4)]: Done 498 out of 498 | elapsed:    5.8s finished
#   -----  Load Model from record/Office31/CUDA3/ad_encoder__1 for clustering  -----
# nmi:0.343127125726394
# nmi class:0.1917846855017107
# domain_accuracy:0.7996983408748115
# ===============================================
# ==============  webcam_amazon  ==============
# ===============================================
# Please install apex for mixed precision training from: https://github.com/NVIDIA/apex
#     ---------------------------------------------------------
#         cuda_dir: 3
#         batch_size: 256,  epochs: 100
#         SSL: simclr,  base_model: encoder
#         jigsaw: True,  fourier: True,  grid: 3
#         num_laps: 2,
#         log_dir: record/Office31/CUDA3/wa_encoder__2
#     ---------------------------------------------------------
#
#
# =================  1/2周目  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  68 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    5.8s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    6.2s finished
# Running on: cuda
# Epoch:0/100(0) loss:5.401469707489014
# Epoch:3/100(50) loss:4.946910858154297
# Epoch:7/100(100) loss:4.924071788787842
# Epoch:10/100(150) loss:4.864960670471191
# Epoch:14/100(200) loss:4.913534164428711
# Epoch:17/100(250) loss:4.837477684020996
# Epoch:21/100(300) loss:4.8319830894470215
# Epoch:25/100(350) loss:4.842366695404053
# Epoch:28/100(400) loss:4.854736328125
# Epoch:32/100(450) loss:4.807175636291504
# Epoch:35/100(500) loss:4.785286903381348
# Epoch:39/100(550) loss:4.833702087402344
# Epoch:42/100(600) loss:4.721830368041992
# Epoch:46/100(650) loss:4.840219497680664
# Epoch:50/100(700) loss:4.7846832275390625
# Epoch:53/100(750) loss:4.740317344665527
# Epoch:57/100(800) loss:4.7541069984436035
# Epoch:60/100(850) loss:4.776547908782959
# Epoch:64/100(900) loss:4.809582233428955
# Epoch:67/100(950) loss:4.720936298370361
# Epoch:71/100(1000) loss:4.6999006271362305
# Epoch:75/100(1050) loss:4.756797790527344
# Epoch:78/100(1100) loss:4.750929832458496
# Epoch:82/100(1150) loss:4.730759620666504
# Epoch:85/100(1200) loss:4.735733985900879
# Epoch:89/100(1250) loss:4.787022590637207
# Epoch:92/100(1300) loss:4.728686332702637
# Epoch:96/100(1350) loss:4.760275840759277
# =================  Clustering 1/2  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  88 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    3.3s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    4.8s finished
#   -----  Load Model from record/Office31/CUDA3/wa_encoder__2 for clustering  -----
# nmi:0.2775029776262686
# nmi class:0.18182027144915058
# domain_accuracy:0.6971207087486158
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    1.9s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    5.1s finished
#   -----  Load Model from record/Office31/CUDA3/wa_encoder__2 for clustering  -----
# nmi:0.29773917726324906
# nmi class:0.18457350171821182
# domain_accuracy:0.7245293466223699
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    2.0s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    4.8s finished
#   -----  Load Model from record/Office31/CUDA3/wa_encoder__2 for clustering  -----
# nmi:0.30063275637808035
# nmi class:0.1889386699036646
# domain_accuracy:0.7250830564784053
# ===============================================
# ==============  webcam_amazon  ==============
# ===============================================
# Please install apex for mixed precision training from: https://github.com/NVIDIA/apex
#     ---------------------------------------------------------
#         cuda_dir: 3
#         batch_size: 256,  epochs: 100
#         SSL: simclr,  base_model: encoder
#         jigsaw: True,  fourier: True,  grid: 3
#         num_laps: 2,
#         log_dir: record/Office31/CUDA3/wa_encoder__3
#     ---------------------------------------------------------
#
#
# =================  1/2周目  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  68 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    3.7s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    5.2s finished
# Running on: cuda
# Epoch:0/100(0) loss:5.430498123168945
# Epoch:3/100(50) loss:4.963836193084717
# Epoch:7/100(100) loss:4.886409759521484
# Epoch:10/100(150) loss:4.8581719398498535
# Epoch:14/100(200) loss:4.901093006134033
# Epoch:17/100(250) loss:4.849483013153076
# Epoch:21/100(300) loss:4.813599586486816
# Epoch:25/100(350) loss:4.804271221160889
# Epoch:28/100(400) loss:4.856894493103027
# Epoch:32/100(450) loss:4.808123588562012
# Epoch:35/100(500) loss:4.793363094329834
# Epoch:39/100(550) loss:4.829911231994629
# Epoch:42/100(600) loss:4.733047962188721
# Epoch:46/100(650) loss:4.823197841644287
# Epoch:50/100(700) loss:4.776294231414795
# Epoch:53/100(750) loss:4.742265224456787
# Epoch:57/100(800) loss:4.758621692657471
# Epoch:60/100(850) loss:4.776130676269531
# Epoch:64/100(900) loss:4.8118672370910645
# Epoch:67/100(950) loss:4.717657566070557
# Epoch:71/100(1000) loss:4.704082489013672
# Epoch:75/100(1050) loss:4.762194633483887
# Epoch:78/100(1100) loss:4.748613357543945
# Epoch:82/100(1150) loss:4.7323150634765625
# Epoch:85/100(1200) loss:4.728189468383789
# Epoch:89/100(1250) loss:4.776457786560059
# Epoch:92/100(1300) loss:4.725890159606934
# Epoch:96/100(1350) loss:4.743458271026611
# =================  Clustering 1/2  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    2.3s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    5.0s finished
#   -----  Load Model from record/Office31/CUDA3/wa_encoder__3 for clustering  -----
# nmi:0.3134458028355065
# nmi class:0.19887717219741868
# domain_accuracy:0.7403100775193798
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    2.7s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    5.3s finished
#   -----  Load Model from record/Office31/CUDA3/wa_encoder__3 for clustering  -----
# nmi:0.2810458870396287
# nmi class:0.20348198745262275
# domain_accuracy:0.7040420819490587
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    2.6s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    5.5s finished
#   -----  Load Model from record/Office31/CUDA3/wa_encoder__3 for clustering  -----
# nmi:0.2706057570682097
# nmi class:0.2028965733146467
# domain_accuracy:0.6921373200442968
# ===============================================
# ==============  webcam_amazon  ==============
# ===============================================
# Please install apex for mixed precision training from: https://github.com/NVIDIA/apex
#     ---------------------------------------------------------
#         cuda_dir: 3
#         batch_size: 256,  epochs: 100
#         SSL: simclr,  base_model: encoder
#         jigsaw: True,  fourier: True,  grid: 3
#         num_laps: 2,
#         log_dir: record/Office31/CUDA3/wa_encoder__4
#     ---------------------------------------------------------
#
#
# =================  1/2周目  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  88 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    4.3s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    5.5s finished
# Running on: cuda
# Epoch:0/100(0) loss:5.405422687530518
# Epoch:3/100(50) loss:4.980407238006592
# Epoch:7/100(100) loss:4.918676376342773
# Epoch:10/100(150) loss:4.881595134735107
# Epoch:14/100(200) loss:4.893898963928223
# Epoch:17/100(250) loss:4.844082832336426
# Epoch:21/100(300) loss:4.818397521972656
# Epoch:25/100(350) loss:4.822751522064209
# Epoch:28/100(400) loss:4.855581760406494
# Epoch:32/100(450) loss:4.824875831604004
# Epoch:35/100(500) loss:4.794639587402344
# Epoch:39/100(550) loss:4.830096244812012
# Epoch:42/100(600) loss:4.727333068847656
# Epoch:46/100(650) loss:4.826061248779297
# Epoch:50/100(700) loss:4.789081573486328
# Epoch:53/100(750) loss:4.744970321655273
# Epoch:57/100(800) loss:4.769067764282227
# Epoch:60/100(850) loss:4.767527103424072
# Epoch:64/100(900) loss:4.7982988357543945
# Epoch:67/100(950) loss:4.729938983917236
# Epoch:71/100(1000) loss:4.721291542053223
# Epoch:75/100(1050) loss:4.760642051696777
# Epoch:78/100(1100) loss:4.763844013214111
# Epoch:82/100(1150) loss:4.736701965332031
# Epoch:85/100(1200) loss:4.740182399749756
# Epoch:89/100(1250) loss:4.784479141235352
# Epoch:92/100(1300) loss:4.742095947265625
# Epoch:96/100(1350) loss:4.75042200088501
# =================  Clustering 1/2  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  88 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    4.1s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    5.1s finished
#   -----  Load Model from record/Office31/CUDA3/wa_encoder__4 for clustering  -----
# nmi:0.2842707154987051
# nmi class:0.18945808867957856
# domain_accuracy:0.7148394241417497
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    2.4s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    5.6s finished
#   -----  Load Model from record/Office31/CUDA3/wa_encoder__4 for clustering  -----
# nmi:0.2830293057302066
# nmi class:0.19206879474496102
# domain_accuracy:0.7112403100775194
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    2.3s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    5.0s finished
#   -----  Load Model from record/Office31/CUDA3/wa_encoder__4 for clustering  -----
# nmi:0.2892134138030071
# nmi class:0.18965496171654092
# domain_accuracy:0.7297895902547065
# CPU times: user 17.2 s, sys: 1.66 s, total: 18.9 s
# Wall time: 45min 48s

# %%
# import os
# os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID" 
# os.environ["CUDA_VISIBLE_DEVICES"] = str(N_CUDA)

# from clustering import run_clustering
# from dataset import get_datasets
# from simclr import SimCLR
# from log_functions import *
# config.config_path = CONFIG_FILE
# config.log_dir = log_dir
# config.num_laps = 2
# config.spread_message = ""
# config.cuda_dir = CUDA_DIR
# config.lap = 1
# config.pseudo_out_dim = 8

# dataset = get_datasets(config, 'train')
# simclr = SimCLR(dataset, config)
# simclr.train()
# run_clustering(config)

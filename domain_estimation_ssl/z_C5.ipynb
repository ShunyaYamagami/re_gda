# %%
# %reset -f
# !rm -fr __pycache__
# !rm -fr */__pycache__

# %%
from z_common import *

# ファイル特有変数
CUDA_DIR = 5
N_CUDA = 2
spread_message = LOG_TEXT

# %%
# %%time
# PARENT = 'Digit'
# DATA_DOMAIN_LIST = [
#   'svhn_mnist',
#   'svhn_synth',
#   'svhn_synth_mnist',
#   'svhn_synth_mnist_mnistm',
# ]
PARENT = 'Office31'
DATA_DOMAIN_LIST = [
  # 'amazon_dslr_webcam',
  # 'dslr_webcam',
  # 'dslr_webcam',
  # 'dslr_webcam',
  'amazon_dslr',
  'amazon_dslr',
  'amazon_dslr',
  'webcam_amazon',
  'webcam_amazon',
  'webcam_amazon',
]


LAP = 1
NUM_LAPS = 2
log_dir_opt = ''
# log_dir_opt += '__record'
# log_dir_opt += '__douse'

counter=0
for DATA_DOMAIN in DATA_DOMAIN_LIST:
  config, CONFIG_FILE, log_dir = config_to_execute(DATA_DOMAIN, PARENT, CUDA_DIR, log_dir_opt)
  log_dir += f'__{counter}'
  counter += 1

  # !rm -fr */__pycache__
  # !CUDA_VISIBLE_DEVICES=$N_CUDA python3 -B run.py --config=$CONFIG_FILE  --log_dir=$log_dir  --num_laps=$NUM_LAPS  --spread_message=$spread_message  --cuda_dir=$CUDA_DIR
# Out:
# ===============================================
# ==============  amazon_dslr  ==============
# ===============================================
# Please install apex for mixed precision training from: https://github.com/NVIDIA/apex
#     ---------------------------------------------------------
#         cuda_dir: 5
#         batch_size: 256,  epochs: 100
#         SSL: simclr,  base_model: encoder
#         jigsaw: True,  fourier: True,  grid: 3
#         num_laps: 2,
#         log_dir: record/Office31/CUDA5/ad_encoder__0
#     ---------------------------------------------------------
#
#
# =================  1/2周目  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  71 tasks      | elapsed:    3.4s
# [Parallel(n_jobs=4)]: Done 2380 tasks      | elapsed:    9.7s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:   10.9s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  76 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=4)]: Done 472 tasks      | elapsed:    8.2s
# [Parallel(n_jobs=4)]: Done 491 out of 498 | elapsed:    8.4s remaining:    0.1s
# [Parallel(n_jobs=4)]: Done 498 out of 498 | elapsed:    8.4s finished
# Running on: cuda
# Epoch:0/100(0) loss:5.389376640319824
# Epoch:4/100(50) loss:4.794044017791748
# Epoch:8/100(100) loss:4.7410359382629395
# Epoch:12/100(150) loss:4.763491630554199
# Epoch:16/100(200) loss:4.7373456954956055
# Epoch:20/100(250) loss:4.730618476867676
# Epoch:25/100(300) loss:4.768165111541748
# Epoch:29/100(350) loss:4.706082820892334
# Epoch:33/100(400) loss:4.737823963165283
# Epoch:37/100(450) loss:4.723333835601807
# Epoch:41/100(500) loss:4.69935941696167
# Epoch:45/100(550) loss:4.730128288269043
# Epoch:50/100(600) loss:4.736222267150879
# Epoch:54/100(650) loss:4.6904778480529785
# Epoch:58/100(700) loss:4.692073822021484
# Epoch:62/100(750) loss:4.737189292907715
# Epoch:66/100(800) loss:4.720941543579102
# Epoch:70/100(850) loss:4.692296981811523
# Epoch:75/100(900) loss:4.691125392913818
# Epoch:79/100(950) loss:4.691011428833008
# Epoch:83/100(1000) loss:4.670998573303223
# Epoch:87/100(1050) loss:4.651607990264893
# Epoch:91/100(1100) loss:4.716675281524658
# Epoch:95/100(1150) loss:4.687335014343262
# =================  Clustering 1/2  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  49 tasks      | elapsed:    3.2s
# [Parallel(n_jobs=4)]: Done 2804 tasks      | elapsed:    9.7s
# [Parallel(n_jobs=4)]: Done 2810 out of 2817 | elapsed:    9.7s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    9.7s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  76 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=4)]: Done 498 out of 498 | elapsed:    7.6s finished
#   -----  Load Model from record/Office31/CUDA5/ad_encoder__0 for clustering  -----
# nmi:0.4169427032331142
# nmi class:0.21695947461556112
# domain_accuracy:0.8506787330316742
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=4)]: Done 2680 tasks      | elapsed:    6.2s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    6.5s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 128 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=4)]: Done 498 out of 498 | elapsed:    6.9s finished
#   -----  Load Model from record/Office31/CUDA5/ad_encoder__0 for clustering  -----
# nmi:0.4169427032331142
# nmi class:0.2285444012844055
# domain_accuracy:0.8506787330316742
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    6.3s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 128 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=4)]: Done 491 out of 498 | elapsed:    6.6s remaining:    0.1s
# [Parallel(n_jobs=4)]: Done 498 out of 498 | elapsed:    6.7s finished
#   -----  Load Model from record/Office31/CUDA5/ad_encoder__0 for clustering  -----
# nmi:0.4169427032331142
# nmi class:0.22743289370333086
# domain_accuracy:0.8506787330316742
# ===============================================
# ==============  amazon_dslr  ==============
# ===============================================
# Please install apex for mixed precision training from: https://github.com/NVIDIA/apex
#     ---------------------------------------------------------
#         cuda_dir: 5
#         batch_size: 256,  epochs: 100
#         SSL: simclr,  base_model: encoder
#         jigsaw: True,  fourier: True,  grid: 3
#         num_laps: 2,
#         log_dir: record/Office31/CUDA5/ad_encoder__1
#     ---------------------------------------------------------
#
#
# =================  1/2周目  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  95 tasks      | elapsed:    2.9s
# [Parallel(n_jobs=4)]: Done 2810 out of 2817 | elapsed:    9.4s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    9.4s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  76 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=4)]: Done 498 out of 498 | elapsed:    7.5s finished
# Running on: cuda
# Epoch:0/100(0) loss:5.389376640319824
# Epoch:4/100(50) loss:4.793832778930664
# Epoch:8/100(100) loss:4.74042272567749
# Epoch:12/100(150) loss:4.76296329498291
# Epoch:16/100(200) loss:4.735220909118652
# Epoch:20/100(250) loss:4.732147216796875
# Epoch:25/100(300) loss:4.767289161682129
# Epoch:29/100(350) loss:4.704900741577148
# Epoch:33/100(400) loss:4.738668918609619
# Epoch:37/100(450) loss:4.719629764556885
# Epoch:41/100(500) loss:4.698776721954346
# Epoch:45/100(550) loss:4.729169845581055
# Epoch:50/100(600) loss:4.733972549438477
# Epoch:54/100(650) loss:4.69769811630249
# Epoch:58/100(700) loss:4.6916632652282715
# Epoch:62/100(750) loss:4.734310626983643
# Epoch:66/100(800) loss:4.7226033210754395
# Epoch:70/100(850) loss:4.687392234802246
# Epoch:75/100(900) loss:4.686495304107666
# Epoch:79/100(950) loss:4.692224502563477
# Epoch:83/100(1000) loss:4.673501014709473
# Epoch:87/100(1050) loss:4.655505180358887
# Epoch:91/100(1100) loss:4.713658332824707
# Epoch:95/100(1150) loss:4.691397666931152
# =================  Clustering 1/2  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  71 tasks      | elapsed:    3.4s
# [Parallel(n_jobs=4)]: Done 2380 tasks      | elapsed:    9.1s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:   10.2s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 128 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=4)]: Done 498 out of 498 | elapsed:    6.9s finished
#   -----  Load Model from record/Office31/CUDA5/ad_encoder__1 for clustering  -----
# nmi:0.4523911223067964
# nmi class:0.21737112286228327
# domain_accuracy:0.8702865761689291
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=4)]: Done 2680 tasks      | elapsed:    6.4s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    6.6s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 128 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=4)]: Done 498 out of 498 | elapsed:    7.4s finished
#   -----  Load Model from record/Office31/CUDA5/ad_encoder__1 for clustering  -----
# nmi:0.4523911223067964
# nmi class:0.22124133540300325
# domain_accuracy:0.8702865761689291
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=4)]: Done 2680 tasks      | elapsed:    6.3s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    6.6s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 128 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=4)]: Done 498 out of 498 | elapsed:    7.5s finished
#   -----  Load Model from record/Office31/CUDA5/ad_encoder__1 for clustering  -----
# nmi:0.4523911223067964
# nmi class:0.2194519851972397
# domain_accuracy:0.8702865761689291
# ===============================================
# ==============  amazon_dslr  ==============
# ===============================================
# Please install apex for mixed precision training from: https://github.com/NVIDIA/apex
#     ---------------------------------------------------------
#         cuda_dir: 5
#         batch_size: 256,  epochs: 100
#         SSL: simclr,  base_model: encoder
#         jigsaw: True,  fourier: True,  grid: 3
#         num_laps: 2,
#         log_dir: record/Office31/CUDA5/ad_encoder__2
#     ---------------------------------------------------------
#
#
# =================  1/2周目  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 102 tasks      | elapsed:    2.9s
# [Parallel(n_jobs=4)]: Done 2216 tasks      | elapsed:    8.0s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    9.3s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  76 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=4)]: Done 491 out of 498 | elapsed:    7.2s remaining:    0.1s
# [Parallel(n_jobs=4)]: Done 498 out of 498 | elapsed:    7.4s finished
# Running on: cuda
# Epoch:0/100(0) loss:5.389376640319824
# Epoch:4/100(50) loss:4.793774127960205
# Epoch:8/100(100) loss:4.7413249015808105
# Epoch:12/100(150) loss:4.764652729034424
# Epoch:16/100(200) loss:4.734673023223877
# Epoch:20/100(250) loss:4.732861042022705
# Epoch:25/100(300) loss:4.766579627990723
# Epoch:29/100(350) loss:4.706339359283447
# Epoch:33/100(400) loss:4.739984035491943
# Epoch:37/100(450) loss:4.720081329345703
# Epoch:41/100(500) loss:4.6951189041137695
# Epoch:45/100(550) loss:4.732333660125732
# Epoch:50/100(600) loss:4.733763694763184
# Epoch:54/100(650) loss:4.694484233856201
# Epoch:58/100(700) loss:4.693477630615234
# Epoch:62/100(750) loss:4.73666524887085
# Epoch:66/100(800) loss:4.727004051208496
# Epoch:70/100(850) loss:4.689091682434082
# Epoch:75/100(900) loss:4.689667224884033
# Epoch:79/100(950) loss:4.692176818847656
# Epoch:83/100(1000) loss:4.672506809234619
# Epoch:87/100(1050) loss:4.654469013214111
# Epoch:91/100(1100) loss:4.718951225280762
# Epoch:95/100(1150) loss:4.688048839569092
# =================  Clustering 1/2  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  62 tasks      | elapsed:    4.3s
# [Parallel(n_jobs=4)]: Done 2320 tasks      | elapsed:   10.3s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:   11.8s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  80 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=4)]: Done 491 out of 498 | elapsed:    8.0s remaining:    0.1s
# [Parallel(n_jobs=4)]: Done 498 out of 498 | elapsed:    8.0s finished
#   -----  Load Model from record/Office31/CUDA5/ad_encoder__2 for clustering  -----
# nmi:0.4139025153473784
# nmi class:0.2257732983809147
# domain_accuracy:0.848868778280543
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    6.9s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 128 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=4)]: Done 491 out of 498 | elapsed:    7.3s remaining:    0.1s
# [Parallel(n_jobs=4)]: Done 498 out of 498 | elapsed:    7.4s finished
#   -----  Load Model from record/Office31/CUDA5/ad_encoder__2 for clustering  -----
# nmi:0.4139025153473784
# nmi class:0.2205248632542507
# domain_accuracy:0.848868778280543
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=4)]: Done 2680 tasks      | elapsed:    6.7s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    7.0s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 128 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=4)]: Done 491 out of 498 | elapsed:    7.7s remaining:    0.1s
# [Parallel(n_jobs=4)]: Done 498 out of 498 | elapsed:    7.7s finished
#   -----  Load Model from record/Office31/CUDA5/ad_encoder__2 for clustering  -----
# nmi:0.4139025153473784
# nmi class:0.21965798974670894
# domain_accuracy:0.848868778280543
# ===============================================
# ==============  webcam_amazon  ==============
# ===============================================
# Please install apex for mixed precision training from: https://github.com/NVIDIA/apex
#     ---------------------------------------------------------
#         cuda_dir: 5
#         batch_size: 256,  epochs: 100
#         SSL: simclr,  base_model: encoder
#         jigsaw: True,  fourier: True,  grid: 3
#         num_laps: 2,
#         log_dir: record/Office31/CUDA5/wa_encoder__3
#     ---------------------------------------------------------
#
#
# =================  1/2周目  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  56 tasks      | elapsed:    3.6s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    6.7s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    7.3s finished
# Running on: cuda
# Epoch:0/100(0) loss:5.327547073364258
# Epoch:3/100(50) loss:4.870728969573975
# Epoch:7/100(100) loss:4.82905912399292
# Epoch:10/100(150) loss:4.7850542068481445
# Epoch:14/100(200) loss:4.811376571655273
# Epoch:17/100(250) loss:4.7584428787231445
# Epoch:21/100(300) loss:4.74281120300293
# Epoch:25/100(350) loss:4.747802257537842
# Epoch:28/100(400) loss:4.788949012756348
# Epoch:32/100(450) loss:4.747245788574219
# Epoch:35/100(500) loss:4.740916728973389
# Epoch:39/100(550) loss:4.755094528198242
# Epoch:42/100(600) loss:4.684299945831299
# Epoch:46/100(650) loss:4.767518520355225
# Epoch:50/100(700) loss:4.7340312004089355
# Epoch:53/100(750) loss:4.694316387176514
# Epoch:57/100(800) loss:4.709890365600586
# Epoch:60/100(850) loss:4.7225236892700195
# Epoch:64/100(900) loss:4.757107734680176
# Epoch:67/100(950) loss:4.670235633850098
# Epoch:71/100(1000) loss:4.65905237197876
# Epoch:75/100(1050) loss:4.6924729347229
# Epoch:78/100(1100) loss:4.694394588470459
# Epoch:82/100(1150) loss:4.680234909057617
# Epoch:85/100(1200) loss:4.6867876052856445
# Epoch:89/100(1250) loss:4.70733118057251
# Epoch:92/100(1300) loss:4.683172702789307
# Epoch:96/100(1350) loss:4.711717128753662
# =================  Clustering 1/2  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  68 tasks      | elapsed:    4.0s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    7.4s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    7.3s finished
#   -----  Load Model from record/Office31/CUDA5/wa_encoder__3 for clustering  -----
# nmi:0.2625032235204702
# nmi class:0.22332755240272423
# domain_accuracy:0.6926910299003323
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 200 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    4.3s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    6.9s finished
#   -----  Load Model from record/Office31/CUDA5/wa_encoder__3 for clustering  -----
# nmi:0.2625032235204702
# nmi class:0.2284936698150095
# domain_accuracy:0.6926910299003323
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    3.7s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    6.9s finished
#   -----  Load Model from record/Office31/CUDA5/wa_encoder__3 for clustering  -----
# nmi:0.2625032235204702
# nmi class:0.2231562176185721
# domain_accuracy:0.6926910299003322
# ===============================================
# ==============  webcam_amazon  ==============
# ===============================================
# Please install apex for mixed precision training from: https://github.com/NVIDIA/apex
#     ---------------------------------------------------------
#         cuda_dir: 5
#         batch_size: 256,  epochs: 100
#         SSL: simclr,  base_model: encoder
#         jigsaw: True,  fourier: True,  grid: 3
#         num_laps: 2,
#         log_dir: record/Office31/CUDA5/wa_encoder__4
#     ---------------------------------------------------------
#
#
# =================  1/2周目  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  56 tasks      | elapsed:    4.0s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    7.6s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=4)]: Done 2680 tasks      | elapsed:    6.5s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    6.9s finished
# Running on: cuda
# Epoch:0/100(0) loss:5.327547073364258
# Epoch:3/100(50) loss:4.87081241607666
# Epoch:7/100(100) loss:4.830094337463379
# Epoch:10/100(150) loss:4.788791656494141
# Epoch:14/100(200) loss:4.814234733581543
# Epoch:17/100(250) loss:4.757065773010254
# Epoch:21/100(300) loss:4.743992805480957
# Epoch:25/100(350) loss:4.748377323150635
# Epoch:28/100(400) loss:4.792587757110596
# Epoch:32/100(450) loss:4.7433648109436035
# Epoch:35/100(500) loss:4.7427473068237305
# Epoch:39/100(550) loss:4.756323337554932
# Epoch:42/100(600) loss:4.683426380157471
# Epoch:46/100(650) loss:4.770769119262695
# Epoch:50/100(700) loss:4.725207805633545
# Epoch:53/100(750) loss:4.693339824676514
# Epoch:57/100(800) loss:4.710977554321289
# Epoch:60/100(850) loss:4.727621078491211
# Epoch:64/100(900) loss:4.759464263916016
# Epoch:67/100(950) loss:4.667880535125732
# Epoch:71/100(1000) loss:4.658127784729004
# Epoch:75/100(1050) loss:4.693543434143066
# Epoch:78/100(1100) loss:4.69882869720459
# Epoch:82/100(1150) loss:4.679020404815674
# Epoch:85/100(1200) loss:4.693892955780029
# Epoch:89/100(1250) loss:4.708731174468994
# Epoch:92/100(1300) loss:4.679557800292969
# Epoch:96/100(1350) loss:4.7086405754089355
# =================  Clustering 1/2  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  56 tasks      | elapsed:    4.5s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    8.4s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=4)]: Done 2680 tasks      | elapsed:    7.2s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    7.6s finished
#   -----  Load Model from record/Office31/CUDA5/wa_encoder__4 for clustering  -----
# nmi:0.26730124892547824
# nmi class:0.22687559101165486
# domain_accuracy:0.6982281284606866
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 200 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    4.0s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=4)]: Done 2680 tasks      | elapsed:    7.1s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    7.4s finished
#   -----  Load Model from record/Office31/CUDA5/wa_encoder__4 for clustering  -----
# nmi:0.26730124892547824
# nmi class:0.21622772004430924
# domain_accuracy:0.6982281284606866
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 200 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    4.4s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=4)]: Done 2680 tasks      | elapsed:    6.6s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    7.1s finished
#   -----  Load Model from record/Office31/CUDA5/wa_encoder__4 for clustering  -----
# nmi:0.26730124892547824
# nmi class:0.21904033206547083
# domain_accuracy:0.6982281284606866
# ===============================================
# ==============  webcam_amazon  ==============
# ===============================================
# Please install apex for mixed precision training from: https://github.com/NVIDIA/apex
#     ---------------------------------------------------------
#         cuda_dir: 5
#         batch_size: 256,  epochs: 100
#         SSL: simclr,  base_model: encoder
#         jigsaw: True,  fourier: True,  grid: 3
#         num_laps: 2,
#         log_dir: record/Office31/CUDA5/wa_encoder__5
#     ---------------------------------------------------------
#
#
# =================  1/2周目  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  56 tasks      | elapsed:    3.9s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    7.2s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    7.0s finished
# Running on: cuda
# Epoch:0/100(0) loss:5.327547073364258
# Epoch:3/100(50) loss:4.870906352996826
# Epoch:7/100(100) loss:4.8298258781433105
# Epoch:10/100(150) loss:4.784516334533691
# Epoch:14/100(200) loss:4.813559532165527
# Epoch:17/100(250) loss:4.758386135101318
# Epoch:21/100(300) loss:4.744004726409912
# Epoch:25/100(350) loss:4.750052452087402
# Epoch:28/100(400) loss:4.792232990264893
# Epoch:32/100(450) loss:4.745004177093506
# Epoch:35/100(500) loss:4.740301132202148
# Epoch:39/100(550) loss:4.758595943450928
# Epoch:42/100(600) loss:4.683598041534424
# Epoch:46/100(650) loss:4.76870059967041
# Epoch:50/100(700) loss:4.728459358215332
# Epoch:53/100(750) loss:4.694215774536133
# Epoch:57/100(800) loss:4.70487117767334
# Epoch:60/100(850) loss:4.725344181060791
# Epoch:64/100(900) loss:4.76442289352417
# Epoch:67/100(950) loss:4.6688103675842285
# Epoch:71/100(1000) loss:4.658705711364746
# Epoch:75/100(1050) loss:4.691900253295898
# Epoch:78/100(1100) loss:4.700164318084717
# Epoch:82/100(1150) loss:4.672319412231445
# Epoch:85/100(1200) loss:4.688037872314453
# Epoch:89/100(1250) loss:4.708349704742432
# Epoch:92/100(1300) loss:4.680795192718506
# Epoch:96/100(1350) loss:4.708401679992676
# =================  Clustering 1/2  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  48 tasks      | elapsed:    3.6s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    6.8s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    6.6s finished
#   -----  Load Model from record/Office31/CUDA5/wa_encoder__5 for clustering  -----
# nmi:0.25663368466140407
# nmi class:0.22032746126237504
# domain_accuracy:0.6857696566998892
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 200 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    3.9s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=4)]: Done 2680 tasks      | elapsed:    6.3s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    6.7s finished
#   -----  Load Model from record/Office31/CUDA5/wa_encoder__5 for clustering  -----
# nmi:0.25663368466140407
# nmi class:0.2267747553426925
# domain_accuracy:0.6857696566998892
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 200 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    3.8s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=4)]: Done 2680 tasks      | elapsed:    6.3s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    6.7s finished
#   -----  Load Model from record/Office31/CUDA5/wa_encoder__5 for clustering  -----
# nmi:0.25663368466140407
# nmi class:0.2303909705969086
# domain_accuracy:0.6857696566998892
# CPU times: user 28.4 s, sys: 2.73 s, total: 31.1 s
# Wall time: 1h 14min 58s

# %%
# import os
# os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID" 
# os.environ["CUDA_VISIBLE_DEVICES"] = str(N_CUDA)

# from clustering import run_clustering
# from dataset import get_datasets
# from simclr import SimCLR
# from log_functions import *
# config.config_path = CONFIG_FILE
# config.log_dir = log_dir
# config.num_laps = 2
# config.spread_message = ""
# config.cuda_dir = CUDA_DIR
# config.lap = 1
# config.pseudo_out_dim = 8

# dataset = get_datasets(config, 'train')
# simclr = SimCLR(dataset, config)
# simclr.train()
# run_clustering(config)

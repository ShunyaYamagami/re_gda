# %%
# %reset -f
# !rm -fr __pycache__
# !rm -fr */__pycache__

# %% [markdown]
# # Domain Estimation

# %%
from z_common import *

# ファイル特有変数
CUDA_DIR = 2
N_CUDA = 2
spread_message = LOG_TEXT

# %%
# %%time
# PARENT = 'Digit'
# DATA_DOMAIN_LIST = [
#   'svhn_mnist',
#   'svhn_synth',
#   'svhn_synth_mnist',
#   'svhn_synth_mnist_mnistm',
# ]
PARENT = 'Office31'
DATA_DOMAIN_LIST = [
  # 'amazon_dslr_webcam',
  # 'dslr_webcam',
  # 'amazon_dslr',
  'webcam_amazon',
  'webcam_amazon',
  'webcam_amazon',
]


LAP = 1
NUM_LAPS = 2
log_dir_opt = ''
# log_dir_opt += '__record'
# log_dir_opt += '__douse'


for DATA_DOMAIN in DATA_DOMAIN_LIST:
  config, CONFIG_FILE, log_dir = config_to_execute(DATA_DOMAIN, PARENT, CUDA_DIR, log_dir_opt)

  # !rm -fr */__pycache__
  # !CUDA_VISIBLE_DEVICES=$N_CUDA python3 -B run.py --config=$CONFIG_FILE  --log_dir=$log_dir  --num_laps=$NUM_LAPS  --spread_message=$spread_message  --cuda_dir=$CUDA_DIR
# Out:
# ===============================================
# ==============  webcam_amazon  ==============
# ===============================================
# Please install apex for mixed precision training from: https://github.com/NVIDIA/apex
#     ---------------------------------------------------------
#         batch_size: 256,  epochs: 100
#         SSL: simclr,  base_model: encoder
#         jigsaw: True,  fourier: True,  grid: 3
#         num_laps: 2
#     ---------------------------------------------------------
#
#
# =================  1/2周目  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  68 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    5.6s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=4)]: Done 2680 tasks      | elapsed:    7.5s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    7.8s finished
# Running on: cuda
# Epoch:0/100(0) loss:5.430399417877197
# Epoch:3/100(50) loss:5.046699523925781
# Epoch:7/100(100) loss:5.038358211517334
# Epoch:10/100(150) loss:4.952150821685791
# Epoch:14/100(200) loss:4.917566299438477
# Epoch:17/100(250) loss:4.929279804229736
# Epoch:21/100(300) loss:4.894797325134277
# Epoch:25/100(350) loss:4.944508075714111
# Epoch:28/100(400) loss:4.9572224617004395
# Epoch:32/100(450) loss:4.914841651916504
# Epoch:35/100(500) loss:4.868900299072266
# Epoch:39/100(550) loss:4.90558385848999
# Epoch:42/100(600) loss:4.885787487030029
# Epoch:46/100(650) loss:4.881869316101074
# Epoch:50/100(700) loss:4.8300862312316895
# Epoch:53/100(750) loss:4.837710857391357
# Epoch:57/100(800) loss:4.888584613800049
# Epoch:60/100(850) loss:4.826419830322266
# Epoch:64/100(900) loss:4.871703624725342
# Epoch:67/100(950) loss:4.826096057891846
# Epoch:71/100(1000) loss:4.8392839431762695
# Epoch:75/100(1050) loss:4.818112373352051
# Epoch:78/100(1100) loss:4.828393936157227
# Epoch:82/100(1150) loss:4.829452037811279
# Epoch:85/100(1200) loss:4.840749263763428
# Epoch:89/100(1250) loss:4.795373916625977
# Epoch:92/100(1300) loss:4.765054702758789
# Epoch:96/100(1350) loss:4.798941135406494
# =================  Clustering 1/2  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  71 tasks      | elapsed:    3.7s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    8.0s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=4)]: Done 2680 tasks      | elapsed:    8.8s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    9.2s finished
#   -----  Load Model from record/Office31/CUDA2/wa_encoder for clustering  -----
#   -----  Load NMI File from record/Office31/CUDA2/wa_encoder  -----
# nmi:0.33738705801175
# nmi class:0.1769419272845597
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 200 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    5.5s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    8.9s finished
#   -----  Load Model from record/Office31/CUDA2/wa_encoder for clustering  -----
#   -----  Load NMI File from record/Office31/CUDA2/wa_encoder  -----
# nmi:0.32784927236289113
# nmi class:0.18018278394235326
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 200 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    4.9s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=4)]: Done 2680 tasks      | elapsed:    9.0s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    9.4s finished
#   -----  Load Model from record/Office31/CUDA2/wa_encoder for clustering  -----
#   -----  Load NMI File from record/Office31/CUDA2/wa_encoder  -----
# nmi:0.3471108999614609
# nmi class:0.17818013183202205
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    4.1s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    7.6s finished
#   -----  Load Model from record/Office31/CUDA2/wa_encoder for clustering  -----
#   -----  Load NMI File from record/Office31/CUDA2/wa_encoder  -----
# nmi:0.34388386429981393
# nmi class:0.17351603074905614
# ===============================================
# ==============  webcam_amazon  ==============
# ===============================================
# Please install apex for mixed precision training from: https://github.com/NVIDIA/apex
#     ---------------------------------------------------------
#         batch_size: 256,  epochs: 100
#         SSL: simclr,  base_model: encoder
#         jigsaw: True,  fourier: True,  grid: 3
#         num_laps: 2
#     ---------------------------------------------------------
#
#
# =================  1/2周目  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  68 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    6.0s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=4)]: Done 2680 tasks      | elapsed:    7.9s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    8.3s finished
# Running on: cuda
# Epoch:0/100(0) loss:5.4776611328125
# Epoch:3/100(50) loss:5.0376129150390625
# Epoch:7/100(100) loss:5.036341667175293
# Epoch:10/100(150) loss:4.958961009979248
# Epoch:14/100(200) loss:4.911736965179443
# Epoch:17/100(250) loss:4.8948235511779785
# Epoch:21/100(300) loss:4.905158996582031

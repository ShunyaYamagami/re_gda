# %%
# %reset -f
# !rm -fr __pycache__
# !rm -fr */__pycache__

# %%
from z_common import *

# ファイル特有変数
CUDA_DIR = 2
N_CUDA = 2
spread_message = LOG_TEXT

# %%
# %%time
# PARENT = 'Digit'
# DATA_DOMAIN_LIST = [
#   'svhn_mnist',
#   'svhn_synth',
#   'svhn_synth_mnist',
#   'svhn_synth_mnist_mnistm',
# ]
PARENT = 'Office31'
DATA_DOMAIN_LIST = [
  # 'amazon_dslr_webcam',
  # 'dslr_webcam',
  # 'dslr_webcam',
  # 'dslr_webcam',
  'amazon_dslr',
  'amazon_dslr',
  'amazon_dslr',
  'webcam_amazon',
  'webcam_amazon',
  'webcam_amazon',
]


LAP = 1
NUM_LAPS = 2
log_dir_opt = ''
# log_dir_opt += '__record'
# log_dir_opt += '__douse'

counter=0
for DATA_DOMAIN in DATA_DOMAIN_LIST:
  config, CONFIG_FILE, log_dir = config_to_execute(DATA_DOMAIN, PARENT, CUDA_DIR, log_dir_opt)
  log_dir += f'__{counter}'
  counter += 1

  # !rm -fr */__pycache__
  # !CUDA_VISIBLE_DEVICES=$N_CUDA python3 -B run.py --config=$CONFIG_FILE  --log_dir=$log_dir  --num_laps=$NUM_LAPS  --spread_message=$spread_message  --cuda_dir=$CUDA_DIR
# Out:
# ===============================================
# ==============  amazon_dslr  ==============
# ===============================================
# Please install apex for mixed precision training from: https://github.com/NVIDIA/apex
#     ---------------------------------------------------------
#         cuda_dir: 2
#         batch_size: 256,  epochs: 100
#         SSL: simclr,  base_model: encoder
#         jigsaw: True,  fourier: True,  grid: 3
#         num_laps: 2,
#         log_dir: record/Office31/CUDA2/ad_encoder__0
#     ---------------------------------------------------------
#
#
# =================  1/2周目  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  71 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=4)]: Done 2380 tasks      | elapsed:    8.3s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    9.4s finished
# /home/syamagami/codes/re_gda/domain_estimation_ssl/dataset.py:107: FutureWarning: The input object of type 'Image' is an array-like implementing one of the corresponding protocols (`__array__`, `__array_interface__` or `__array_struct__`); but not a sequence (or 0-D). In the future, this object will be coerced as if it was first converted using `np.array(obj)`. To retain the old behaviour, you have to either modify the type 'Image', or assign to an empty array created with `np.empty(correct_shape, dtype=object)`.
#   self.imgs = np.array([t[1] for t in self.processed])
# /home/syamagami/codes/re_gda/domain_estimation_ssl/dataset.py:107: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   self.imgs = np.array([t[1] for t in self.processed])
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  76 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=4)]: Done 498 out of 498 | elapsed:    7.8s finished
# /home/syamagami/codes/re_gda/domain_estimation_ssl/dataset.py:107: FutureWarning: The input object of type 'Image' is an array-like implementing one of the corresponding protocols (`__array__`, `__array_interface__` or `__array_struct__`); but not a sequence (or 0-D). In the future, this object will be coerced as if it was first converted using `np.array(obj)`. To retain the old behaviour, you have to either modify the type 'Image', or assign to an empty array created with `np.empty(correct_shape, dtype=object)`.
#   self.imgs = np.array([t[1] for t in self.processed])
# /home/syamagami/codes/re_gda/domain_estimation_ssl/dataset.py:107: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   self.imgs = np.array([t[1] for t in self.processed])
# Running on: cuda
# Epoch:0/100(0) loss:5.545013904571533
# Epoch:4/100(50) loss:5.038558483123779
# Epoch:8/100(100) loss:4.931620121002197
# Epoch:12/100(150) loss:4.950357913970947
# Epoch:16/100(200) loss:4.926121711730957
# Epoch:20/100(250) loss:4.872621536254883
# Epoch:25/100(300) loss:4.927886009216309
# Epoch:29/100(350) loss:4.876858234405518
# Epoch:33/100(400) loss:4.877121925354004
# Epoch:37/100(450) loss:4.8586015701293945
# Epoch:41/100(500) loss:4.851805686950684
# Epoch:45/100(550) loss:4.883217811584473
# Epoch:50/100(600) loss:4.852745056152344
# Epoch:54/100(650) loss:4.834846019744873
# Epoch:58/100(700) loss:4.8247809410095215
# Epoch:62/100(750) loss:4.839101314544678
# Epoch:66/100(800) loss:4.83244514465332
# Epoch:70/100(850) loss:4.803287506103516
# Epoch:75/100(900) loss:4.821706771850586
# Epoch:79/100(950) loss:4.851871490478516
# Epoch:83/100(1000) loss:4.796667098999023
# Epoch:87/100(1050) loss:4.756680011749268
# Epoch:91/100(1100) loss:4.863598823547363
# Epoch:95/100(1150) loss:4.821498394012451
# =================  Clustering 1/2  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  74 tasks      | elapsed:    3.6s
# [Parallel(n_jobs=4)]: Done 2188 tasks      | elapsed:   10.2s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:   12.2s finished
# /home/syamagami/codes/re_gda/domain_estimation_ssl/dataset.py:107: FutureWarning: The input object of type 'Image' is an array-like implementing one of the corresponding protocols (`__array__`, `__array_interface__` or `__array_struct__`); but not a sequence (or 0-D). In the future, this object will be coerced as if it was first converted using `np.array(obj)`. To retain the old behaviour, you have to either modify the type 'Image', or assign to an empty array created with `np.empty(correct_shape, dtype=object)`.
#   self.imgs = np.array([t[1] for t in self.processed])
# /home/syamagami/codes/re_gda/domain_estimation_ssl/dataset.py:107: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   self.imgs = np.array([t[1] for t in self.processed])
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  76 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=4)]: Done 498 out of 498 | elapsed:    8.3s finished
# /home/syamagami/codes/re_gda/domain_estimation_ssl/dataset.py:107: FutureWarning: The input object of type 'Image' is an array-like implementing one of the corresponding protocols (`__array__`, `__array_interface__` or `__array_struct__`); but not a sequence (or 0-D). In the future, this object will be coerced as if it was first converted using `np.array(obj)`. To retain the old behaviour, you have to either modify the type 'Image', or assign to an empty array created with `np.empty(correct_shape, dtype=object)`.
#   self.imgs = np.array([t[1] for t in self.processed])
# /home/syamagami/codes/re_gda/domain_estimation_ssl/dataset.py:107: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   self.imgs = np.array([t[1] for t in self.processed])
#   -----  Load Model from record/Office31/CUDA2/ad_encoder__0 for clustering  -----
# nmi:0.39082144683342673
# nmi class:0.17455249562165645
# domain_accuracy:0.8343891402714932
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 200 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=4)]: Done 2328 tasks      | elapsed:    8.0s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    9.5s finished
# /home/syamagami/codes/re_gda/domain_estimation_ssl/dataset.py:107: FutureWarning: The input object of type 'Image' is an array-like implementing one of the corresponding protocols (`__array__`, `__array_interface__` or `__array_struct__`); but not a sequence (or 0-D). In the future, this object will be coerced as if it was first converted using `np.array(obj)`. To retain the old behaviour, you have to either modify the type 'Image', or assign to an empty array created with `np.empty(correct_shape, dtype=object)`.
#   self.imgs = np.array([t[1] for t in self.processed])
# /home/syamagami/codes/re_gda/domain_estimation_ssl/dataset.py:107: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   self.imgs = np.array([t[1] for t in self.processed])
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 128 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=4)]: Done 498 out of 498 | elapsed:    9.1s finished
# /home/syamagami/codes/re_gda/domain_estimation_ssl/dataset.py:107: FutureWarning: The input object of type 'Image' is an array-like implementing one of the corresponding protocols (`__array__`, `__array_interface__` or `__array_struct__`); but not a sequence (or 0-D). In the future, this object will be coerced as if it was first converted using `np.array(obj)`. To retain the old behaviour, you have to either modify the type 'Image', or assign to an empty array created with `np.empty(correct_shape, dtype=object)`.
#   self.imgs = np.array([t[1] for t in self.processed])
# /home/syamagami/codes/re_gda/domain_estimation_ssl/dataset.py:107: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   self.imgs = np.array([t[1] for t in self.processed])
#   -----  Load Model from record/Office31/CUDA2/ad_encoder__0 for clustering  -----
# nmi:0.8446474893144994
# nmi class:0.16907110412261503
# domain_accuracy:0.9834087481146304
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    8.8s finished
# /home/syamagami/codes/re_gda/domain_estimation_ssl/dataset.py:107: FutureWarning: The input object of type 'Image' is an array-like implementing one of the corresponding protocols (`__array__`, `__array_interface__` or `__array_struct__`); but not a sequence (or 0-D). In the future, this object will be coerced as if it was first converted using `np.array(obj)`. To retain the old behaviour, you have to either modify the type 'Image', or assign to an empty array created with `np.empty(correct_shape, dtype=object)`.
#   self.imgs = np.array([t[1] for t in self.processed])
# /home/syamagami/codes/re_gda/domain_estimation_ssl/dataset.py:107: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   self.imgs = np.array([t[1] for t in self.processed])
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 128 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=4)]: Done 498 out of 498 | elapsed:    8.6s finished
# /home/syamagami/codes/re_gda/domain_estimation_ssl/dataset.py:107: FutureWarning: The input object of type 'Image' is an array-like implementing one of the corresponding protocols (`__array__`, `__array_interface__` or `__array_struct__`); but not a sequence (or 0-D). In the future, this object will be coerced as if it was first converted using `np.array(obj)`. To retain the old behaviour, you have to either modify the type 'Image', or assign to an empty array created with `np.empty(correct_shape, dtype=object)`.
#   self.imgs = np.array([t[1] for t in self.processed])
# /home/syamagami/codes/re_gda/domain_estimation_ssl/dataset.py:107: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   self.imgs = np.array([t[1] for t in self.processed])
#   -----  Load Model from record/Office31/CUDA2/ad_encoder__0 for clustering  -----
# nmi:0.3372073616965284
# nmi class:0.1691035204045449
# domain_accuracy:0.7948717948717948
# ===============================================
# ==============  amazon_dslr  ==============
# ===============================================
# Please install apex for mixed precision training from: https://github.com/NVIDIA/apex
#     ---------------------------------------------------------
#         cuda_dir: 2
#         batch_size: 256,  epochs: 100
#         SSL: simclr,  base_model: encoder
#         jigsaw: True,  fourier: True,  grid: 3
#         num_laps: 2,
#         log_dir: record/Office31/CUDA2/ad_encoder__1
#     ---------------------------------------------------------
#
#
# =================  1/2周目  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  68 tasks      | elapsed:    3.2s
# [Parallel(n_jobs=4)]: Done 2810 out of 2817 | elapsed:   10.6s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:   10.6s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  76 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=4)]: Done 498 out of 498 | elapsed:    7.5s finished
# Running on: cuda
# Epoch:0/100(0) loss:5.489745140075684
# Epoch:4/100(50) loss:5.021245956420898
# Epoch:8/100(100) loss:4.936272144317627
# Epoch:12/100(150) loss:4.964081287384033
# Epoch:16/100(200) loss:4.940939426422119
# Epoch:20/100(250) loss:4.8739824295043945
# Epoch:25/100(300) loss:4.946474075317383
# Epoch:29/100(350) loss:4.863427639007568
# Epoch:33/100(400) loss:4.856072902679443
# Epoch:37/100(450) loss:4.888338088989258
# Epoch:41/100(500) loss:4.87955904006958
# Epoch:45/100(550) loss:4.887824535369873
# Epoch:50/100(600) loss:4.865334510803223
# Epoch:54/100(650) loss:4.836770057678223
# Epoch:58/100(700) loss:4.847545623779297
# Epoch:62/100(750) loss:4.841787338256836
# Epoch:66/100(800) loss:4.790957450866699
# Epoch:70/100(850) loss:4.8297953605651855
# Epoch:75/100(900) loss:4.834646701812744
# Epoch:79/100(950) loss:4.814910411834717
# Epoch:83/100(1000) loss:4.810352325439453
# Epoch:87/100(1050) loss:4.778966903686523
# Epoch:91/100(1100) loss:4.843231201171875
# Epoch:95/100(1150) loss:4.826642036437988
# =================  Clustering 1/2  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  71 tasks      | elapsed:    4.0s
# [Parallel(n_jobs=4)]: Done 2769 tasks      | elapsed:   11.4s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:   11.4s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 128 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=4)]: Done 498 out of 498 | elapsed:    6.6s finished
#   -----  Load Model from record/Office31/CUDA2/ad_encoder__1 for clustering  -----
# nmi:0.3210620547951183
# nmi class:0.17463210138930965
# domain_accuracy:0.7897435897435897
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=4)]: Done 2680 tasks      | elapsed:    7.2s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    7.5s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  80 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=4)]: Done 498 out of 498 | elapsed:    6.8s finished
#   -----  Load Model from record/Office31/CUDA2/ad_encoder__1 for clustering  -----
# nmi:0.7257789292889795
# nmi class:0.17430568853949163
# domain_accuracy:0.9622926093514329
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=4)]: Done 2680 tasks      | elapsed:    6.6s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    7.0s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 128 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=4)]: Done 498 out of 498 | elapsed:    7.0s finished
#   -----  Load Model from record/Office31/CUDA2/ad_encoder__1 for clustering  -----
# nmi:0.2310207814335358
# nmi class:0.17652491568237236
# domain_accuracy:0.6805429864253394
# ===============================================
# ==============  amazon_dslr  ==============
# ===============================================
# Please install apex for mixed precision training from: https://github.com/NVIDIA/apex
#     ---------------------------------------------------------
#         cuda_dir: 2
#         batch_size: 256,  epochs: 100
#         SSL: simclr,  base_model: encoder
#         jigsaw: True,  fourier: True,  grid: 3
#         num_laps: 2,
#         log_dir: record/Office31/CUDA2/ad_encoder__2
#     ---------------------------------------------------------
#
#
# =================  1/2周目  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  68 tasks      | elapsed:    3.3s
# [Parallel(n_jobs=4)]: Done 2810 out of 2817 | elapsed:   10.5s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:   10.6s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 128 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=4)]: Done 491 out of 498 | elapsed:    7.0s remaining:    0.1s
# [Parallel(n_jobs=4)]: Done 498 out of 498 | elapsed:    7.0s finished
# Running on: cuda
# Epoch:0/100(0) loss:5.485309600830078
# Epoch:4/100(50) loss:5.011891841888428
# Epoch:8/100(100) loss:4.950704097747803
# Epoch:12/100(150) loss:4.935633659362793
# Epoch:16/100(200) loss:4.918840408325195
# Epoch:20/100(250) loss:4.930307388305664
# Epoch:25/100(300) loss:4.959753036499023
# Epoch:29/100(350) loss:4.881782531738281
# Epoch:33/100(400) loss:4.880971431732178
# Epoch:37/100(450) loss:4.870571136474609
# Epoch:41/100(500) loss:4.844043254852295
# Epoch:45/100(550) loss:4.872071743011475
# Epoch:50/100(600) loss:4.842733383178711
# Epoch:54/100(650) loss:4.828187465667725
# Epoch:58/100(700) loss:4.832385540008545
# Epoch:62/100(750) loss:4.8005876541137695
# Epoch:66/100(800) loss:4.825649738311768
# Epoch:70/100(850) loss:4.775166988372803
# Epoch:75/100(900) loss:4.842784404754639
# Epoch:79/100(950) loss:4.8327860832214355
# Epoch:83/100(1000) loss:4.800510406494141
# Epoch:87/100(1050) loss:4.780105113983154
# Epoch:91/100(1100) loss:4.848139762878418
# Epoch:95/100(1150) loss:4.795873641967773
# =================  Clustering 1/2  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  71 tasks      | elapsed:    4.0s
# [Parallel(n_jobs=4)]: Done 2380 tasks      | elapsed:   10.6s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:   11.9s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  76 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=4)]: Done 376 tasks      | elapsed:    6.4s
# [Parallel(n_jobs=4)]: Done 498 out of 498 | elapsed:    8.9s finished
#   -----  Load Model from record/Office31/CUDA2/ad_encoder__2 for clustering  -----
# nmi:0.8345086105176486
# nmi class:0.17429354773978342
# domain_accuracy:0.9819004524886877
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=4)]: Done 2680 tasks      | elapsed:    7.9s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    8.2s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 128 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=4)]: Done 498 out of 498 | elapsed:    8.9s finished
#   -----  Load Model from record/Office31/CUDA2/ad_encoder__2 for clustering  -----
# nmi:0.8349343867231059
# nmi class:0.17439709528638
# domain_accuracy:0.9825037707390648
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    8.3s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  76 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=4)]: Done 498 out of 498 | elapsed:    8.0s finished
#   -----  Load Model from record/Office31/CUDA2/ad_encoder__2 for clustering  -----
# nmi:0.8405509622689872
# nmi class:0.1667996523047264
# domain_accuracy:0.9828054298642533
# ===============================================
# ==============  webcam_amazon  ==============
# ===============================================
# Please install apex for mixed precision training from: https://github.com/NVIDIA/apex
#     ---------------------------------------------------------
#         cuda_dir: 2
#         batch_size: 256,  epochs: 100
#         SSL: simclr,  base_model: encoder
#         jigsaw: True,  fourier: True,  grid: 3
#         num_laps: 2,
#         log_dir: record/Office31/CUDA2/wa_encoder__3
#     ---------------------------------------------------------
#
#
# =================  1/2周目  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  56 tasks      | elapsed:    3.8s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    7.5s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=4)]: Done 2680 tasks      | elapsed:    9.2s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    9.6s finished
# Running on: cuda
# Epoch:0/100(0) loss:5.431682109832764
# Epoch:3/100(50) loss:5.029874324798584
# Epoch:7/100(100) loss:5.041907787322998
# Epoch:10/100(150) loss:4.972368240356445
# Epoch:14/100(200) loss:4.985738277435303
# Epoch:17/100(250) loss:4.90057897567749
# Epoch:21/100(300) loss:4.843287944793701
# Epoch:25/100(350) loss:4.916532039642334
# Epoch:28/100(400) loss:4.854368209838867
# Epoch:32/100(450) loss:4.864091873168945
# Epoch:35/100(500) loss:4.862205505371094
# Epoch:39/100(550) loss:4.867973804473877
# Epoch:42/100(600) loss:4.812793254852295
# Epoch:46/100(650) loss:4.878732681274414
# Epoch:50/100(700) loss:4.818990230560303
# Epoch:53/100(750) loss:4.818349838256836
# Epoch:57/100(800) loss:4.805613994598389
# Epoch:60/100(850) loss:4.820324897766113
# Epoch:64/100(900) loss:4.919210433959961
# Epoch:67/100(950) loss:4.811279773712158
# Epoch:71/100(1000) loss:4.793639659881592
# Epoch:75/100(1050) loss:4.800232887268066
# Epoch:78/100(1100) loss:4.772303104400635
# Epoch:82/100(1150) loss:4.790805339813232
# Epoch:85/100(1200) loss:4.785262107849121
# Epoch:89/100(1250) loss:4.772879123687744
# Epoch:92/100(1300) loss:4.788598537445068
# Epoch:96/100(1350) loss:4.783273696899414
# =================  Clustering 1/2  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  56 tasks      | elapsed:    4.1s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    8.6s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 200 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=4)]: Done 2424 tasks      | elapsed:    8.2s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    9.5s finished
#   -----  Load Model from record/Office31/CUDA2/wa_encoder__3 for clustering  -----
# nmi:0.23072131194571316
# nmi class:0.17627985381440595
# domain_accuracy:0.7464008859357697
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    4.3s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=4)]: Done 2680 tasks      | elapsed:    8.3s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    8.8s finished
#   -----  Load Model from record/Office31/CUDA2/wa_encoder__3 for clustering  -----
# nmi:0.23386811135336216
# nmi class:0.18365262051250805
# domain_accuracy:0.7477851605758582
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 200 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    4.1s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 248 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=4)]: Done 2810 out of 2817 | elapsed:    7.4s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    7.4s finished
#   -----  Load Model from record/Office31/CUDA2/wa_encoder__3 for clustering  -----
# nmi:0.23591488694334586
# nmi class:0.17885737445472502
# domain_accuracy:0.748062015503876
# ===============================================
# ==============  webcam_amazon  ==============
# ===============================================
# Please install apex for mixed precision training from: https://github.com/NVIDIA/apex
#     ---------------------------------------------------------
#         cuda_dir: 2
#         batch_size: 256,  epochs: 100
#         SSL: simclr,  base_model: encoder
#         jigsaw: True,  fourier: True,  grid: 3
#         num_laps: 2,
#         log_dir: record/Office31/CUDA2/wa_encoder__4
#     ---------------------------------------------------------
#
#
# =================  1/2周目  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  56 tasks      | elapsed:    3.9s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    8.3s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=4)]: Done 2680 tasks      | elapsed:    7.8s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    8.1s finished
# Running on: cuda
# Epoch:0/100(0) loss:5.478133201599121
# Epoch:3/100(50) loss:5.035864353179932
# Epoch:7/100(100) loss:5.0327606201171875
# Epoch:10/100(150) loss:4.956471920013428
# Epoch:14/100(200) loss:4.904144763946533
# Epoch:17/100(250) loss:4.890057563781738
# Epoch:21/100(300) loss:4.846702575683594
# Epoch:25/100(350) loss:4.899109363555908
# Epoch:28/100(400) loss:4.931275367736816
# Epoch:32/100(450) loss:4.896276950836182
# Epoch:35/100(500) loss:4.934434413909912
# Epoch:39/100(550) loss:4.84114933013916
# Epoch:42/100(600) loss:4.83437967300415
# Epoch:46/100(650) loss:4.884980201721191
# Epoch:50/100(700) loss:4.834901332855225
# Epoch:53/100(750) loss:4.808403968811035
# Epoch:57/100(800) loss:4.825549602508545
# Epoch:60/100(850) loss:4.83498477935791
# Epoch:64/100(900) loss:4.869518280029297
# Epoch:67/100(950) loss:4.834619998931885
# Epoch:71/100(1000) loss:4.78902530670166
# Epoch:75/100(1050) loss:4.837739944458008
# Epoch:78/100(1100) loss:4.797994136810303
# Epoch:82/100(1150) loss:4.849961280822754
# Epoch:85/100(1200) loss:4.810998916625977
# Epoch:89/100(1250) loss:4.785454750061035
# Epoch:92/100(1300) loss:4.79704475402832
# Epoch:96/100(1350) loss:4.787481307983398
# =================  Clustering 1/2  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    4.4s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    8.4s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=4)]: Done 2680 tasks      | elapsed:    9.5s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:   10.2s finished
#   -----  Load Model from record/Office31/CUDA2/wa_encoder__4 for clustering  -----
# nmi:0.3552597088333463
# nmi class:0.1733144252781225
# domain_accuracy:0.7931893687707641
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 136 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    5.0s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=4)]: Done 2680 tasks      | elapsed:    8.8s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    9.2s finished
#   -----  Load Model from record/Office31/CUDA2/wa_encoder__4 for clustering  -----
# nmi:0.34884950417592586
# nmi class:0.17520894950053004
# domain_accuracy:0.7868217054263565
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 200 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    5.0s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=4)]: Done 2680 tasks      | elapsed:    9.8s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:   10.3s finished
#   -----  Load Model from record/Office31/CUDA2/wa_encoder__4 for clustering  -----
# nmi:0.3547640227941114
# nmi class:0.17322593364144778
# domain_accuracy:0.787375415282392
# ===============================================
# ==============  webcam_amazon  ==============
# ===============================================
# Please install apex for mixed precision training from: https://github.com/NVIDIA/apex
#     ---------------------------------------------------------
#         cuda_dir: 2
#         batch_size: 256,  epochs: 100
#         SSL: simclr,  base_model: encoder
#         jigsaw: True,  fourier: True,  grid: 3
#         num_laps: 2,
#         log_dir: record/Office31/CUDA2/wa_encoder__5
#     ---------------------------------------------------------
#
#
# =================  1/2周目  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  56 tasks      | elapsed:    4.2s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    8.6s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 200 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=4)]: Done 2328 tasks      | elapsed:    8.4s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:   10.0s finished
# Running on: cuda
# Epoch:0/100(0) loss:5.512444972991943
# Epoch:3/100(50) loss:5.010871410369873
# Epoch:7/100(100) loss:4.993106842041016
# Epoch:10/100(150) loss:4.988894462585449
# Epoch:14/100(200) loss:4.90777587890625
# Epoch:17/100(250) loss:4.8872151374816895
# Epoch:21/100(300) loss:4.875795364379883
# Epoch:25/100(350) loss:4.8672194480896
# Epoch:28/100(400) loss:4.912830829620361
# Epoch:32/100(450) loss:4.883930683135986
# Epoch:35/100(500) loss:4.904491424560547
# Epoch:39/100(550) loss:4.857736587524414
# Epoch:42/100(600) loss:4.81813383102417
# Epoch:46/100(650) loss:4.887300968170166
# Epoch:50/100(700) loss:4.8534722328186035
# Epoch:53/100(750) loss:4.820641994476318
# Epoch:57/100(800) loss:4.834439277648926
# Epoch:60/100(850) loss:4.852734088897705
# Epoch:64/100(900) loss:4.863786220550537
# Epoch:67/100(950) loss:4.810886859893799
# Epoch:71/100(1000) loss:4.809642791748047
# Epoch:75/100(1050) loss:4.832424640655518
# Epoch:78/100(1100) loss:4.841305255889893
# Epoch:82/100(1150) loss:4.778951644897461
# Epoch:85/100(1200) loss:4.790261268615723
# Epoch:89/100(1250) loss:4.815112590789795
# Epoch:92/100(1300) loss:4.7901225090026855
# Epoch:96/100(1350) loss:4.810888290405273
# =================  Clustering 1/2  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  56 tasks      | elapsed:    4.4s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    8.5s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=4)]: Done 2680 tasks      | elapsed:    8.7s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    9.1s finished
#   -----  Load Model from record/Office31/CUDA2/wa_encoder__5 for clustering  -----
# nmi:0.366838171419937
# nmi class:0.17315042800274408
# domain_accuracy:0.7873754152823921
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 248 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    4.8s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=4)]: Done 2680 tasks      | elapsed:    9.5s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    9.8s finished
#   -----  Load Model from record/Office31/CUDA2/wa_encoder__5 for clustering  -----
# nmi:0.2785351832208633
# nmi class:0.17704783168955818
# domain_accuracy:0.7403100775193798
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 200 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    4.4s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=4)]: Done 2680 tasks      | elapsed:    9.6s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    9.8s finished
#   -----  Load Model from record/Office31/CUDA2/wa_encoder__5 for clustering  -----
# nmi:0.3443408367018446
# nmi class:0.1782986234369922
# domain_accuracy:0.7724252491694352
# CPU times: user 27.8 s, sys: 2.85 s, total: 30.6 s
# Wall time: 1h 14min 1s

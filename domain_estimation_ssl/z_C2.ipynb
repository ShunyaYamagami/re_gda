# %%
# %reset -f
# !rm -fr __pycache__
# !rm -fr */__pycache__

# %% [markdown]
# # Domain Estimation

# %%
from z_common import *

# ファイル特有変数
CUDA_DIR = 2
N_CUDA = 2
spread_message = LOG_TEXT

# %%
# %%time
# PARENT = 'Digit'
# DATA_DOMAIN_LIST = [
#   'svhn_mnist',
#   'svhn_synth',
#   'svhn_synth_mnist',
#   'svhn_synth_mnist_mnistm',
# ]
PARENT = 'Office31'
DATA_DOMAIN_LIST = [
  # 'amazon_dslr_webcam',
  # 'dslr_webcam',
  'amazon_dslr',
  # 'webcam_amazon',
]


LAP = 1
NUM_LAPS = 1
log_dir_opt = ''
# log_dir_opt += '__record'


for DATA_DOMAIN in DATA_DOMAIN_LIST:
  config, CONFIG_FILE, log_dir = config_to_execute(DATA_DOMAIN, PARENT, CUDA_DIR, log_dir_opt)

  # !rm -fr */__pycache__
  # !CUDA_VISIBLE_DEVICES=$N_CUDA python3 -B run.py --config=$CONFIG_FILE  --log_dir=$log_dir  --num_laps=$NUM_LAPS  --spread_message=$spread_message
# Out:
# ===============================================
# ==============  amazon_dslr  ==============
# ===============================================
# Please install apex for mixed precision training from: https://github.com/NVIDIA/apex
#       ---------------------------------------------------------
#                 batch_size: 256,  epochs: 150
#                 SSL: simclr,  base_model: encoder
#                 jigsaw: True,  fourier: False,  grid: 3
#                 num_laps: 1
#         ---------------------------------------------------------
#
# =================  1/1周目  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  88 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=4)]: Done 2810 out of 2817 | elapsed:    7.6s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    7.7s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 184 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=4)]: Done 498 out of 498 | elapsed:    4.8s finished
# Running on: cuda
# Epoch:0/150(0) loss:5.503409385681152
# Epoch:4/150(50) loss:4.970980167388916
# Epoch:8/150(100) loss:4.869233131408691
# Epoch:12/150(150) loss:4.8385443687438965
# Epoch:16/150(200) loss:4.829795837402344
# Epoch:20/150(250) loss:4.834584712982178
# Epoch:25/150(300) loss:4.845390319824219
# Epoch:29/150(350) loss:4.764100551605225
# Epoch:33/150(400) loss:4.780879020690918
# Epoch:37/150(450) loss:4.766971588134766
# Epoch:41/150(500) loss:4.795457363128662
# Epoch:45/150(550) loss:4.78531551361084
# Epoch:50/150(600) loss:4.7866902351379395
# Epoch:54/150(650) loss:4.751853942871094
# Epoch:58/150(700) loss:4.756825923919678
# Epoch:62/150(750) loss:4.764523029327393
# Epoch:66/150(800) loss:4.751483917236328
# Epoch:70/150(850) loss:4.74758243560791
# Epoch:75/150(900) loss:4.7698259353637695
# Epoch:79/150(950) loss:4.69364595413208
# Epoch:83/150(1000) loss:4.7360615730285645
# Epoch:87/150(1050) loss:4.729799270629883
# Epoch:91/150(1100) loss:4.734809398651123

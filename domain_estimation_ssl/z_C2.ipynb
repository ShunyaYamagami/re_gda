# %%
# %reset -f
# !rm -fr __pycache__
# !rm -fr */__pycache__

# %% [markdown]
# # Domain Estimation

# %%
from z_common import *
import sys
sys.dont_write_bytecode = True  # pycacheを作らないようにする

# ファイル特有変数
CUDA_DIR = 2
N_CUDA = 2
spread_message = LOG_TEXT

# %%
# %%time
# PARENT = 'Digit'
# DATA_DOMAIN_LIST = [
#   'svhn_mnist',
#   'svhn_synth',
#   'svhn_synth_mnist',
#   'svhn_synth_mnist_mnistm',
# ]
PARENT = 'Office31'
DATA_DOMAIN_LIST = [
  # 'amazon_dslr_webcam',
  'dslr_webcam',
  # 'amazon_dslr',
  # 'webcam_amazon',
]


LAP = 1
NUM_LAPS = 2
log_dir_opt = ''
# log_dir_opt += '__record'


for DATA_DOMAIN in DATA_DOMAIN_LIST:
  config, CONFIG_FILE, log_dir = config_to_execute(DATA_DOMAIN, PARENT, CUDA_DIR, log_dir_opt)

  # !rm -fr */__pycache__
  # !CUDA_VISIBLE_DEVICES=$N_CUDA python3 -B run.py --config=$CONFIG_FILE  --log_dir=$log_dir  --num_laps=$NUM_LAPS  --spread_message=$spread_message
# Out:
# ===============================================
# ==============  amazon_dslr  ==============
# ===============================================
# Please install apex for mixed precision training from: https://github.com/NVIDIA/apex
#     ---------------------------------------------------------
#             batch_size: 256,  epochs: 100
#             SSL: simsiam,  base_model: encoder
#             jigsaw: True,  fourier: True,  grid: 3
#             num_laps: 2
#     ---------------------------------------------------------
# =================  1周目  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=4)]: Done 328 tasks      | elapsed:    9.4s
# [Parallel(n_jobs=4)]: Done 828 tasks      | elapsed:   22.3s
# [Parallel(n_jobs=4)]: Done 1528 tasks      | elapsed:   43.7s
# [Parallel(n_jobs=4)]: Done 2428 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=4)]: Done 2810 out of 2817 | elapsed:  1.3min remaining:    0.2s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:  1.3min finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  76 tasks      | elapsed:    2.9s
# [Parallel(n_jobs=4)]: Done 376 tasks      | elapsed:   12.0s
# [Parallel(n_jobs=4)]: Done 498 out of 498 | elapsed:   15.8s finished
# Running on: cuda
# Epoch:0/100(0) loss:-0.016285743564367294
# Epoch:4/100(50) loss:-0.8217315673828125
# Epoch:8/100(100) loss:-0.8804062604904175
# Epoch:12/100(150) loss:-0.9033569097518921
# Epoch:16/100(200) loss:-0.8522800207138062
# Epoch:20/100(250) loss:-0.8829149007797241
# Epoch:25/100(300) loss:-0.8735467195510864
# Epoch:29/100(350) loss:-0.8135977983474731
# Epoch:33/100(400) loss:-0.8774482011795044
# Epoch:37/100(450) loss:-0.8615612983703613
# Epoch:41/100(500) loss:-0.8557506799697876
# Epoch:45/100(550) loss:-0.8615626096725464
# Epoch:50/100(600) loss:-0.8878656625747681
# Epoch:54/100(650) loss:-0.8942594528198242
# Epoch:58/100(700) loss:-0.8818923234939575
# Epoch:62/100(750) loss:-0.8585622310638428
# Epoch:66/100(800) loss:-0.8659851551055908
# Epoch:70/100(850) loss:-0.8389342427253723
# Epoch:75/100(900) loss:-0.7950263619422913
# Epoch:79/100(950) loss:-0.8842114210128784
# Epoch:83/100(1000) loss:-0.8703420162200928
# Epoch:87/100(1050) loss:-0.8735154867172241
# Epoch:91/100(1100) loss:-0.8432152271270752
# Epoch:95/100(1150) loss:-0.8832491636276245
# =================  Clustering 1  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  76 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=4)]: Done 376 tasks      | elapsed:   10.9s
# [Parallel(n_jobs=4)]: Done 876 tasks      | elapsed:   24.0s
# [Parallel(n_jobs=4)]: Done 1576 tasks      | elapsed:   42.6s
# [Parallel(n_jobs=4)]: Done 2476 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=4)]: Done 2810 out of 2817 | elapsed:  1.3min remaining:    0.2s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:  1.3min finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  76 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=4)]: Done 376 tasks      | elapsed:   12.8s
# [Parallel(n_jobs=4)]: Done 498 out of 498 | elapsed:   16.7s finished
#   -----  Load Model from record/Office31/CUDA2/ad_encoder for clustering  -----
#     -----  Load NMI File from record/Office31/CUDA2/ad_encoder  -----
# nmi:0.15790655201253476
# nmi class:0.1519096395425636
# =================  2周目  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  76 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=4)]: Done 376 tasks      | elapsed:   10.4s
# [Parallel(n_jobs=4)]: Done 876 tasks      | elapsed:   21.7s
# [Parallel(n_jobs=4)]: Done 1576 tasks      | elapsed:   40.2s
# [Parallel(n_jobs=4)]: Done 2476 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=4)]: Done 2810 out of 2817 | elapsed:  1.2min remaining:    0.2s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:  1.2min finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  76 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=4)]: Done 376 tasks      | elapsed:   10.9s
# [Parallel(n_jobs=4)]: Done 498 out of 498 | elapsed:   14.3s finished
# Running on: cuda
#   ----- Loaded pre-trained model from record/Office31/CUDA2/ad_encoder for SSL  -----
# Epoch:0/100(0) loss:-0.8554301261901855
# Epoch:4/100(50) loss:-0.8119485378265381
# Epoch:8/100(100) loss:-0.8763415217399597
# Epoch:12/100(150) loss:-0.8258510828018188
# Epoch:16/100(200) loss:-0.877311646938324
# Epoch:20/100(250) loss:-0.8125851154327393
# Epoch:25/100(300) loss:-0.8689072132110596
# Epoch:29/100(350) loss:-0.8541160821914673
# Epoch:33/100(400) loss:-0.8478659391403198
# Epoch:37/100(450) loss:-0.8852492570877075
# Epoch:41/100(500) loss:-0.8684571385383606
# Epoch:45/100(550) loss:-0.8505786657333374
# Epoch:50/100(600) loss:-0.8731954097747803
# Epoch:54/100(650) loss:-0.8786742687225342
# Epoch:58/100(700) loss:-0.8411856293678284
# Epoch:62/100(750) loss:-0.8878145217895508
# Epoch:66/100(800) loss:-0.855867862701416
# Epoch:70/100(850) loss:-0.879287600517273
# Epoch:75/100(900) loss:-0.8916773796081543
# Epoch:79/100(950) loss:-0.866836428642273
# Epoch:83/100(1000) loss:-0.878248393535614
# Epoch:87/100(1050) loss:-0.8596707582473755
# Epoch:91/100(1100) loss:-0.8640038371086121
# Epoch:95/100(1150) loss:-0.8525547981262207
# =================  Clustering 2  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  76 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=4)]: Done 376 tasks      | elapsed:    9.7s
# [Parallel(n_jobs=4)]: Done 876 tasks      | elapsed:   22.2s
# [Parallel(n_jobs=4)]: Done 1576 tasks      | elapsed:   40.1s
# [Parallel(n_jobs=4)]: Done 2476 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=4)]: Done 2810 out of 2817 | elapsed:  1.3min remaining:    0.2s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:  1.3min finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  76 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=4)]: Done 376 tasks      | elapsed:    9.6s
# [Parallel(n_jobs=4)]: Done 498 out of 498 | elapsed:   12.8s finished
#   -----  Load Model from record/Office31/CUDA2/ad_encoder__2 for clustering  -----
#     -----  Load NMI File from record/Office31/CUDA2/ad_encoder__2  -----
# nmi:0.2022778011938508
# nmi class:0.1507352788817128
# record/Office31/CUDA2/ad_encoder__2
# CPU times: user 4.83 s, sys: 566 ms, total: 5.4 s
# Wall time: 12min 31s

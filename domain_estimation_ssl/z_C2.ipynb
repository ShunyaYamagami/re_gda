# %%
# %reset -f
# !rm -fr __pycache__
# !rm -fr */__pycache__

# %% [markdown]
# # Domain Estimation

# %%
from z_common import *

# ファイル特有変数
CUDA_DIR = 2
N_CUDA = 2
spread_message = LOG_TEXT

# %%
# %%time
# PARENT = 'Digit'
# DATA_DOMAIN_LIST = [
#   'svhn_mnist',
#   'svhn_synth',
#   'svhn_synth_mnist',
#   'svhn_synth_mnist_mnistm',
# ]
PARENT = 'Office31'
DATA_DOMAIN_LIST = [
  # 'amazon_dslr_webcam',
  'dslr_webcam',
  # 'amazon_dslr',
  # 'webcam_amazon',
]


LAP = 1
NUM_LAPS = 3
log_dir_opt = ''
# log_dir_opt += '__record'


for DATA_DOMAIN in DATA_DOMAIN_LIST:
  config, CONFIG_FILE, log_dir = config_to_execute(DATA_DOMAIN, PARENT, CUDA_DIR, log_dir_opt)

  # !rm -fr */__pycache__
  # !CUDA_VISIBLE_DEVICES=$N_CUDA python3 -B run.py --config=$CONFIG_FILE  --log_dir=$log_dir  --num_laps=$NUM_LAPS  --spread_message=$spread_message
# Out:
# ===============================================
# ==============  dslr_webcam  ==============
# ===============================================
# Please install apex for mixed precision training from: https://github.com/NVIDIA/apex
#     ---------------------------------------------------------
#         batch_size: 256,  epochs: 100
#         SSL: simclr,  base_model: encoder
#         jigsaw: True,  fourier: False,  grid: 3
#         num_laps: 3
#     ---------------------------------------------------------
#
# =================  2/3周目  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  56 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=4)]: Done 498 out of 498 | elapsed:    7.7s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    3.0s finished
# Running on: cuda
#   ----- Loaded pre-trained model from record/Office31/CUDA2/dw_encoder for SSL  -----
# Epoch:0/100(0) loss:4.6006669998168945
# Epoch:10/100(50) loss:4.573192596435547
# Epoch:20/100(100) loss:4.5628662109375
# Epoch:30/100(150) loss:4.543569564819336
# Epoch:40/100(200) loss:4.556701183319092
# Epoch:50/100(250) loss:4.529560089111328
# Epoch:60/100(300) loss:4.56234884262085
# Epoch:70/100(350) loss:4.540729999542236
# Epoch:80/100(400) loss:4.5299506187438965
# Epoch:90/100(450) loss:4.510584831237793
# =================  Clustering 2/3  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 128 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=4)]: Done 498 out of 498 | elapsed:    5.0s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 200 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    3.1s finished
#   -----  Load Model from record/Office31/CUDA2/dw_encoder__2 for clustering  -----
#   -----  Load NMI File from record/Office31/CUDA2/dw_encoder__2  -----
# nmi:0.5489329238047743
# nmi class:0.3927816235354065
# =================  3/3周目  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 128 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=4)]: Done 498 out of 498 | elapsed:    5.2s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    2.8s finished
# Running on: cuda
#   ----- Loaded pre-trained model from record/Office31/CUDA2/dw_encoder__2 for SSL  -----
# Epoch:0/100(0) loss:4.518676280975342
# Epoch:10/100(50) loss:4.515992164611816
# Epoch:20/100(100) loss:4.5359039306640625
# Epoch:30/100(150) loss:4.522190093994141
# Epoch:40/100(200) loss:4.519026756286621
# Epoch:50/100(250) loss:4.5214524269104
# Epoch:60/100(300) loss:4.505365371704102
# Epoch:70/100(350) loss:4.5328049659729
# Epoch:80/100(400) loss:4.516723155975342
# Epoch:90/100(450) loss:4.495639801025391
# =================  Clustering 3/3  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 200 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=4)]: Done 498 out of 498 | elapsed:    2.5s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    1.9s finished
#   -----  Load Model from record/Office31/CUDA2/dw_encoder__2__3 for clustering  -----
#   -----  Load NMI File from record/Office31/CUDA2/dw_encoder__2__3  -----
# nmi:0.5953542008455085
# nmi class:0.4104478762783347
# CPU times: user 1.88 s, sys: 232 ms, total: 2.12 s
# Wall time: 5min 39s

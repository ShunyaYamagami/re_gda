# %%
# %reset -f
# !rm -fr __pycache__
# !rm -fr */__pycache__

# %% [markdown]
# # Domain Estimation

# %%
from z_common import *

# ファイル特有変数
CUDA_DIR = 2
N_CUDA = 2
spread_message = LOG_TEXT

# %%
# PARENT = 'Digit'
# DATA_DOMAIN_LIST = [
#   'svhn_mnist',
#   'svhn_synth',
#   'svhn_synth_mnist',
#   'svhn_synth_mnist_mnistm',
# ]
PARENT = 'Office31'
DATA_DOMAIN_LIST = [
  # 'amazon_dslr_webcam',
  # 'dslr_webcam',
  # 'amazon_dslr',
  'webcam_amazon',
  'webcam_amazon',
  'webcam_amazon',
]


LAP = 1
NUM_LAPS = 2
log_dir_opt = ''
# log_dir_opt += '__record'
# log_dir_opt += '__douse'


for DATA_DOMAIN in DATA_DOMAIN_LIST:
  config, CONFIG_FILE, log_dir = config_to_execute(DATA_DOMAIN, PARENT, CUDA_DIR, log_dir_opt)

  # !rm -fr */__pycache__
  # !CUDA_VISIBLE_DEVICES=$N_CUDA python3 -B run.py --config=$CONFIG_FILE  --log_dir=$log_dir  --num_laps=$NUM_LAPS  --spread_message=$spread_message  --cuda_dir=$CUDA_DIR
# Out:
# ===============================================
# ==============  webcam_amazon  ==============
# ===============================================
# Please install apex for mixed precision training from: https://github.com/NVIDIA/apex
#     ---------------------------------------------------------
#         cuda_dir: 2
#         batch_size: 256,  epochs: 100
#         SSL: simclr,  base_model: encoder
#         jigsaw: True,  fourier: True,  grid: 3
#         num_laps: 2,
#     ---------------------------------------------------------
#
#
# =================  1/2周目  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  68 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    6.2s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    7.3s finished
# Running on: cuda
# Epoch:0/100(0) loss:5.367345333099365
# Epoch:3/100(50) loss:4.886612892150879
# Epoch:7/100(100) loss:4.818603992462158
# Epoch:10/100(150) loss:4.775512218475342
# Epoch:14/100(200) loss:4.757197856903076
# Epoch:17/100(250) loss:4.7622761726379395
# Epoch:21/100(300) loss:4.770540237426758
# Epoch:25/100(350) loss:4.738418102264404
# Epoch:28/100(400) loss:4.739021301269531
# Epoch:32/100(450) loss:4.7994065284729
# Epoch:35/100(500) loss:4.737105846405029
# Epoch:39/100(550) loss:4.713107109069824
# Epoch:42/100(600) loss:4.734071731567383
# Epoch:46/100(650) loss:4.720780372619629
# Epoch:50/100(700) loss:4.735002040863037
# Epoch:53/100(750) loss:4.7168755531311035
# Epoch:57/100(800) loss:4.728586673736572
# Epoch:60/100(850) loss:4.687735080718994
# Epoch:64/100(900) loss:4.71036434173584
# Epoch:67/100(950) loss:4.703418731689453
# Epoch:71/100(1000) loss:4.690591812133789
# Epoch:75/100(1050) loss:4.707158088684082
# Epoch:78/100(1100) loss:4.703700065612793
# Epoch:82/100(1150) loss:4.762772083282471
# Epoch:85/100(1200) loss:4.703802108764648
# Epoch:89/100(1250) loss:4.696171760559082
# Epoch:92/100(1300) loss:4.6500115394592285
# Epoch:96/100(1350) loss:4.693709850311279
# =================  Clustering 1/2  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  88 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    4.5s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    6.0s finished
#   -----  Load Model from record/Office31/CUDA2/wa_encoder for clustering  -----
# nmi:0.21643185048174135
# nmi class:0.23279622060719982
# domain_accuracy:0.3169988925802879
# class_accuracy:0.03239202657807309
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 216 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    2.9s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    5.8s finished
#   -----  Load Model from record/Office31/CUDA2/wa_encoder for clustering  -----
# nmi:0.21643185048174132
# nmi class:0.23740262787860694
# domain_accuracy:0.6830011074197121
# class_accuracy:0.0221483942414175
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    2.8s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    5.8s finished
#   -----  Load Model from record/Office31/CUDA2/wa_encoder for clustering  -----
# nmi:0.21297179155779017
# nmi class:0.229961329628096
# domain_accuracy:0.3183831672203765
# class_accuracy:0.021871539313399777
# ===============================================
# ==============  webcam_amazon  ==============
# ===============================================
# Please install apex for mixed precision training from: https://github.com/NVIDIA/apex
#     ---------------------------------------------------------
#         cuda_dir: 2
#         batch_size: 256,  epochs: 100
#         SSL: simclr,  base_model: encoder
#         jigsaw: True,  fourier: True,  grid: 3
#         num_laps: 2,
#     ---------------------------------------------------------
#
#
# =================  1/2周目  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  56 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    4.6s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=4)]: Done 2680 tasks      | elapsed:    5.6s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    5.9s finished
# Running on: cuda
# Epoch:0/100(0) loss:5.367345333099365
# Epoch:3/100(50) loss:4.886594772338867
# Epoch:7/100(100) loss:4.818047523498535
# Epoch:10/100(150) loss:4.7797417640686035
# Epoch:14/100(200) loss:4.7570929527282715
# Epoch:17/100(250) loss:4.765095233917236
# Epoch:21/100(300) loss:4.771500110626221
# Epoch:25/100(350) loss:4.737706661224365
# Epoch:28/100(400) loss:4.736550331115723
# Epoch:32/100(450) loss:4.7992119789123535
# Epoch:35/100(500) loss:4.736698627471924
# Epoch:39/100(550) loss:4.713506698608398
# Epoch:42/100(600) loss:4.732698440551758
# Epoch:46/100(650) loss:4.723766326904297
# Epoch:50/100(700) loss:4.736314296722412
# Epoch:53/100(750) loss:4.720688819885254
# Epoch:57/100(800) loss:4.730751991271973
# Epoch:60/100(850) loss:4.685892581939697
# Epoch:64/100(900) loss:4.7132086753845215
# Epoch:67/100(950) loss:4.704645156860352
# Epoch:71/100(1000) loss:4.691445350646973
# Epoch:75/100(1050) loss:4.7088751792907715
# Epoch:78/100(1100) loss:4.7042083740234375
# Epoch:82/100(1150) loss:4.773016452789307
# Epoch:85/100(1200) loss:4.699942111968994
# Epoch:89/100(1250) loss:4.692413330078125
# Epoch:92/100(1300) loss:4.652373313903809
# Epoch:96/100(1350) loss:4.691140651702881
# =================  Clustering 1/2  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  68 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    4.7s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=4)]: Done 2680 tasks      | elapsed:    6.2s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    6.4s finished
#   -----  Load Model from record/Office31/CUDA2/wa_encoder for clustering  -----
# nmi:0.21673284111675692
# nmi class:0.22856899997199615
# domain_accuracy:0.3017718715393134
# class_accuracy:0.031007751937984496
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    2.8s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    6.1s finished
#   -----  Load Model from record/Office31/CUDA2/wa_encoder for clustering  -----
# nmi:0.21673284111675692
# nmi class:0.23670978969357326
# domain_accuracy:0.6982281284606866
# class_accuracy:0.024916943521594685
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    2.8s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    6.1s finished
#   -----  Load Model from record/Office31/CUDA2/wa_encoder for clustering  -----
# nmi:0.21673284111675692
# nmi class:0.23187901753340942
# domain_accuracy:0.3017718715393134
# class_accuracy:0.02630121816168328
# ===============================================
# ==============  webcam_amazon  ==============
# ===============================================
# Please install apex for mixed precision training from: https://github.com/NVIDIA/apex
#     ---------------------------------------------------------
#         cuda_dir: 2
#         batch_size: 256,  epochs: 100
#         SSL: simclr,  base_model: encoder
#         jigsaw: True,  fourier: True,  grid: 3
#         num_laps: 2,
#     ---------------------------------------------------------
#
#
# =================  1/2周目  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  88 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    4.3s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    5.6s finished
# Running on: cuda
# Epoch:0/100(0) loss:5.367345333099365
# Epoch:3/100(50) loss:4.887060642242432
# Epoch:7/100(100) loss:4.818480491638184
# Epoch:10/100(150) loss:4.778229236602783
# Epoch:14/100(200) loss:4.759184837341309
# Epoch:17/100(250) loss:4.770543098449707
# Epoch:21/100(300) loss:4.774499416351318
# Epoch:25/100(350) loss:4.736879825592041
# Epoch:28/100(400) loss:4.73774528503418
# Epoch:32/100(450) loss:4.803550720214844
# Epoch:35/100(500) loss:4.737292766571045
# Epoch:39/100(550) loss:4.710540294647217
# Epoch:42/100(600) loss:4.731082916259766
# Epoch:46/100(650) loss:4.719175338745117
# Epoch:50/100(700) loss:4.73713493347168
# Epoch:53/100(750) loss:4.722039222717285
# Epoch:57/100(800) loss:4.731108665466309
# Epoch:60/100(850) loss:4.688140392303467
# Epoch:64/100(900) loss:4.710799694061279
# Epoch:67/100(950) loss:4.706953048706055
# Epoch:71/100(1000) loss:4.692350387573242
# Epoch:75/100(1050) loss:4.708804607391357
# Epoch:78/100(1100) loss:4.705635070800781
# Epoch:82/100(1150) loss:4.761599540710449
# Epoch:85/100(1200) loss:4.702849864959717
# Epoch:89/100(1250) loss:4.6928510665893555
# Epoch:92/100(1300) loss:4.657690048217773
# Epoch:96/100(1350) loss:4.691863536834717
# =================  Clustering 1/2  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  88 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    4.9s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    5.9s finished
#   -----  Load Model from record/Office31/CUDA2/wa_encoder for clustering  -----
# nmi:0.20438705232481322
# nmi class:0.23547423319228047
# domain_accuracy:0.6871539313399778
# class_accuracy:0.024916943521594685
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    2.5s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=4)]: Done 2680 tasks      | elapsed:    5.8s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    6.2s finished
#   -----  Load Model from record/Office31/CUDA2/wa_encoder for clustering  -----
# nmi:0.20438705232481322
# nmi class:0.23691830643442746
# domain_accuracy:0.3128460686600221
# class_accuracy:0.03045404208194906
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    2.6s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    5.8s finished
#   -----  Load Model from record/Office31/CUDA2/wa_encoder for clustering  -----
# nmi:0.20438705232481322
# nmi class:0.2376367342830907
# domain_accuracy:0.3128460686600221
# class_accuracy:0.026854928017718716

# %% [markdown]
# jigsaw + mask

# %%
# from clustering import run_clustering
# from dataset import get_datasets
# from simclr import SimCLR
# from log_functions import *
# config.config_path = CONFIG_FILE
# config.log_dir = log_dir
# config.num_laps = 2

# config.lap = 1
# dataset = get_datasets(config, 'train')
# simclr = SimCLR(dataset, config)
# simclr.train()
# run_clustering(config)

# config.lap = 2
# # config.edls = pd.read_csv(os.path.join(config.log_dir, 'cluster_pca_gmm.csv'), names=['domain_label'], dtype=int).domain_label.values
# # config.log_dir__old = config.log_dir  # simclrのdoes_load_modelだけのために設けた．
# # config.log_dir += f'__{config.lap}'

# # dataset = get_datasets(config, 'train')
# # simclr = SimCLR(dataset, config)
# # simclr.train(does_load_model=True)

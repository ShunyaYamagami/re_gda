# %%
# %reset -f
# !rm -fr __pycache__
# !rm -fr */__pycache__

# %% [markdown]
# # Domain Estimation

# %%
from z_common import *

# ファイル特有変数
CUDA_DIR = 2
N_CUDA = 2
spread_message = LOG_TEXT

# %%
# %%time
# PARENT = 'Digit'
# DATA_DOMAIN_LIST = [
#   'svhn_mnist',
#   'svhn_synth',
#   'svhn_synth_mnist',
#   'svhn_synth_mnist_mnistm',
# ]
PARENT = 'Office31'
DATA_DOMAIN_LIST = [
  # 'amazon_dslr_webcam',
  'dslr_webcam',
  # 'amazon_dslr',
  # 'webcam_amazon',
]


LAP = 1
NUM_LAPS = 2
log_dir_opt = ''
# log_dir_opt += '__record'
# log_dir_opt += '__douse'


for DATA_DOMAIN in DATA_DOMAIN_LIST:
  config, CONFIG_FILE, log_dir = config_to_execute(DATA_DOMAIN, PARENT, CUDA_DIR, log_dir_opt)

  # !rm -fr */__pycache__
  # !CUDA_VISIBLE_DEVICES=$N_CUDA python3 -B run.py --config=$CONFIG_FILE  --log_dir=$log_dir  --num_laps=$NUM_LAPS  --spread_message=$spread_message
# Out:
# ===============================================
# ==============  dslr_webcam  ==============
# ===============================================
# Please install apex for mixed precision training from: https://github.com/NVIDIA/apex
#     ---------------------------------------------------------
#         batch_size: 256,  epochs: 100
#         SSL: simclr,  base_model: encoder
#         jigsaw: True,  fourier: True,  grid: 3
#         num_laps: 2
#     ---------------------------------------------------------
#
#
# =================  1/2周目  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  68 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=4)]: Done 498 out of 498 | elapsed:    5.3s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    2.7s finished
# Running on: cuda
# Epoch:0/100(0) loss:5.311790943145752
# Epoch:10/100(50) loss:4.858824253082275
# Epoch:20/100(100) loss:4.8309006690979
# Epoch:30/100(150) loss:4.824542999267578
# Epoch:40/100(200) loss:4.773635387420654
# Epoch:50/100(250) loss:4.753168106079102
# Epoch:60/100(300) loss:4.763159275054932
# Epoch:70/100(350) loss:4.76377010345459
# Epoch:80/100(400) loss:4.7743239402771
# Epoch:90/100(450) loss:4.74696159362793
# =================  Clustering 1/2  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 128 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=4)]: Done 498 out of 498 | elapsed:    4.5s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    2.4s finished
#   -----  Load Model from record/Office31/CUDA2/dw_encoder for clustering  -----
#   -----  Load NMI File from record/Office31/CUDA2/dw_encoder  -----
# nmi:0.4222635917646908
# nmi class:0.3814059345444009
# =================  2/2周目  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  76 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=4)]: Done 376 tasks      | elapsed:   11.4s
# [Parallel(n_jobs=4)]: Done 498 out of 498 | elapsed:   14.9s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  76 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=4)]: Done 376 tasks      | elapsed:    9.2s
# [Parallel(n_jobs=4)]: Done 788 out of 795 | elapsed:   21.4s remaining:    0.2s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:   21.7s finished
# Running on: cuda
#   ----- Loaded pre-trained model from record/Office31/CUDA2/dw_encoder for SSL  -----
# Epoch:0/100(0) loss:4.714459419250488
# Epoch:10/100(50) loss:4.6145853996276855
# Epoch:20/100(100) loss:4.648043155670166
# Epoch:30/100(150) loss:4.635847568511963
# Epoch:40/100(200) loss:4.640440940856934
# Epoch:50/100(250) loss:4.657601833343506

# %%
# %reset -f
# !rm -fr __pycache__
# !rm -fr */__pycache__

# %% [markdown]
# # Domain Estimation

# %%
from z_common import *

# ファイル特有変数
CUDA_DIR = 2
N_CUDA = 2
spread_message = LOG_TEXT

# %%
# %%time
# PARENT = 'Digit'
# DATA_DOMAIN_LIST = [
#   'svhn_mnist',
#   'svhn_synth',
#   'svhn_synth_mnist',
#   'svhn_synth_mnist_mnistm',
# ]
PARENT = 'Office31'
DATA_DOMAIN_LIST = [
  # 'amazon_dslr_webcam',
  'dslr_webcam',
  'amazon_dslr',
  'webcam_amazon',
]


LAP = 1
NUM_LAPS = 1
log_dir_opt = ''
# log_dir_opt += '__record'


for DATA_DOMAIN in DATA_DOMAIN_LIST:
  config, CONFIG_FILE, log_dir = config_to_execute(DATA_DOMAIN, PARENT, CUDA_DIR, log_dir_opt)

  # !rm -fr */__pycache__
  # !CUDA_VISIBLE_DEVICES=$N_CUDA python3 -B run.py --config=$CONFIG_FILE  --log_dir=$log_dir  --num_laps=$NUM_LAPS  --spread_message=$spread_message
# Out:
# ===============================================
# ==============  dslr_webcam  ==============
# ===============================================
# Please install apex for mixed precision training from: https://github.com/NVIDIA/apex
#       ---------------------------------------------------------
#                 batch_size: 256,  epochs: 150
#                 SSL: simclr,  base_model: encoder
#                 jigsaw: True,  fourier: False,  grid: 3
#                 num_laps: 1
#         ---------------------------------------------------------
#
# =================  1/1周目  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  88 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=4)]: Done 498 out of 498 | elapsed:    4.3s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    2.1s finished
# Running on: cuda
# Epoch:0/150(0) loss:5.293476104736328
# Epoch:10/150(50) loss:4.889520645141602
# Epoch:20/150(100) loss:4.832769393920898
# Epoch:30/150(150) loss:4.834794998168945
# Epoch:40/150(200) loss:4.743178844451904
# Epoch:50/150(250) loss:4.790039539337158
# Epoch:60/150(300) loss:4.788527965545654
# Epoch:70/150(350) loss:4.753672122955322
# Epoch:80/150(400) loss:4.740188121795654
# Epoch:90/150(450) loss:4.7718329429626465
# Epoch:100/150(500) loss:4.764961242675781
# Epoch:110/150(550) loss:4.734570026397705
# Epoch:120/150(600) loss:4.710074424743652
# Epoch:130/150(650) loss:4.75809383392334
# Epoch:140/150(700) loss:4.716206073760986
# =================  Clustering 1/1  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 200 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=4)]: Done 498 out of 498 | elapsed:    2.9s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    2.2s finished
#   -----  Load Model from record/Office31/CUDA2/dw_encoder for clustering  -----
#   -----  Load NMI File from record/Office31/CUDA2/dw_encoder  -----
# nmi:0.6586010830544811
# nmi class:0.38671596721586377
# ===============================================
# ==============  amazon_dslr  ==============
# ===============================================
# Please install apex for mixed precision training from: https://github.com/NVIDIA/apex
#       ---------------------------------------------------------
#                 batch_size: 256,  epochs: 150
#                 SSL: simclr,  base_model: encoder
#                 jigsaw: True,  fourier: False,  grid: 3
#                 num_laps: 1
#         ---------------------------------------------------------
#
# =================  1/1周目  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  88 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=4)]: Done 2810 out of 2817 | elapsed:    6.2s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    6.2s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 200 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=4)]: Done 498 out of 498 | elapsed:    2.8s finished
# Running on: cuda
# Epoch:0/150(0) loss:5.457184791564941
# Epoch:4/150(50) loss:4.9897565841674805
# Epoch:8/150(100) loss:4.889049053192139
# Epoch:12/150(150) loss:4.820806503295898
# Epoch:16/150(200) loss:4.836867809295654
# Epoch:20/150(250) loss:4.825073719024658
# Epoch:25/150(300) loss:4.811647891998291
# Epoch:29/150(350) loss:4.765689373016357
# Epoch:33/150(400) loss:4.799242973327637
# Epoch:37/150(450) loss:4.800518989562988
# Epoch:41/150(500) loss:4.791217803955078
# Epoch:45/150(550) loss:4.7802653312683105
# Epoch:50/150(600) loss:4.765995979309082
# Epoch:54/150(650) loss:4.778829574584961
# Epoch:58/150(700) loss:4.746448040008545
# Epoch:62/150(750) loss:4.775914192199707
# Epoch:66/150(800) loss:4.775447368621826
# Epoch:70/150(850) loss:4.765286445617676
# Epoch:75/150(900) loss:4.734302997589111
# Epoch:79/150(950) loss:4.704709053039551
# Epoch:83/150(1000) loss:4.7429680824279785
# Epoch:87/150(1050) loss:4.751832962036133
# Epoch:91/150(1100) loss:4.746994972229004
# Epoch:95/150(1150) loss:4.718070983886719
# Epoch:100/150(1200) loss:4.755924224853516
# Epoch:104/150(1250) loss:4.7322845458984375
# Epoch:108/150(1300) loss:4.726259708404541
# Epoch:112/150(1350) loss:4.720846176147461
# Epoch:116/150(1400) loss:4.711630344390869
# Epoch:120/150(1450) loss:4.732771873474121
# Epoch:125/150(1500) loss:4.70643949508667
# Epoch:129/150(1550) loss:4.719837665557861
# Epoch:133/150(1600) loss:4.721131324768066
# Epoch:137/150(1650) loss:4.717869281768799
# Epoch:141/150(1700) loss:4.679195404052734
# Epoch:145/150(1750) loss:4.7471137046813965
# =================  Clustering 1/1  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    5.7s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 200 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=4)]: Done 498 out of 498 | elapsed:    2.9s finished
#   -----  Load Model from record/Office31/CUDA2/ad_encoder for clustering  -----
#   -----  Load NMI File from record/Office31/CUDA2/ad_encoder  -----
# nmi:0.8601483179840854
# nmi class:0.18678927624913166
# ===============================================
# ==============  webcam_amazon  ==============
# ===============================================
# Please install apex for mixed precision training from: https://github.com/NVIDIA/apex
#       ---------------------------------------------------------
#                 batch_size: 256,  epochs: 150
#                 SSL: simclr,  base_model: encoder
#                 jigsaw: True,  fourier: True,  grid: 3
#                 num_laps: 1
#         ---------------------------------------------------------
#
# =================  1/1周目  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  52 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=4)]: Done 352 tasks      | elapsed:    8.7s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:   18.1s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  76 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=4)]: Done 376 tasks      | elapsed:    7.8s
# [Parallel(n_jobs=4)]: Done 876 tasks      | elapsed:   18.0s

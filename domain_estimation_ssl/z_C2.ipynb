# %%
# %reset -f
# !rm -fr __pycache__
# !rm -fr */__pycache__

# %% [markdown]
# # Domain Estimation

# %%
from z_common import *

# ファイル特有変数
CUDA_DIR = 2
N_CUDA = 2
spread_message = LOG_TEXT

# %%
# %%time
# PARENT = 'Digit'
# DATA_DOMAIN_LIST = [
#   'svhn_mnist',
#   'svhn_synth',
#   'svhn_synth_mnist',
#   'svhn_synth_mnist_mnistm',
# ]
PARENT = 'Office31'
DATA_DOMAIN_LIST = [
  # 'amazon_dslr_webcam',
  # 'dslr_webcam',
  # 'amazon_dslr',
  'webcam_amazon',
  'webcam_amazon',
]


LAP = 1
NUM_LAPS = 2
log_dir_opt = ''
# log_dir_opt += '__record'
# log_dir_opt += '__douse'


for DATA_DOMAIN in DATA_DOMAIN_LIST:
  config, CONFIG_FILE, log_dir = config_to_execute(DATA_DOMAIN, PARENT, CUDA_DIR, log_dir_opt)

  # !rm -fr */__pycache__
  # !CUDA_VISIBLE_DEVICES=$N_CUDA python3 -B run.py --config=$CONFIG_FILE  --log_dir=$log_dir  --num_laps=$NUM_LAPS  --spread_message=$spread_message  --cuda_dir=$CUDA_DIR
# Out:
# ===============================================
# ==============  webcam_amazon  ==============
# ===============================================
# Please install apex for mixed precision training from: https://github.com/NVIDIA/apex
#     ---------------------------------------------------------
#         cuda_dir: 2
#         batch_size: 256,  epochs: 100
#         SSL: simclr,  base_model: encoder
#         jigsaw: True,  fourier: True,  grid: 3
#         num_laps: 2
#     ---------------------------------------------------------
#
#
# =================  1/2周目  =================
# =================  Clustering 1/2  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  56 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=4)]: Done 356 tasks      | elapsed:    7.3s
# [Parallel(n_jobs=4)]: Done 788 out of 795 | elapsed:   15.0s remaining:    0.1s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:   15.1s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  76 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=4)]: Done 376 tasks      | elapsed:    6.4s
# [Parallel(n_jobs=4)]: Done 876 tasks      | elapsed:   14.9s
# [Parallel(n_jobs=4)]: Done 1576 tasks      | elapsed:   27.1s
# [Parallel(n_jobs=4)]: Done 2476 tasks      | elapsed:   42.6s
# [Parallel(n_jobs=4)]: Done 2810 out of 2817 | elapsed:   48.4s remaining:    0.1s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:   48.5s finished
#   -----  Load Model from record/Office31/CUDA2/wa_encoder for clustering  -----
# nmi:0.19817083512288353
# nmi class:0.22290470640229895
# domain_accuracy:0.7278516057585825
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  76 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=4)]: Done 376 tasks      | elapsed:    7.0s
# [Parallel(n_jobs=4)]: Done 788 out of 795 | elapsed:   14.4s remaining:    0.1s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:   14.5s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  76 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=4)]: Done 376 tasks      | elapsed:    6.7s
# [Parallel(n_jobs=4)]: Done 876 tasks      | elapsed:   15.2s
# [Parallel(n_jobs=4)]: Done 1576 tasks      | elapsed:   27.4s
# [Parallel(n_jobs=4)]: Done 2476 tasks      | elapsed:   43.0s
# [Parallel(n_jobs=4)]: Done 2810 out of 2817 | elapsed:   48.7s remaining:    0.1s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:   48.8s finished
#   -----  Load Model from record/Office31/CUDA2/wa_encoder for clustering  -----
# nmi:0.005794626756508924
# nmi class:0.22409340271698897
# domain_accuracy:0.5420819490586932
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  76 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=4)]: Done 376 tasks      | elapsed:    7.0s
# [Parallel(n_jobs=4)]: Done 788 out of 795 | elapsed:   14.4s remaining:    0.1s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:   14.5s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  76 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=4)]: Done 376 tasks      | elapsed:    6.6s
# [Parallel(n_jobs=4)]: Done 876 tasks      | elapsed:   15.2s
# [Parallel(n_jobs=4)]: Done 1576 tasks      | elapsed:   27.7s
# [Parallel(n_jobs=4)]: Done 2476 tasks      | elapsed:   43.2s
# [Parallel(n_jobs=4)]: Done 2810 out of 2817 | elapsed:   49.0s remaining:    0.1s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:   49.2s finished
#   -----  Load Model from record/Office31/CUDA2/wa_encoder for clustering  -----
# nmi:0.16598368890360418
# nmi class:0.2291538196236109
# domain_accuracy:0.7098560354374308
# ===============================================
# ==============  webcam_amazon  ==============
# ===============================================
# Please install apex for mixed precision training from: https://github.com/NVIDIA/apex
#     ---------------------------------------------------------
#         cuda_dir: 2
#         batch_size: 256,  epochs: 100
#         SSL: simclr,  base_model: encoder
#         jigsaw: True,  fourier: True,  grid: 3
#         num_laps: 2
#     ---------------------------------------------------------
#
#
# =================  1/2周目  =================
# =================  Clustering 1/2  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  52 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=4)]: Done 352 tasks      | elapsed:    7.6s
# [Parallel(n_jobs=4)]: Done 788 out of 795 | elapsed:   15.4s remaining:    0.1s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:   15.5s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  76 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=4)]: Done 376 tasks      | elapsed:    6.6s
# [Parallel(n_jobs=4)]: Done 876 tasks      | elapsed:   15.2s
# [Parallel(n_jobs=4)]: Done 1576 tasks      | elapsed:   27.4s
# [Parallel(n_jobs=4)]: Done 2476 tasks      | elapsed:   43.0s
# [Parallel(n_jobs=4)]: Done 2810 out of 2817 | elapsed:   48.8s remaining:    0.1s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:   48.9s finished
#   -----  Load Model from record/Office31/CUDA2/wa_encoder for clustering  -----
# nmi:0.20697303569424536
# nmi class:0.2278220266213496
# domain_accuracy:0.7261904761904762
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  76 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=4)]: Done 376 tasks      | elapsed:    7.0s
# [Parallel(n_jobs=4)]: Done 788 out of 795 | elapsed:   14.5s remaining:    0.1s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:   14.6s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  76 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=4)]: Done 376 tasks      | elapsed:    6.7s
# [Parallel(n_jobs=4)]: Done 876 tasks      | elapsed:   15.5s
# [Parallel(n_jobs=4)]: Done 1576 tasks      | elapsed:   27.7s
# [Parallel(n_jobs=4)]: Done 2476 tasks      | elapsed:   43.2s
# [Parallel(n_jobs=4)]: Done 2810 out of 2817 | elapsed:   49.0s remaining:    0.1s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:   49.1s finished
#   -----  Load Model from record/Office31/CUDA2/wa_encoder for clustering  -----
# nmi:0.1686911565153268
# nmi class:0.2245777580494279
# domain_accuracy:0.7106866002214839
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  76 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=4)]: Done 376 tasks      | elapsed:    7.0s
# [Parallel(n_jobs=4)]: Done 788 out of 795 | elapsed:   14.4s remaining:    0.1s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:   14.5s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  76 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=4)]: Done 376 tasks      | elapsed:    6.6s
# [Parallel(n_jobs=4)]: Done 876 tasks      | elapsed:   15.6s
# [Parallel(n_jobs=4)]: Done 1576 tasks      | elapsed:   27.7s
# [Parallel(n_jobs=4)]: Done 2476 tasks      | elapsed:   43.3s
# [Parallel(n_jobs=4)]: Done 2810 out of 2817 | elapsed:   49.1s remaining:    0.1s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:   49.2s finished
#   -----  Load Model from record/Office31/CUDA2/wa_encoder for clustering  -----
# nmi:0.19793342816254542
# nmi class:0.22452858296823572
# domain_accuracy:0.7259136212624584
# CPU times: user 3.09 s, sys: 456 ms, total: 3.55 s
# Wall time: 7min 21s

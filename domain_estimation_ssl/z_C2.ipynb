# %%
# %reset -f
# !rm -fr __pycache__
# !rm -fr */__pycache__

# %%
from z_common import *

# ファイル特有変数
CUDA_DIR = 2
N_CUDA = 2
spread_message = LOG_TEXT

# %%
# %%time
PARENT = 'Digit'
DATA_DOMAIN_LIST = [
  # 'svhn_mnist',
  # 'svhn_synth',
  'svhn_synth_mnist',
  'svhn_synth_mnist',
  'svhn_synth_mnist',
  # 'svhn_synth_mnist_mnistm',
]
# PARENT = 'Office31'
# DATA_DOMAIN_LIST = [
  # 'amazon_dslr_webcam',
  # 'dslr_webcam',
  # 'amazon_dslr',
  # 'webcam_amazon',
# ]


NUM_LAPS = 2
log_dir_opt = ''
# log_dir_opt += '__record'

counter=0
for DATA_DOMAIN in DATA_DOMAIN_LIST:
  config, CONFIG_FILE, log_dir = config_to_execute(DATA_DOMAIN, PARENT, CUDA_DIR, log_dir_opt)
  log_dir += f'__{counter}'
  counter += 1

  # !rm -fr */__pycache__
  # !CUDA_VISIBLE_DEVICES=$N_CUDA python3 -B run.py --config=$CONFIG_FILE  --log_dir=$log_dir  --num_laps=$NUM_LAPS  --spread_message=$spread_message  --cuda_dir=$CUDA_DIR
# Out:
# ===============================================
# ==============  svhn_synth  ==============
# ===============================================
# Please install apex for mixed precision training from: https://github.com/NVIDIA/apex
#
#     ===============================================
#     =============== svhn_synth ===================
#     ===============================================
#     ---------------------------------------------------------
#         cuda_dir: 2
#         batch_size: 256,  epochs: 50
#         SSL: simclr,  base_model: encoder
#         jigsaw: True,  fourier: False,  grid: 3
#         num_laps: 2, sampling_num: 3000
#         log_dir: record/Digit/CUDA2/svhn_synth_encoder__0
#     ---------------------------------------------------------
#
#
# =================  1/2周目  =================
#   ----- get dataset svhn -----
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  88 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=4)]: Done 1288 tasks      | elapsed:   10.4s
# [Parallel(n_jobs=4)]: Done 3000 out of 3000 | elapsed:   26.1s finished
#   ----- get dataset synth -----
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  76 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=4)]: Done 376 tasks      | elapsed:    9.0s
# [Parallel(n_jobs=4)]: Done 876 tasks      | elapsed:   21.2s
# [Parallel(n_jobs=4)]: Done 1944 tasks      | elapsed:   38.5s
# [Parallel(n_jobs=4)]: Done 3000 out of 3000 | elapsed:  1.1min finished
# Running on: cuda
# Epoch:0/50(0) loss:6.4495062828063965
# Epoch:2/50(50) loss:6.075422286987305
# Epoch:4/50(100) loss:5.804271697998047
# Epoch:6/50(150) loss:5.6151862144470215
# Epoch:8/50(200) loss:5.5264153480529785
# Epoch:10/50(250) loss:5.454058647155762
# Epoch:13/50(300) loss:5.461338996887207
# Epoch:15/50(350) loss:5.308793067932129
# Epoch:17/50(400) loss:5.369002819061279
# Epoch:19/50(450) loss:5.308282852172852
# Epoch:21/50(500) loss:5.220600128173828
# Epoch:23/50(550) loss:5.216623783111572
# Epoch:26/50(600) loss:5.374473571777344
# Epoch:28/50(650) loss:5.297544956207275
# Epoch:30/50(700) loss:5.2771382331848145
# Epoch:32/50(750) loss:5.172042369842529
# Epoch:34/50(800) loss:5.183250427246094
# Epoch:36/50(850) loss:5.199382781982422
# Epoch:39/50(900) loss:5.107156753540039
# Epoch:41/50(950) loss:5.095651149749756
# Epoch:43/50(1000) loss:5.149205684661865
# Epoch:45/50(1050) loss:5.103984832763672
# Epoch:47/50(1100) loss:5.06118631362915
# =================  Clustering 1/2  =================
#   ----- get dataset svhn -----
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 102 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=4)]: Done 3000 out of 3000 | elapsed:    5.2s finished
#   ----- get dataset synth -----
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 128 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=4)]: Done 728 tasks      | elapsed:    8.8s
# [Parallel(n_jobs=4)]: Done 1728 tasks      | elapsed:   21.8s
# [Parallel(n_jobs=4)]: Done 3000 out of 3000 | elapsed:   37.5s finished
#   -----  Load Model from record/Digit/CUDA2/svhn_synth_encoder__0/checkpoints/model.pth for clustering  -----
# nmi:0.5340373205243351
# nmi class:0.01797650689392556
# domain_accuracy:0.8995
#   ----- get dataset svhn -----
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=4)]: Done 3000 out of 3000 | elapsed:   12.5s finished
#   ----- get dataset synth -----
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 128 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=4)]: Done 728 tasks      | elapsed:   10.3s
# [Parallel(n_jobs=4)]: Done 1728 tasks      | elapsed:   26.3s
# [Parallel(n_jobs=4)]: Done 3000 out of 3000 | elapsed:   42.0s finished
#   -----  Load Model from record/Digit/CUDA2/svhn_synth_encoder__0/checkpoints/model.pth for clustering  -----
# nmi:0.49180582510607423
# nmi class:0.020540389057028607
# domain_accuracy:0.8845
#   ----- get dataset svhn -----
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 200 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=4)]: Done 1400 tasks      | elapsed:    6.2s
# [Parallel(n_jobs=4)]: Done 3000 out of 3000 | elapsed:   13.9s finished
#   ----- get dataset synth -----
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 200 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=4)]: Done 1400 tasks      | elapsed:    8.3s
# [Parallel(n_jobs=4)]: Done 3000 out of 3000 | elapsed:   17.5s finished
#   -----  Load Model from record/Digit/CUDA2/svhn_synth_encoder__0/checkpoints/model.pth for clustering  -----
# nmi:0.48268456323420034
# nmi class:0.015755121348958498
# domain_accuracy:0.883
# ===============================================
# ==============  svhn_synth  ==============
# ===============================================
# Please install apex for mixed precision training from: https://github.com/NVIDIA/apex
#
#     ===============================================
#     =============== svhn_synth ===================
#     ===============================================
#     ---------------------------------------------------------
#         cuda_dir: 2
#         batch_size: 256,  epochs: 50
#         SSL: simclr,  base_model: encoder
#         jigsaw: True,  fourier: False,  grid: 3
#         num_laps: 2, sampling_num: 3000
#         log_dir: record/Digit/CUDA2/svhn_synth_encoder__1
#     ---------------------------------------------------------
#
#
# =================  1/2周目  =================
#   ----- get dataset svhn -----
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  88 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=4)]: Done 1288 tasks      | elapsed:    7.9s
# [Parallel(n_jobs=4)]: Done 3000 out of 3000 | elapsed:   14.1s finished
#   ----- get dataset synth -----
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=4)]: Done 2680 tasks      | elapsed:    8.0s
# [Parallel(n_jobs=4)]: Done 3000 out of 3000 | elapsed:    9.2s finished
# Running on: cuda
# Epoch:0/50(0) loss:6.441967964172363
# Epoch:2/50(50) loss:6.019332408905029
# Epoch:4/50(100) loss:5.880501747131348
# Epoch:6/50(150) loss:5.672486305236816
# Epoch:8/50(200) loss:5.605789661407471
# Epoch:10/50(250) loss:5.45500373840332
# Epoch:13/50(300) loss:5.356923580169678
# Epoch:15/50(350) loss:5.288877964019775
# Epoch:17/50(400) loss:5.321946144104004
# Epoch:19/50(450) loss:5.274364471435547
# Epoch:21/50(500) loss:5.28680944442749
# Epoch:23/50(550) loss:5.2741522789001465
# Epoch:26/50(600) loss:5.200374126434326
# Epoch:28/50(650) loss:5.235727310180664
# Epoch:30/50(700) loss:5.303842067718506
# Epoch:32/50(750) loss:5.236210823059082
# Epoch:34/50(800) loss:5.174844264984131
# Epoch:36/50(850) loss:5.195853233337402
# Epoch:39/50(900) loss:5.101500511169434
# Epoch:41/50(950) loss:5.056904315948486
# Epoch:43/50(1000) loss:5.141504287719727
# Epoch:45/50(1050) loss:5.135177135467529
# Epoch:47/50(1100) loss:5.062870502471924
# =================  Clustering 1/2  =================
#   ----- get dataset svhn -----
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 102 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=4)]: Done 3000 out of 3000 | elapsed:    4.1s finished
#   ----- get dataset synth -----
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=4)]: Done 3000 out of 3000 | elapsed:    5.3s finished
#   -----  Load Model from record/Digit/CUDA2/svhn_synth_encoder__1/checkpoints/model.pth for clustering  -----
# nmi:0.5495456534555173
# nmi class:0.01526114491141413
# domain_accuracy:0.9051666666666667
#   ----- get dataset svhn -----
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=4)]: Done 2808 tasks      | elapsed:    7.4s
# [Parallel(n_jobs=4)]: Done 3000 out of 3000 | elapsed:    7.7s finished
#   ----- get dataset synth -----
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=4)]: Done 2972 tasks      | elapsed:    5.3s
# [Parallel(n_jobs=4)]: Done 3000 out of 3000 | elapsed:    5.4s finished
#   -----  Load Model from record/Digit/CUDA2/svhn_synth_encoder__1/checkpoints/model.pth for clustering  -----
# nmi:0.554771258323457
# nmi class:0.016332590922904584
# domain_accuracy:0.9065
#   ----- get dataset svhn -----
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=4)]: Done 3000 out of 3000 | elapsed:    7.3s finished
#   ----- get dataset synth -----
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=4)]: Done 3000 out of 3000 | elapsed:    4.8s finished
#   -----  Load Model from record/Digit/CUDA2/svhn_synth_encoder__1/checkpoints/model.pth for clustering  -----
# nmi:0.5685978278293183
# nmi class:0.015344970165634677
# domain_accuracy:0.9096666666666666
# ===============================================
# ==============  svhn_synth  ==============
# ===============================================
# Please install apex for mixed precision training from: https://github.com/NVIDIA/apex
#
#     ===============================================
#     =============== svhn_synth ===================
#     ===============================================
#     ---------------------------------------------------------
#         cuda_dir: 2
#         batch_size: 256,  epochs: 50
#         SSL: simclr,  base_model: encoder
#         jigsaw: True,  fourier: False,  grid: 3
#         num_laps: 2, sampling_num: 3000
#         log_dir: record/Digit/CUDA2/svhn_synth_encoder__2
#     ---------------------------------------------------------
#
#
# =================  1/2周目  =================
#   ----- get dataset svhn -----
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  95 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=4)]: Done 3000 out of 3000 | elapsed:    3.9s finished
#   ----- get dataset synth -----
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=4)]: Done 3000 out of 3000 | elapsed:    3.1s finished
# Running on: cuda
# Epoch:0/50(0) loss:6.542632102966309
# Epoch:2/50(50) loss:6.060650825500488
# Epoch:4/50(100) loss:5.821324825286865
# Epoch:6/50(150) loss:5.704864978790283
# Epoch:8/50(200) loss:5.562022686004639
# Epoch:10/50(250) loss:5.400295257568359
# Epoch:13/50(300) loss:5.391794681549072
# Epoch:15/50(350) loss:5.305348873138428
# Epoch:17/50(400) loss:5.351632118225098
# Epoch:19/50(450) loss:5.245790958404541
# Epoch:21/50(500) loss:5.288261413574219
# Epoch:23/50(550) loss:5.273595809936523
# Epoch:26/50(600) loss:5.2351155281066895
# Epoch:28/50(650) loss:5.272505760192871
# Epoch:30/50(700) loss:5.1476969718933105
# Epoch:32/50(750) loss:5.2736592292785645
# Epoch:34/50(800) loss:5.218811988830566
# Epoch:36/50(850) loss:5.226322174072266
# Epoch:39/50(900) loss:5.134960174560547
# Epoch:41/50(950) loss:5.086431503295898
# Epoch:43/50(1000) loss:5.129078388214111
# Epoch:45/50(1050) loss:5.190810680389404
# Epoch:47/50(1100) loss:5.087883472442627
# =================  Clustering 1/2  =================
#   ----- get dataset svhn -----
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 102 tasks      | elapsed:    2.9s
# [Parallel(n_jobs=4)]: Done 3000 out of 3000 | elapsed:    5.4s finished
#   ----- get dataset synth -----
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=4)]: Done 3000 out of 3000 | elapsed:    3.0s finished
#   -----  Load Model from record/Digit/CUDA2/svhn_synth_encoder__2/checkpoints/model.pth for clustering  -----
# nmi:0.5270347421741146
# nmi class:0.025222980600503094
# domain_accuracy:0.8968333333333334
#   ----- get dataset svhn -----
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=4)]: Done 3000 out of 3000 | elapsed:    4.8s finished
#   ----- get dataset synth -----
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=4)]: Done 3000 out of 3000 | elapsed:    5.7s finished
#   -----  Load Model from record/Digit/CUDA2/svhn_synth_encoder__2/checkpoints/model.pth for clustering  -----
# nmi:0.4995898744663855
# nmi class:0.026588966644786792
# domain_accuracy:0.8843333333333333
#   ----- get dataset svhn -----
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=4)]: Done 3000 out of 3000 | elapsed:    5.0s finished
#   ----- get dataset synth -----
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=4)]: Done 2972 tasks      | elapsed:    5.1s
# [Parallel(n_jobs=4)]: Done 3000 out of 3000 | elapsed:    5.1s finished
#   -----  Load Model from record/Digit/CUDA2/svhn_synth_encoder__2/checkpoints/model.pth for clustering  -----
# nmi:0.5179417084944589
# nmi class:0.01874745034223914
# domain_accuracy:0.8923333333333333
# CPU times: user 10.2 s, sys: 1.21 s, total: 11.4 s
# Wall time: 31min 38s

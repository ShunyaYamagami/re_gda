# %%
# %reset -f
# !rm -fr __pycache__
# !rm -fr */__pycache__

# %% [markdown]
# # Domain Estimation

# %%
from z_common import *

# ファイル特有変数
CUDA_DIR = 1
N_CUDA = 1
spread_message = LOG_TEXT

# %%
# %%time
# PARENT = 'Digit'
# DATA_DOMAIN_LIST = [
#   'svhn_mnist',
#   'svhn_synth',
#   'svhn_synth_mnist',
#   'svhn_synth_mnist_mnistm',
# ]
PARENT = 'Office31'
DATA_DOMAIN_LIST = [
  # 'amazon_dslr_webcam',
  'dslr_webcam',
  # 'amazon_dslr',
  # 'webcam_amazon',
]


LAP = 1
NUM_LAPS = 3
log_dir_opt = ''
# log_dir_opt += '__record'


for DATA_DOMAIN in DATA_DOMAIN_LIST:
  config, CONFIG_FILE, log_dir = config_to_execute(DATA_DOMAIN, PARENT, CUDA_DIR, log_dir_opt)

  # !rm -fr */__pycache__
  # !CUDA_VISIBLE_DEVICES=$N_CUDA python3 -B run.py --config=$CONFIG_FILE  --log_dir=$log_dir  --num_laps=$NUM_LAPS  --spread_message=$spread_message
# Out:
# ===============================================
# ==============  dslr_webcam  ==============
# ===============================================
# Please install apex for mixed precision training from: https://github.com/NVIDIA/apex
#     ---------------------------------------------------------
#         batch_size: 256,  epochs: 100
#         SSL: simclr,  base_model: encoder
#         jigsaw: True,  fourier: False,  grid: 3
#         num_laps: 3
#     ---------------------------------------------------------
#
# =================  2/3周目  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  88 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=4)]: Done 498 out of 498 | elapsed:    3.7s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    2.2s finished
# Running on: cuda
#   ----- Loaded pre-trained model from record/Office31/CUDA1/dw_encoder for SSL  -----
# Epoch:0/100(0) loss:4.588078498840332
# Epoch:10/100(50) loss:4.54475736618042
# Epoch:20/100(100) loss:4.523767471313477
# Epoch:30/100(150) loss:4.542189598083496
# Epoch:40/100(200) loss:4.5108866691589355
# Epoch:50/100(250) loss:4.513934135437012
# Epoch:60/100(300) loss:4.534718990325928
# Epoch:70/100(350) loss:4.516270637512207
# Epoch:80/100(400) loss:4.498350143432617
# Epoch:90/100(450) loss:4.500242710113525
# =================  Clustering 2/3  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 128 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=4)]: Done 498 out of 498 | elapsed:    5.1s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    2.8s finished
#   -----  Load Model from record/Office31/CUDA1/dw_encoder__2 for clustering  -----
#   -----  Load NMI File from record/Office31/CUDA1/dw_encoder__2  -----
# nmi:0.6547136891595547
# nmi class:0.40707049324603894
# =================  3/3周目  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 104 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=4)]: Done 498 out of 498 | elapsed:    4.8s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 200 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    2.8s finished
# Running on: cuda
#   ----- Loaded pre-trained model from record/Office31/CUDA1/dw_encoder__2 for SSL  -----
# Epoch:0/100(0) loss:4.749738693237305
# Epoch:10/100(50) loss:4.634637832641602
# Epoch:20/100(100) loss:4.627800941467285
# Epoch:30/100(150) loss:4.591304779052734
# Epoch:40/100(200) loss:4.56233024597168
# Epoch:50/100(250) loss:4.5699543952941895
# Epoch:60/100(300) loss:4.579707145690918
# Epoch:70/100(350) loss:4.6053900718688965
# Epoch:80/100(400) loss:4.580216884613037
# Epoch:90/100(450) loss:4.590000629425049
# =================  Clustering 3/3  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 128 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=4)]: Done 498 out of 498 | elapsed:    4.9s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    2.9s finished
#   -----  Load Model from record/Office31/CUDA1/dw_encoder__2__3 for clustering  -----
#   -----  Load NMI File from record/Office31/CUDA1/dw_encoder__2__3  -----
# nmi:0.5147311601025977
# nmi class:0.4189620062937745
# CPU times: user 2.02 s, sys: 227 ms, total: 2.25 s
# Wall time: 6min 13s

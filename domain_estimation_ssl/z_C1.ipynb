# %%
# %reset -f
# !rm -fr __pycache__
# !rm -fr */__pycache__

# %% [markdown]
# # Domain Estimation

# %%
from z_common import *
import sys
sys.dont_write_bytecode = True  # pycacheを作らないようにする

# ファイル特有変数
CUDA_DIR = 1
N_CUDA = 1
spread_message = LOG_TEXT

# %%
# %%time
########## Change here! ##########
# PARENT = 'Digit'
# DATA_DOMAIN_LIST = [
#   'svhn_mnist',
#   'svhn_synth',
#   'svhn_synth_mnist',
#   'svhn_synth_mnist_mnistm',
# ]
PARENT = 'Office31'
DATA_DOMAIN_LIST = [
  # 'amazon_dslr_webcam',
  'dslr_webcam',
  # 'amazon_dslr',
  # 'webcam_amazon',
]

LAP = 1
NUM_LAPS = 2
log_dir_opt = ''
# log_dir_opt += '__record'

try:
  start_time = time()
  for DATA_DOMAIN in DATA_DOMAIN_LIST:
    config, CONFIG_FILE, log_dir = config_to_execute(DATA_DOMAIN, PARENT, CUDA_DIR, log_dir_opt)

    # !rm -fr */__pycache__
    # !CUDA_VISIBLE_DEVICES=$N_CUDA python3 -B run.py --config=$CONFIG_FILE  --log_dir=$log_dir  --num_laps=$NUM_LAPS

    log_spread_sheet(config, log_dir, DATA_DOMAIN, spread_message)

  end_time = time()
  send_email(not_error=True, body_text=f'実行終了. 実行時間: {(end_time-start_time)/60:.2f} 分', config=config, log_dir=log_dir, DATA_DOMAIN=DATA_DOMAIN)
except:
  error_message=traceback.format_exc()
  send_email(not_error=False, error_message=error_message)
# Out:
# ===============================================
# ==============  dslr_webcam  ==============
# ===============================================
# Please install apex for mixed precision training from: https://github.com/NVIDIA/apex
#     ---------------------------------------------------------
#             batch_size: 256,  epochs: 100
#             SSL: simsiam,  base_model: encoder
#             jigsaw: True,  fourier: False
#             num_laps: 2
#     ---------------------------------------------------------
# =================  1周目  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  88 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=4)]: Done 498 out of 498 | elapsed:    3.6s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    2.0s finished
# Running on: cuda
# Epoch:0/100(0) loss:0.01890423707664013
# Epoch:10/100(50) loss:-0.8368582129478455
# Epoch:20/100(100) loss:-0.8675006628036499
# Epoch:30/100(150) loss:-0.8670675158500671
# Epoch:40/100(200) loss:-0.8949221968650818
# Epoch:50/100(250) loss:-0.8843969106674194
# Epoch:60/100(300) loss:-0.8635240793228149
# Epoch:70/100(350) loss:-0.893816351890564
# Epoch:80/100(400) loss:-0.9022561311721802
# Epoch:90/100(450) loss:-0.8836442232131958
# =================  Clustering 1  =================
# Traceback (most recent call last):
#   File "/home/syamagami/codes/re_gda/domain_estimation_ssl/run.py", line 64, in <module>
#     main(args)
#   File "/home/syamagami/codes/re_gda/domain_estimation_ssl/run.py", line 45, in main
#     run_clustering(config)
#   File "/home/syamagami/codes/re_gda/domain_estimation_ssl/clustering.py", line 75, in run_clustering
#     model = Encoder(config.model.ssl, input_dim=3, output_dim=config.model.out_dim)
# TypeError: Encoder.__init__() got an unexpected keyword argument 'output_dim'
# CPU times: user 861 ms, sys: 142 ms, total: 1 s
# Wall time: 1min 39s

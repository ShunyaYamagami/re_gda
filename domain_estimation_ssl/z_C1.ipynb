# %%
# %reset -f
# !rm -fr __pycache__
# !rm -fr */__pycache__

# %% [markdown]
# # Domain Estimation

# %%
from z_common import *

# ファイル特有変数
CUDA_DIR = 2
N_CUDA = 2
spread_message = LOG_TEXT

# %%
# %%time
# PARENT = 'Digit'
# DATA_DOMAIN_LIST = [
#   'svhn_mnist',
#   'svhn_synth',
#   'svhn_synth_mnist',
#   'svhn_synth_mnist_mnistm',
# ]
PARENT = 'Office31'
DATA_DOMAIN_LIST = [
  # 'amazon_dslr_webcam',
  'dslr_webcam',
  'amazon_dslr',
  'webcam_amazon',
]


LAP = 1
NUM_LAPS = 1
log_dir_opt = ''
# log_dir_opt += '__record'


for DATA_DOMAIN in DATA_DOMAIN_LIST:
  config, CONFIG_FILE, log_dir = config_to_execute(DATA_DOMAIN, PARENT, CUDA_DIR, log_dir_opt)

  # !rm -fr */__pycache__
  # !CUDA_VISIBLE_DEVICES=$N_CUDA python3 -B run.py --config=$CONFIG_FILE  --log_dir=$log_dir  --num_laps=$NUM_LAPS  --spread_message=$spread_message
# Out:
# ===============================================
# ==============  dslr_webcam  ==============
# ===============================================
# Please install apex for mixed precision training from: https://github.com/NVIDIA/apex
#       ---------------------------------------------------------
#                 batch_size: 256,  epochs: 150
#                 SSL: simclr,  base_model: encoder
#                 jigsaw: True,  fourier: False,  grid: 3
#                 num_laps: 1
#         ---------------------------------------------------------
#
# =================  1/1周目  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  88 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=4)]: Done 498 out of 498 | elapsed:    4.0s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    2.1s finished
# Running on: cuda
# Epoch:0/150(0) loss:5.277018070220947
# Epoch:10/150(50) loss:4.895529747009277
# Epoch:20/150(100) loss:4.815725803375244
# Epoch:30/150(150) loss:4.798798561096191
# Epoch:40/150(200) loss:4.780884265899658
# Epoch:50/150(250) loss:4.75973653793335
# Epoch:60/150(300) loss:4.784397125244141
# Epoch:70/150(350) loss:4.740067481994629
# Epoch:80/150(400) loss:4.7392258644104
# Epoch:90/150(450) loss:4.757238864898682
# Epoch:100/150(500) loss:4.747590065002441
# Epoch:110/150(550) loss:4.6953325271606445
# Epoch:120/150(600) loss:4.7083940505981445
# Epoch:130/150(650) loss:4.745517730712891
# Epoch:140/150(700) loss:4.721401214599609
# =================  Clustering 1/1  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 200 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=4)]: Done 498 out of 498 | elapsed:    3.0s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    2.2s finished
#   -----  Load Model from record/Office31/CUDA2/dw_encoder for clustering  -----
#   -----  Load NMI File from record/Office31/CUDA2/dw_encoder  -----
# nmi:0.6714637887301803
# nmi class:0.38278067439606045
# ===============================================
# ==============  amazon_dslr  ==============
# ===============================================
# Please install apex for mixed precision training from: https://github.com/NVIDIA/apex
#       ---------------------------------------------------------
#                 batch_size: 256,  epochs: 150
#                 SSL: simclr,  base_model: encoder
#                 jigsaw: True,  fourier: False,  grid: 3
#                 num_laps: 1
#         ---------------------------------------------------------
#
# =================  1/1周目  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  88 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    6.8s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 200 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=4)]: Done 498 out of 498 | elapsed:    2.9s finished
# Running on: cuda
# Epoch:0/150(0) loss:5.527193069458008
# Epoch:4/150(50) loss:4.968119144439697
# Epoch:8/150(100) loss:4.850451946258545
# Epoch:12/150(150) loss:4.830810546875
# Epoch:16/150(200) loss:4.810185432434082
# Epoch:20/150(250) loss:4.8374834060668945
# Epoch:25/150(300) loss:4.8282880783081055
# Epoch:29/150(350) loss:4.762629508972168
# Epoch:33/150(400) loss:4.781801700592041
# Epoch:37/150(450) loss:4.799256324768066
# Epoch:41/150(500) loss:4.781774520874023
# Epoch:45/150(550) loss:4.7863006591796875
# Epoch:50/150(600) loss:4.783691883087158
# Epoch:54/150(650) loss:4.756451606750488
# Epoch:58/150(700) loss:4.726083278656006
# Epoch:62/150(750) loss:4.775078773498535
# Epoch:66/150(800) loss:4.768035411834717
# Epoch:70/150(850) loss:4.798519134521484
# Epoch:75/150(900) loss:4.7463812828063965
# Epoch:79/150(950) loss:4.707458972930908
# Epoch:83/150(1000) loss:4.7532477378845215
# Epoch:87/150(1050) loss:4.725757122039795
# Epoch:91/150(1100) loss:4.7075347900390625
# Epoch:95/150(1150) loss:4.706132411956787
# Epoch:100/150(1200) loss:4.731866359710693
# Epoch:104/150(1250) loss:4.702836990356445
# Epoch:108/150(1300) loss:4.719217300415039
# Epoch:112/150(1350) loss:4.699894428253174
# Epoch:116/150(1400) loss:4.718601703643799
# Epoch:120/150(1450) loss:4.736649513244629
# Epoch:125/150(1500) loss:4.691047191619873
# Epoch:129/150(1550) loss:4.7181291580200195
# Epoch:133/150(1600) loss:4.724652290344238
# Epoch:137/150(1650) loss:4.726159572601318
# Epoch:141/150(1700) loss:4.695839881896973
# Epoch:145/150(1750) loss:4.727593898773193
# =================  Clustering 1/1  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    5.7s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 200 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=4)]: Done 498 out of 498 | elapsed:    2.8s finished
#   -----  Load Model from record/Office31/CUDA2/ad_encoder for clustering  -----
#   -----  Load NMI File from record/Office31/CUDA2/ad_encoder  -----
# nmi:0.8669800195473651
# nmi class:0.1829467138145173
# send_email
# ===============================================
# ==============  webcam_amazon  ==============
# ===============================================
# Please install apex for mixed precision training from: https://github.com/NVIDIA/apex
#       ---------------------------------------------------------
#                 batch_size: 256,  epochs: 150
#                 SSL: simclr,  base_model: encoder
#                 jigsaw: True,  fourier: True,  grid: 3
#                 num_laps: 1
#         ---------------------------------------------------------
#
# =================  1/1周目  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  52 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=4)]: Done 352 tasks      | elapsed:    8.4s
# [Parallel(n_jobs=4)]: Done 788 out of 795 | elapsed:   17.5s remaining:    0.2s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:   17.7s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  76 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=4)]: Done 376 tasks      | elapsed:    7.7s
# [Parallel(n_jobs=4)]: Done 876 tasks      | elapsed:   17.9s

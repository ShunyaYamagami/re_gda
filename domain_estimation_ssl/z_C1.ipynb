# %%
# %reset -f
# !rm -fr __pycache__
# !rm -fr */__pycache__

# %% [markdown]
# # Domain Estimation

# %%
from z_common import *

# ファイル特有変数
CUDA_DIR = 1
N_CUDA = 1
spread_message = LOG_TEXT

# %%
# %%time
# PARENT = 'Digit'
# DATA_DOMAIN_LIST = [
#   'svhn_mnist',
#   'svhn_synth',
#   'svhn_synth_mnist',
#   'svhn_synth_mnist_mnistm',
# ]
PARENT = 'Office31'
DATA_DOMAIN_LIST = [
  # 'amazon_dslr_webcam',
  # 'dslr_webcam',
  # 'amazon_dslr',
  'webcam_amazon',
  'webcam_amazon',
  'webcam_amazon',
]


LAP = 1
NUM_LAPS = 2
log_dir_opt = ''
# log_dir_opt += '__record'
# log_dir_opt += '__douse'


for DATA_DOMAIN in DATA_DOMAIN_LIST:
  config, CONFIG_FILE, log_dir = config_to_execute(DATA_DOMAIN, PARENT, CUDA_DIR, log_dir_opt)

  # !rm -fr */__pycache__
  # !CUDA_VISIBLE_DEVICES=$N_CUDA python3 -B run.py --config=$CONFIG_FILE  --log_dir=$log_dir  --num_laps=$NUM_LAPS  --spread_message=$spread_message  --cuda_dir=$CUDA_DIR
# Out:
# ===============================================
# ==============  webcam_amazon  ==============
# ===============================================
# Please install apex for mixed precision training from: https://github.com/NVIDIA/apex
#     ---------------------------------------------------------
#         batch_size: 256,  epochs: 100
#         SSL: simclr,  base_model: encoder
#         jigsaw: True,  fourier: True,  grid: 3
#         num_laps: 2
#     ---------------------------------------------------------
#
#
# =================  1/2周目  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    4.1s
# [Parallel(n_jobs=4)]: Done 244 tasks      | elapsed:   12.4s
# [Parallel(n_jobs=4)]: Done 744 tasks      | elapsed:   38.7s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:   41.4s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=4)]: Done 192 tasks      | elapsed:   11.1s
# [Parallel(n_jobs=4)]: Done 442 tasks      | elapsed:   25.2s
# [Parallel(n_jobs=4)]: Done 792 tasks      | elapsed:   45.6s
# [Parallel(n_jobs=4)]: Done 1242 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=4)]: Done 1880 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=4)]: Done 2810 out of 2817 | elapsed:  2.6min remaining:    0.4s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:  2.6min finished
# Running on: cuda
# Epoch:0/100(0) loss:5.439306259155273
# Epoch:3/100(50) loss:4.9691619873046875
# Epoch:7/100(100) loss:4.9562225341796875
# Epoch:10/100(150) loss:4.8297319412231445
# Epoch:14/100(200) loss:4.824448585510254
# Epoch:17/100(250) loss:4.833611011505127
# Epoch:21/100(300) loss:4.8113908767700195
# Epoch:25/100(350) loss:4.793212890625
# Epoch:28/100(400) loss:4.806821823120117
# Epoch:32/100(450) loss:4.837493419647217
# Epoch:35/100(500) loss:4.766341209411621
# Epoch:39/100(550) loss:4.7815423011779785
# Epoch:42/100(600) loss:4.767029762268066
# Epoch:46/100(650) loss:4.775655269622803
# Epoch:50/100(700) loss:4.759873390197754
# Epoch:53/100(750) loss:4.739624500274658
# Epoch:57/100(800) loss:4.792374610900879
# Epoch:60/100(850) loss:4.739395618438721
# Epoch:64/100(900) loss:4.732358932495117
# Epoch:67/100(950) loss:4.729283332824707
# Epoch:71/100(1000) loss:4.715685844421387
# Epoch:75/100(1050) loss:4.717273712158203
# Epoch:78/100(1100) loss:4.743607044219971
# Epoch:82/100(1150) loss:4.748786926269531
# Epoch:85/100(1200) loss:4.743595123291016
# Epoch:89/100(1250) loss:4.715691566467285
# Epoch:92/100(1300) loss:4.715097904205322
# Epoch:96/100(1350) loss:4.735980987548828
# =================  Clustering 1/2  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    5.3s
# [Parallel(n_jobs=4)]: Done 192 tasks      | elapsed:   14.2s
# [Parallel(n_jobs=4)]: Done 442 tasks      | elapsed:   29.2s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:   50.6s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  76 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=4)]: Done 376 tasks      | elapsed:   22.0s

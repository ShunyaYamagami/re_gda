# %%
# %reset -f
# !rm -fr __pycache__
# !rm -fr */__pycache__

# %%
from z_common import *

# ファイル特有変数
CUDA_DIR = 1
N_CUDA = 1
spread_message = LOG_TEXT

# %%
# %%time
PARENT = 'Digit'
DATA_DOMAIN_LIST = [
  # 'svhn_mnist',
  # 'svhn_synth',
  'svhn_synth_mnist',
  'svhn_synth_mnist',
  'svhn_synth_mnist',
  # 'svhn_synth_mnist_mnistm',
]
# PARENT = 'Office31'
# DATA_DOMAIN_LIST = [
  # 'amazon_dslr_webcam',
  # 'dslr_webcam',
  # 'amazon_dslr',
  # 'webcam_amazon',
# ]


NUM_LAPS = 2
log_dir_opt = ''
# log_dir_opt += '__record'

counter=0
for DATA_DOMAIN in DATA_DOMAIN_LIST:
  config, CONFIG_FILE, log_dir = config_to_execute(DATA_DOMAIN, PARENT, CUDA_DIR, log_dir_opt)
  log_dir += f'__{counter}'
  counter += 1

  # !rm -fr */__pycache__
  # !CUDA_VISIBLE_DEVICES=$N_CUDA python3 -B run.py --config=$CONFIG_FILE  --log_dir=$log_dir  --num_laps=$NUM_LAPS  --spread_message=$spread_message  --cuda_dir=$CUDA_DIR
# Out:
# ===============================================
# ==============  svhn_synth  ==============
# ===============================================
# Please install apex for mixed precision training from: https://github.com/NVIDIA/apex
#
#     ===============================================
#     =============== svhn_synth ===================
#     ===============================================
#     ---------------------------------------------------------
#         cuda_dir: 1
#         batch_size: 256,  epochs: 50
#         SSL: simclr,  base_model: encoder
#         jigsaw: True,  fourier: False,  grid: 3
#         num_laps: 2, sampling_num: 3000
#         log_dir: record/Digit/CUDA1/svhn_synth_encoder__0
#     ---------------------------------------------------------
#
#
# =================  1/2周目  =================
#   ----- get dataset svhn -----
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  68 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=4)]: Done 668 tasks      | elapsed:   10.2s
# [Parallel(n_jobs=4)]: Done 1668 tasks      | elapsed:   30.5s
# [Parallel(n_jobs=4)]: Done 3000 out of 3000 | elapsed:   54.3s finished
#   ----- get dataset synth -----
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  76 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=4)]: Done 376 tasks      | elapsed:    8.7s
# [Parallel(n_jobs=4)]: Done 876 tasks      | elapsed:   23.4s
# [Parallel(n_jobs=4)]: Done 1576 tasks      | elapsed:   37.9s
# [Parallel(n_jobs=4)]: Done 2476 tasks      | elapsed:   54.4s
# [Parallel(n_jobs=4)]: Done 3000 out of 3000 | elapsed:  1.1min finished
# Running on: cuda
# Epoch:0/50(0) loss:6.518578052520752
# Epoch:2/50(50) loss:6.155761241912842
# Epoch:4/50(100) loss:6.000484943389893
# Epoch:6/50(150) loss:5.915220737457275
# Epoch:8/50(200) loss:5.769037246704102
# Epoch:10/50(250) loss:5.585103988647461
# Epoch:13/50(300) loss:5.546984672546387
# Epoch:15/50(350) loss:5.570526123046875
# Epoch:17/50(400) loss:5.458642959594727
# Epoch:19/50(450) loss:5.392616271972656
# Epoch:21/50(500) loss:5.31818962097168
# Epoch:23/50(550) loss:5.371836185455322
# Epoch:26/50(600) loss:5.698375701904297
# Epoch:28/50(650) loss:5.337958812713623
# Epoch:30/50(700) loss:5.192967891693115
# Epoch:32/50(750) loss:5.252848148345947
# Epoch:34/50(800) loss:5.181259632110596
# Epoch:36/50(850) loss:5.176336765289307
# Epoch:39/50(900) loss:5.153852939605713
# Epoch:41/50(950) loss:5.100371837615967
# Epoch:43/50(1000) loss:5.214055061340332
# Epoch:45/50(1050) loss:5.160180568695068
# Epoch:47/50(1100) loss:5.08527946472168
# =================  Clustering 1/2  =================
#   ----- get dataset svhn -----
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  74 tasks      | elapsed:    2.9s
# [Parallel(n_jobs=4)]: Done 2620 tasks      | elapsed:   16.1s
# [Parallel(n_jobs=4)]: Done 3000 out of 3000 | elapsed:   20.7s finished
#   ----- get dataset synth -----
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 128 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=4)]: Done 728 tasks      | elapsed:   12.7s
# [Parallel(n_jobs=4)]: Done 1728 tasks      | elapsed:   28.4s
# [Parallel(n_jobs=4)]: Done 3000 out of 3000 | elapsed:   43.5s finished
#   -----  Load Model from record/Digit/CUDA1/svhn_synth_encoder__0/checkpoints/model.pth for clustering  -----
# nmi:0.3345035681089805
# nmi class:0.026914098841846354
# domain_accuracy:0.8156666666666667
#   ----- get dataset svhn -----
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 200 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=4)]: Done 1400 tasks      | elapsed:    8.3s
# [Parallel(n_jobs=4)]: Done 3000 out of 3000 | elapsed:   19.5s finished
#   ----- get dataset synth -----
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 128 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=4)]: Done 1208 tasks      | elapsed:    8.4s
# [Parallel(n_jobs=4)]: Done 3000 out of 3000 | elapsed:   20.3s finished
#   -----  Load Model from record/Digit/CUDA1/svhn_synth_encoder__0/checkpoints/model.pth for clustering  -----
# nmi:0.30848045952088815
# nmi class:0.024497697575171257
# domain_accuracy:0.8081666666666667
#   ----- get dataset svhn -----
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 200 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=4)]: Done 2910 tasks      | elapsed:   12.4s
# [Parallel(n_jobs=4)]: Done 3000 out of 3000 | elapsed:   12.6s finished
#   ----- get dataset synth -----
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 200 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=4)]: Done 2104 tasks      | elapsed:    6.9s
# [Parallel(n_jobs=4)]: Done 3000 out of 3000 | elapsed:    9.1s finished
#   -----  Load Model from record/Digit/CUDA1/svhn_synth_encoder__0/checkpoints/model.pth for clustering  -----
# nmi:0.32958759922877384
# nmi class:0.02168334671975819
# domain_accuracy:0.8161666666666667
# ===============================================
# ==============  svhn_synth  ==============
# ===============================================
# Please install apex for mixed precision training from: https://github.com/NVIDIA/apex
#
#     ===============================================
#     =============== svhn_synth ===================
#     ===============================================
#     ---------------------------------------------------------
#         cuda_dir: 1
#         batch_size: 256,  epochs: 50
#         SSL: simclr,  base_model: encoder
#         jigsaw: True,  fourier: False,  grid: 3
#         num_laps: 2, sampling_num: 3000
#         log_dir: record/Digit/CUDA1/svhn_synth_encoder__1
#     ---------------------------------------------------------
#
#
# =================  1/2周目  =================
#   ----- get dataset svhn -----
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  68 tasks      | elapsed:    3.3s
# [Parallel(n_jobs=4)]: Done 3000 out of 3000 | elapsed:    9.1s finished
#   ----- get dataset synth -----
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=4)]: Done 2680 tasks      | elapsed:    7.4s
# [Parallel(n_jobs=4)]: Done 3000 out of 3000 | elapsed:    8.1s finished
# Running on: cuda
# Epoch:0/50(0) loss:6.406322002410889
# Epoch:2/50(50) loss:6.090167999267578
# Epoch:4/50(100) loss:5.862748622894287
# Epoch:6/50(150) loss:5.86000919342041
# Epoch:8/50(200) loss:5.609095573425293
# Epoch:10/50(250) loss:5.515523910522461
# Epoch:13/50(300) loss:5.555084705352783
# Epoch:15/50(350) loss:5.449056148529053
# Epoch:17/50(400) loss:5.351757049560547
# Epoch:19/50(450) loss:5.2342000007629395
# Epoch:21/50(500) loss:5.32259464263916
# Epoch:23/50(550) loss:5.2348127365112305
# Epoch:26/50(600) loss:5.214243412017822
# Epoch:28/50(650) loss:5.301619052886963
# Epoch:30/50(700) loss:5.259322166442871
# Epoch:32/50(750) loss:5.243078231811523
# Epoch:34/50(800) loss:5.140893936157227
# Epoch:36/50(850) loss:5.164149284362793
# Epoch:39/50(900) loss:5.116098880767822
# Epoch:41/50(950) loss:5.101504325866699
# Epoch:43/50(1000) loss:5.124959945678711
# Epoch:45/50(1050) loss:5.1166791915893555
# Epoch:47/50(1100) loss:5.10181999206543
# =================  Clustering 1/2  =================
#   ----- get dataset svhn -----
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  88 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=4)]: Done 3000 out of 3000 | elapsed:    6.9s finished
#   ----- get dataset synth -----
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=4)]: Done 2680 tasks      | elapsed:    7.3s
# [Parallel(n_jobs=4)]: Done 3000 out of 3000 | elapsed:    8.6s finished
#   -----  Load Model from record/Digit/CUDA1/svhn_synth_encoder__1/checkpoints/model.pth for clustering  -----
# nmi:0.3097076318781726
# nmi class:0.03780046008371952
# domain_accuracy:0.8088333333333333
#   ----- get dataset svhn -----
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=4)]: Done 2843 tasks      | elapsed:    6.2s
# [Parallel(n_jobs=4)]: Done 3000 out of 3000 | elapsed:    6.5s finished
#   ----- get dataset synth -----
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=4)]: Done 3000 out of 3000 | elapsed:    7.3s finished
#   -----  Load Model from record/Digit/CUDA1/svhn_synth_encoder__1/checkpoints/model.pth for clustering  -----
# nmi:0.3212623877277774
# nmi class:0.036736051020219845
# domain_accuracy:0.8126666666666666
#   ----- get dataset svhn -----
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=4)]: Done 3000 out of 3000 | elapsed:    6.1s finished
#   ----- get dataset synth -----
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=4)]: Done 2680 tasks      | elapsed:    6.0s
# [Parallel(n_jobs=4)]: Done 3000 out of 3000 | elapsed:    6.7s finished
#   -----  Load Model from record/Digit/CUDA1/svhn_synth_encoder__1/checkpoints/model.pth for clustering  -----
# nmi:0.3042340835494399
# nmi class:0.04195755849479764
# domain_accuracy:0.8046666666666666
# ===============================================
# ==============  svhn_synth  ==============
# ===============================================
# Please install apex for mixed precision training from: https://github.com/NVIDIA/apex
#
#     ===============================================
#     =============== svhn_synth ===================
#     ===============================================
#     ---------------------------------------------------------
#         cuda_dir: 1
#         batch_size: 256,  epochs: 50
#         SSL: simclr,  base_model: encoder
#         jigsaw: True,  fourier: False,  grid: 3
#         num_laps: 2, sampling_num: 3000
#         log_dir: record/Digit/CUDA1/svhn_synth_encoder__2
#     ---------------------------------------------------------
#
#
# =================  1/2周目  =================
#   ----- get dataset svhn -----
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  95 tasks      | elapsed:    2.9s
# [Parallel(n_jobs=4)]: Done 3000 out of 3000 | elapsed:    9.0s finished
#   ----- get dataset synth -----
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=4)]: Done 3000 out of 3000 | elapsed:    5.5s finished
# Running on: cuda
# Epoch:0/50(0) loss:6.553130149841309
# Epoch:2/50(50) loss:6.225005626678467
# Epoch:4/50(100) loss:5.968253135681152
# Epoch:6/50(150) loss:5.88740348815918
# Epoch:8/50(200) loss:5.640635967254639
# Epoch:10/50(250) loss:5.756239414215088
# Epoch:13/50(300) loss:5.526808738708496
# Epoch:15/50(350) loss:5.382233142852783
# Epoch:17/50(400) loss:5.330631256103516
# Epoch:19/50(450) loss:5.374921798706055
# Epoch:21/50(500) loss:5.254963397979736
# Epoch:23/50(550) loss:5.330367088317871
# Epoch:26/50(600) loss:5.32684850692749
# Epoch:28/50(650) loss:5.295669078826904
# Epoch:30/50(700) loss:5.231102466583252
# Epoch:32/50(750) loss:5.271481990814209
# Epoch:34/50(800) loss:5.175677299499512
# Epoch:36/50(850) loss:5.173577308654785
# Epoch:39/50(900) loss:5.07526969909668
# Epoch:41/50(950) loss:5.113773822784424
# Epoch:43/50(1000) loss:5.1318817138671875
# Epoch:45/50(1050) loss:5.1257452964782715
# Epoch:47/50(1100) loss:5.130331993103027
# =================  Clustering 1/2  =================
#   ----- get dataset svhn -----
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  68 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=4)]: Done 2380 tasks      | elapsed:    7.4s
# [Parallel(n_jobs=4)]: Done 3000 out of 3000 | elapsed:    8.6s finished
#   ----- get dataset synth -----
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=4)]: Done 3000 out of 3000 | elapsed:    5.9s finished
#   -----  Load Model from record/Digit/CUDA1/svhn_synth_encoder__2/checkpoints/model.pth for clustering  -----
# nmi:0.3263924974682156
# nmi class:0.029826560938439214
# domain_accuracy:0.8175
#   ----- get dataset svhn -----
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=4)]: Done 3000 out of 3000 | elapsed:    5.5s finished
#   ----- get dataset synth -----
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=4)]: Done 3000 out of 3000 | elapsed:    5.8s finished
#   -----  Load Model from record/Digit/CUDA1/svhn_synth_encoder__2/checkpoints/model.pth for clustering  -----
# nmi:0.33628923011832007
# nmi class:0.023642505780813332
# domain_accuracy:0.8201666666666667
#   ----- get dataset svhn -----
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=4)]: Done 3000 out of 3000 | elapsed:    4.5s finished
#   ----- get dataset synth -----
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=4)]: Done 3000 out of 3000 | elapsed:    4.7s finished
#   -----  Load Model from record/Digit/CUDA1/svhn_synth_encoder__2/checkpoints/model.pth for clustering  -----
# nmi:0.31831824195349495
# nmi class:0.02930470252009747
# domain_accuracy:0.8101666666666667
# CPU times: user 10.3 s, sys: 1.25 s, total: 11.6 s
# Wall time: 32min 8s

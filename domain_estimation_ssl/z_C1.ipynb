# %%
# %reset -f
# !rm -fr __pycache__
# !rm -fr */__pycache__

# %% [markdown]
# # Domain Estimation

# %%
from z_common import *

# ファイル特有変数
CUDA_DIR = 1
N_CUDA = 1
spread_message = LOG_TEXT

# %%
# %%time
# PARENT = 'Digit'
# DATA_DOMAIN_LIST = [
#   'svhn_mnist',
#   'svhn_synth',
#   'svhn_synth_mnist',
#   'svhn_synth_mnist_mnistm',
# ]
PARENT = 'Office31'
DATA_DOMAIN_LIST = [
  # 'amazon_dslr_webcam',
  # 'dslr_webcam',
  # 'amazon_dslr',
  'webcam_amazon',
  'webcam_amazon',
]


LAP = 1
NUM_LAPS = 2
log_dir_opt = ''
# log_dir_opt += '__record'
# log_dir_opt += '__jig_const_pha'


for DATA_DOMAIN in DATA_DOMAIN_LIST:
  config, CONFIG_FILE, log_dir = config_to_execute(DATA_DOMAIN, PARENT, CUDA_DIR, log_dir_opt)

  # !rm -fr */__pycache__
  # !CUDA_VISIBLE_DEVICES=$N_CUDA python3 -B run.py --config=$CONFIG_FILE  --log_dir=$log_dir  --num_laps=$NUM_LAPS  --spread_message=$spread_message  --cuda_dir=$CUDA_DIR
# Out:
# ===============================================
# ==============  webcam_amazon  ==============
# ===============================================
# Please install apex for mixed precision training from: https://github.com/NVIDIA/apex
#     ---------------------------------------------------------
#         cuda_dir: 1
#         batch_size: 256,  epochs: 100
#         SSL: simclr,  base_model: encoder
#         jigsaw: True,  fourier: True,  grid: 3
#         num_laps: 2
#     ---------------------------------------------------------
#
#
# =================  1/2周目  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  56 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=4)]: Done 356 tasks      | elapsed:    7.4s
# [Parallel(n_jobs=4)]: Done 788 out of 795 | elapsed:   15.0s remaining:    0.1s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:   15.1s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 128 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=4)]: Done 728 tasks      | elapsed:   12.7s
# [Parallel(n_jobs=4)]: Done 1728 tasks      | elapsed:   30.2s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:   52.6s finished
# Running on: cuda
# Epoch:0/100(0) loss:5.43712854385376
# Epoch:3/100(50) loss:4.983818054199219
# Epoch:7/100(100) loss:4.9409050941467285
# Epoch:10/100(150) loss:4.855093479156494
# Epoch:14/100(200) loss:4.826416015625
# Epoch:17/100(250) loss:4.825715065002441
# Epoch:21/100(300) loss:4.846520900726318
# Epoch:25/100(350) loss:4.803335189819336
# Epoch:28/100(400) loss:4.7602009773254395
# Epoch:32/100(450) loss:4.849360942840576
# Epoch:35/100(500) loss:4.807013034820557
# Epoch:39/100(550) loss:4.774660110473633
# Epoch:42/100(600) loss:4.782380104064941
# Epoch:46/100(650) loss:4.792574882507324
# Epoch:50/100(700) loss:4.756143093109131
# Epoch:53/100(750) loss:4.793491840362549
# Epoch:57/100(800) loss:4.7859272956848145
# Epoch:60/100(850) loss:4.727527618408203
# Epoch:64/100(900) loss:4.766083717346191
# Epoch:67/100(950) loss:4.737768173217773
# Epoch:71/100(1000) loss:4.734175682067871
# Epoch:75/100(1050) loss:4.724867820739746
# Epoch:78/100(1100) loss:4.731588363647461
# Epoch:82/100(1150) loss:4.778278827667236
# Epoch:85/100(1200) loss:4.7705159187316895
# Epoch:89/100(1250) loss:4.749630928039551
# Epoch:92/100(1300) loss:4.69520378112793
# Epoch:96/100(1350) loss:4.727203369140625
# =================  Clustering 1/2  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    3.2s
# [Parallel(n_jobs=4)]: Done 192 tasks      | elapsed:    8.8s
# [Parallel(n_jobs=4)]: Done 500 tasks      | elapsed:   20.8s
# [Parallel(n_jobs=4)]: Done 788 out of 795 | elapsed:   31.3s remaining:    0.3s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:   31.5s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  76 tasks      | elapsed:    2.9s
# [Parallel(n_jobs=4)]: Done 376 tasks      | elapsed:   13.2s
# [Parallel(n_jobs=4)]: Done 876 tasks      | elapsed:   29.5s
# [Parallel(n_jobs=4)]: Done 1576 tasks      | elapsed:   47.4s
# [Parallel(n_jobs=4)]: Done 2476 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=4)]: Done 2810 out of 2817 | elapsed:  1.3min remaining:    0.2s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:  1.3min finished
#   -----  Load Model from record/Office31/CUDA1/wa_encoder for clustering  -----
# nmi:0.06803859503292256
# nmi class:0.18287556313912207
# domain_accuracy:0.6359357696566998
# classs_accuracy:0.035160575858250276
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  76 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=4)]: Done 376 tasks      | elapsed:   11.4s
# [Parallel(n_jobs=4)]: Done 788 out of 795 | elapsed:   23.5s remaining:    0.2s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:   23.6s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  76 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=4)]: Done 376 tasks      | elapsed:   11.3s
# [Parallel(n_jobs=4)]: Done 876 tasks      | elapsed:   24.9s
# [Parallel(n_jobs=4)]: Done 1576 tasks      | elapsed:   45.0s
# [Parallel(n_jobs=4)]: Done 2476 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=4)]: Done 2810 out of 2817 | elapsed:  1.3min remaining:    0.2s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:  1.3min finished
#   -----  Load Model from record/Office31/CUDA1/wa_encoder for clustering  -----
# nmi:0.5587750361708873
# nmi class:0.19121184393375135
# domain_accuracy:0.9238648947951273
# classs_accuracy:0.031284606866002214
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  76 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=4)]: Done 376 tasks      | elapsed:   10.1s
# [Parallel(n_jobs=4)]: Done 788 out of 795 | elapsed:   21.4s remaining:    0.2s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:   21.5s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  76 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=4)]: Done 376 tasks      | elapsed:   10.4s
# [Parallel(n_jobs=4)]: Done 876 tasks      | elapsed:   24.6s
# [Parallel(n_jobs=4)]: Done 1576 tasks      | elapsed:   44.3s
# [Parallel(n_jobs=4)]: Done 2476 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=4)]: Done 2810 out of 2817 | elapsed:  1.3min remaining:    0.2s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:  1.3min finished
#   -----  Load Model from record/Office31/CUDA1/wa_encoder for clustering  -----
# nmi:0.616063889102049
# nmi class:0.1800267075723611
# domain_accuracy:0.05841638981173865
# classs_accuracy:0.0221483942414175
# ===============================================
# ==============  webcam_amazon  ==============
# ===============================================
# Please install apex for mixed precision training from: https://github.com/NVIDIA/apex
#     ---------------------------------------------------------
#         cuda_dir: 1
#         batch_size: 256,  epochs: 100
#         SSL: simclr,  base_model: encoder
#         jigsaw: True,  fourier: True,  grid: 3
#         num_laps: 2
#     ---------------------------------------------------------
#
#
# =================  1/2周目  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  52 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=4)]: Done 352 tasks      | elapsed:    8.1s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:   17.9s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  76 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=4)]: Done 376 tasks      | elapsed:    8.1s
# [Parallel(n_jobs=4)]: Done 876 tasks      | elapsed:   18.7s
# [Parallel(n_jobs=4)]: Done 1576 tasks      | elapsed:   31.3s
# [Parallel(n_jobs=4)]: Done 2476 tasks      | elapsed:   47.6s
# [Parallel(n_jobs=4)]: Done 2810 out of 2817 | elapsed:   53.7s remaining:    0.1s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:   53.8s finished
# Running on: cuda
# Epoch:0/100(0) loss:5.453180313110352
# Epoch:3/100(50) loss:4.961864948272705
# Epoch:7/100(100) loss:4.930587291717529
# Epoch:10/100(150) loss:4.863830089569092
# Epoch:14/100(200) loss:4.855557918548584
# Epoch:17/100(250) loss:4.852166652679443
# Epoch:21/100(300) loss:4.836727619171143
# Epoch:25/100(350) loss:4.820693016052246
# Epoch:28/100(400) loss:4.782191753387451
# Epoch:32/100(450) loss:4.836639404296875
# Epoch:35/100(500) loss:4.786346435546875
# Epoch:39/100(550) loss:4.76423978805542
# Epoch:42/100(600) loss:4.771075248718262
# Epoch:46/100(650) loss:4.770697116851807
# Epoch:50/100(700) loss:4.761600494384766
# Epoch:53/100(750) loss:4.741901874542236
# Epoch:57/100(800) loss:4.774778842926025
# Epoch:60/100(850) loss:4.7219929695129395
# Epoch:64/100(900) loss:4.7600250244140625
# Epoch:67/100(950) loss:4.732761859893799
# Epoch:71/100(1000) loss:4.732661247253418
# Epoch:75/100(1050) loss:4.735278129577637
# Epoch:78/100(1100) loss:4.720721244812012
# Epoch:82/100(1150) loss:4.776423931121826
# Epoch:85/100(1200) loss:4.751110553741455
# Epoch:89/100(1250) loss:4.7365312576293945
# Epoch:92/100(1300) loss:4.683470726013184
# Epoch:96/100(1350) loss:4.70219087600708
# =================  Clustering 1/2  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  76 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=4)]: Done 376 tasks      | elapsed:   11.6s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:   24.7s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  76 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=4)]: Done 376 tasks      | elapsed:    9.1s
# [Parallel(n_jobs=4)]: Done 876 tasks      | elapsed:   21.4s
# [Parallel(n_jobs=4)]: Done 1576 tasks      | elapsed:   36.6s
# [Parallel(n_jobs=4)]: Done 2476 tasks      | elapsed:   53.0s
# [Parallel(n_jobs=4)]: Done 2810 out of 2817 | elapsed:   59.1s remaining:    0.1s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:   59.2s finished
#   -----  Load Model from record/Office31/CUDA1/wa_encoder for clustering  -----
# nmi:0.627298720405457
# nmi class:0.1843777580821236
# domain_accuracy:0.9454595791805094
# classs_accuracy:0.031007751937984496
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  76 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=4)]: Done 376 tasks      | elapsed:    7.3s
# [Parallel(n_jobs=4)]: Done 788 out of 795 | elapsed:   16.0s remaining:    0.1s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:   16.1s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  76 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=4)]: Done 376 tasks      | elapsed:    6.9s
# [Parallel(n_jobs=4)]: Done 876 tasks      | elapsed:   16.0s
# [Parallel(n_jobs=4)]: Done 1576 tasks      | elapsed:   29.4s
# [Parallel(n_jobs=4)]: Done 2476 tasks      | elapsed:   45.3s
# [Parallel(n_jobs=4)]: Done 2810 out of 2817 | elapsed:   51.1s remaining:    0.1s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:   51.3s finished
#   -----  Load Model from record/Office31/CUDA1/wa_encoder for clustering  -----
# nmi:0.582551633743271
# nmi class:0.18879716880045763
# domain_accuracy:0.9313399778516057
# classs_accuracy:0.03488372093023256
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  76 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=4)]: Done 376 tasks      | elapsed:    7.2s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:   15.1s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  76 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=4)]: Done 376 tasks      | elapsed:    6.7s
# [Parallel(n_jobs=4)]: Done 876 tasks      | elapsed:   15.7s
# [Parallel(n_jobs=4)]: Done 1576 tasks      | elapsed:   28.0s
# [Parallel(n_jobs=4)]: Done 2476 tasks      | elapsed:   43.8s
# [Parallel(n_jobs=4)]: Done 2810 out of 2817 | elapsed:   49.6s remaining:    0.1s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:   49.8s finished
#   -----  Load Model from record/Office31/CUDA1/wa_encoder for clustering  -----
# nmi:0.5534304725222321
# nmi class:0.18287110471871068
# domain_accuracy:0.07945736434108527
# classs_accuracy:0.027408637873754152
# CPU times: user 8.31 s, sys: 818 ms, total: 9.13 s
# Wall time: 23min 17s

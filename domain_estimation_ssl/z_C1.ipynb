# %%
# %reset -f
# !rm -fr __pycache__
# !rm -fr */__pycache__

# %% [markdown]
# # Domain Estimation

# %%
from z_common import *

# ファイル特有変数
CUDA_DIR = 1
N_CUDA = 1
spread_message = LOG_TEXT

# %%
# PARENT = 'Digit'
# DATA_DOMAIN_LIST = [
#   'svhn_mnist',
#   'svhn_synth',
#   'svhn_synth_mnist',
#   'svhn_synth_mnist_mnistm',
# ]
PARENT = 'Office31'
DATA_DOMAIN_LIST = [
  # 'amazon_dslr_webcam',
  # 'dslr_webcam',
  # 'amazon_dslr',
  'webcam_amazon',
  'webcam_amazon',
]


LAP = 1
NUM_LAPS = 2
log_dir_opt = ''
# log_dir_opt += '__record'
# log_dir_opt += '__douse'


for DATA_DOMAIN in DATA_DOMAIN_LIST:
  config, CONFIG_FILE, log_dir = config_to_execute(DATA_DOMAIN, PARENT, CUDA_DIR, log_dir_opt)

  # !rm -fr */__pycache__
  # !CUDA_VISIBLE_DEVICES=$N_CUDA python3 -B run.py --config=$CONFIG_FILE  --log_dir=$log_dir  --num_laps=$NUM_LAPS  --spread_message=$spread_message  --cuda_dir=$CUDA_DIR
# Out:
# ===============================================
# ==============  webcam_amazon  ==============
# ===============================================
# Please install apex for mixed precision training from: https://github.com/NVIDIA/apex
#     ---------------------------------------------------------
#         cuda_dir: 1
#         batch_size: 256,  epochs: 100
#         SSL: simclr,  base_model: encoder
#         jigsaw: True,  fourier: True,  grid: 3
#         num_laps: 2,
#     ---------------------------------------------------------
#
#
# =================  1/2周目  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  88 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    5.2s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    7.7s finished
# Running on: cuda
# Epoch:0/100(0) loss:5.367345333099365
# Epoch:3/100(50) loss:4.890944957733154
# Epoch:7/100(100) loss:4.8160600662231445
# Epoch:10/100(150) loss:4.77646017074585
# Epoch:14/100(200) loss:4.759433746337891
# Epoch:17/100(250) loss:4.76958703994751
# Epoch:21/100(300) loss:4.774561882019043
# Epoch:25/100(350) loss:4.735881805419922
# Epoch:28/100(400) loss:4.738803386688232
# Epoch:32/100(450) loss:4.798464298248291
# Epoch:35/100(500) loss:4.738593101501465
# Epoch:39/100(550) loss:4.712455749511719
# Epoch:42/100(600) loss:4.733684539794922
# Epoch:46/100(650) loss:4.722048282623291
# Epoch:50/100(700) loss:4.733058452606201
# Epoch:53/100(750) loss:4.723049640655518
# Epoch:57/100(800) loss:4.731127738952637
# Epoch:60/100(850) loss:4.68731689453125
# Epoch:64/100(900) loss:4.7129316329956055
# Epoch:67/100(950) loss:4.704805850982666
# Epoch:71/100(1000) loss:4.692248344421387
# Epoch:75/100(1050) loss:4.71022891998291
# Epoch:78/100(1100) loss:4.710211753845215
# Epoch:82/100(1150) loss:4.763197422027588
# Epoch:85/100(1200) loss:4.703347206115723
# Epoch:89/100(1250) loss:4.6894659996032715
# Epoch:92/100(1300) loss:4.650146961212158
# Epoch:96/100(1350) loss:4.690488338470459
# =================  Clustering 1/2  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  56 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    6.1s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    7.1s finished
#   -----  Load Model from record/Office31/CUDA1/wa_encoder for clustering  -----
# nmi:0.18742990413704524
# nmi class:0.2272732652426682
# domain_accuracy:0.31146179401993357
# class_accuracy:0.023809523809523808
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 200 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    4.2s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=4)]: Done 2680 tasks      | elapsed:    6.5s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    6.7s finished
#   -----  Load Model from record/Office31/CUDA1/wa_encoder for clustering  -----
# nmi:0.18742990413704524
# nmi class:0.22658442257517555
# domain_accuracy:0.6885382059800664
# class_accuracy:0.02602436323366556
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    3.0s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=4)]: Done 2680 tasks      | elapsed:    6.7s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    6.9s finished
#   -----  Load Model from record/Office31/CUDA1/wa_encoder for clustering  -----
# nmi:0.18742990413704524
# nmi class:0.22485551511423016
# domain_accuracy:0.31146179401993357
# class_accuracy:0.024916943521594685
# ===============================================
# ==============  webcam_amazon  ==============
# ===============================================
# Please install apex for mixed precision training from: https://github.com/NVIDIA/apex
#     ---------------------------------------------------------
#         cuda_dir: 1
#         batch_size: 256,  epochs: 100
#         SSL: simclr,  base_model: encoder
#         jigsaw: True,  fourier: True,  grid: 3
#         num_laps: 2,
#     ---------------------------------------------------------
#
#
# =================  1/2周目  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  68 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    5.1s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=4)]: Done 2680 tasks      | elapsed:    7.0s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    7.4s finished
# Running on: cuda
# Epoch:0/100(0) loss:5.367345333099365
# Epoch:3/100(50) loss:4.890357494354248
# Epoch:7/100(100) loss:4.816287994384766
# Epoch:10/100(150) loss:4.776142120361328
# Epoch:14/100(200) loss:4.757633209228516
# Epoch:17/100(250) loss:4.77335786819458
# Epoch:21/100(300) loss:4.773860931396484
# Epoch:25/100(350) loss:4.735785484313965
# Epoch:28/100(400) loss:4.735658645629883
# Epoch:32/100(450) loss:4.801012992858887
# Epoch:35/100(500) loss:4.738475799560547
# Epoch:39/100(550) loss:4.71209192276001
# Epoch:42/100(600) loss:4.732278823852539
# Epoch:46/100(650) loss:4.718784809112549
# Epoch:50/100(700) loss:4.736974239349365
# Epoch:53/100(750) loss:4.7207112312316895
# Epoch:57/100(800) loss:4.728509426116943
# Epoch:60/100(850) loss:4.689140796661377
# Epoch:64/100(900) loss:4.712123394012451
# Epoch:67/100(950) loss:4.703095436096191
# Epoch:71/100(1000) loss:4.691978454589844
# Epoch:75/100(1050) loss:4.706405162811279
# Epoch:78/100(1100) loss:4.701009750366211
# Epoch:82/100(1150) loss:4.760647773742676
# Epoch:85/100(1200) loss:4.703319549560547
# Epoch:89/100(1250) loss:4.694150447845459
# Epoch:92/100(1300) loss:4.651832580566406
# Epoch:96/100(1350) loss:4.686460494995117
# =================  Clustering 1/2  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  56 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    5.2s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=4)]: Done 2717 tasks      | elapsed:    6.9s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    7.3s finished
#   -----  Load Model from record/Office31/CUDA1/wa_encoder for clustering  -----
# nmi:0.20756110451361234
# nmi class:0.2291554889875
# domain_accuracy:0.6910299003322259
# class_accuracy:0.027131782945736434
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    3.7s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    6.8s finished
#   -----  Load Model from record/Office31/CUDA1/wa_encoder for clustering  -----
# nmi:0.20756110451361234
# nmi class:0.22870166279679363
# domain_accuracy:0.6910299003322259
# class_accuracy:0.020210409745293468
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 168 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    3.2s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    6.5s finished
#   -----  Load Model from record/Office31/CUDA1/wa_encoder for clustering  -----
# nmi:0.20756110451361234
# nmi class:0.22076013796975674
# domain_accuracy:0.3089700996677741
# class_accuracy:0.02131782945736434

# %% [markdown]
# jigsaw + phase const

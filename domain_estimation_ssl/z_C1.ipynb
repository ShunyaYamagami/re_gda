# %%
# %reset -f
# !rm -fr __pycache__
# !rm -fr */__pycache__

# %% [markdown]
# # Domain Estimation

# %%
from z_common import *
import sys
sys.dont_write_bytecode = True  # pycacheを作らないようにする

# ファイル特有変数
CUDA_DIR = 1
N_CUDA = 1
spread_message = LOG_TEXT

# %%
# %%time
# PARENT = 'Digit'
# DATA_DOMAIN_LIST = [
#   'svhn_mnist',
#   'svhn_synth',
#   'svhn_synth_mnist',
#   'svhn_synth_mnist_mnistm',
# ]
PARENT = 'Office31'
DATA_DOMAIN_LIST = [
  # 'amazon_dslr_webcam',
  'dslr_webcam',
  # 'amazon_dslr',
  # 'webcam_amazon',
]


LAP = 1
NUM_LAPS = 2
log_dir_opt = ''
# log_dir_opt += '__record'


for DATA_DOMAIN in DATA_DOMAIN_LIST:
  config, CONFIG_FILE, log_dir = config_to_execute(DATA_DOMAIN, PARENT, CUDA_DIR, log_dir_opt)

  # !rm -fr */__pycache__
  # !CUDA_VISIBLE_DEVICES=$N_CUDA python3 -B run.py --config=$CONFIG_FILE  --log_dir=$log_dir  --num_laps=$NUM_LAPS  --spread_message=$spread_message
# Out:
# ===============================================
# ==============  amazon_dslr  ==============
# ===============================================
# Please install apex for mixed precision training from: https://github.com/NVIDIA/apex
#     ---------------------------------------------------------
#             batch_size: 256,  epochs: 100
#             SSL: simsiam,  base_model: encoder
#             jigsaw: True,  fourier: True,  grid: 3
#             num_laps: 2
#     ---------------------------------------------------------
# =================  1周目  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  48 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=4)]: Done 348 tasks      | elapsed:    9.1s
# [Parallel(n_jobs=4)]: Done 848 tasks      | elapsed:   21.4s
# [Parallel(n_jobs=4)]: Done 1548 tasks      | elapsed:   39.6s
# [Parallel(n_jobs=4)]: Done 2448 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=4)]: Done 2810 out of 2817 | elapsed:  1.2min remaining:    0.2s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:  1.2min finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  76 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=4)]: Done 376 tasks      | elapsed:   12.9s
# [Parallel(n_jobs=4)]: Done 498 out of 498 | elapsed:   17.2s finished
# Running on: cuda
# Epoch:0/100(0) loss:-0.010351207107305527
# Epoch:4/100(50) loss:-0.8479554653167725
# Epoch:8/100(100) loss:-0.8798891305923462
# Epoch:12/100(150) loss:-0.9065468311309814
# Epoch:16/100(200) loss:-0.8833133578300476
# Epoch:20/100(250) loss:-0.8044078350067139
# Epoch:25/100(300) loss:-0.8459311723709106
# Epoch:29/100(350) loss:-0.7539976835250854
# Epoch:33/100(400) loss:-0.8342756032943726
# Epoch:37/100(450) loss:-0.8408291935920715
# Epoch:41/100(500) loss:-0.8465749025344849
# Epoch:45/100(550) loss:-0.8505669236183167
# Epoch:50/100(600) loss:-0.841628909111023
# Epoch:54/100(650) loss:-0.8678558468818665
# Epoch:58/100(700) loss:-0.8741087913513184
# Epoch:62/100(750) loss:-0.8293459415435791
# Epoch:66/100(800) loss:-0.835532546043396
# Epoch:70/100(850) loss:-0.8060758709907532
# Epoch:75/100(900) loss:-0.8206034302711487
# Epoch:79/100(950) loss:-0.8441765308380127
# Epoch:83/100(1000) loss:-0.8383867740631104
# Epoch:87/100(1050) loss:-0.8368958234786987
# Epoch:91/100(1100) loss:-0.8620990514755249
# Epoch:95/100(1150) loss:-0.871487021446228
# =================  Clustering 1  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  76 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=4)]: Done 376 tasks      | elapsed:    9.2s
# [Parallel(n_jobs=4)]: Done 876 tasks      | elapsed:   21.8s
# [Parallel(n_jobs=4)]: Done 1576 tasks      | elapsed:   40.0s
# [Parallel(n_jobs=4)]: Done 2476 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=4)]: Done 2810 out of 2817 | elapsed:  1.2min remaining:    0.2s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:  1.2min finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  76 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=4)]: Done 376 tasks      | elapsed:   11.6s
# [Parallel(n_jobs=4)]: Done 498 out of 498 | elapsed:   15.5s finished
#   -----  Load Model from record/Office31/CUDA1/ad_encoder for clustering  -----
#     -----  Load NMI File from record/Office31/CUDA1/ad_encoder  -----
# nmi:0.15776375977460314
# nmi class:0.1486995519909541
# =================  2周目  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  76 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=4)]: Done 376 tasks      | elapsed:   11.3s
# [Parallel(n_jobs=4)]: Done 876 tasks      | elapsed:   24.7s
# [Parallel(n_jobs=4)]: Done 1576 tasks      | elapsed:   44.2s
# [Parallel(n_jobs=4)]: Done 2476 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=4)]: Done 2810 out of 2817 | elapsed:  1.2min remaining:    0.2s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:  1.2min finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  76 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=4)]: Done 376 tasks      | elapsed:   11.9s
# [Parallel(n_jobs=4)]: Done 498 out of 498 | elapsed:   15.4s finished
# Running on: cuda
#   ----- Loaded pre-trained model from record/Office31/CUDA1/ad_encoder for SSL  -----
# Epoch:0/100(0) loss:-0.8665834665298462
# Epoch:4/100(50) loss:-0.8225801587104797
# Epoch:8/100(100) loss:-0.8505256175994873
# Epoch:12/100(150) loss:-0.8435112237930298
# Epoch:16/100(200) loss:-0.883665919303894
# Epoch:20/100(250) loss:-0.8602134585380554
# Epoch:25/100(300) loss:-0.887201726436615
# Epoch:29/100(350) loss:-0.8253835439682007
# Epoch:33/100(400) loss:-0.8341577053070068
# Epoch:37/100(450) loss:-0.8853062987327576
# Epoch:41/100(500) loss:-0.8704478144645691
# Epoch:45/100(550) loss:-0.8561990261077881
# Epoch:50/100(600) loss:-0.8971503973007202
# Epoch:54/100(650) loss:-0.8877530097961426
# Epoch:58/100(700) loss:-0.8774621486663818
# Epoch:62/100(750) loss:-0.9053474068641663
# Epoch:66/100(800) loss:-0.8669898509979248
# Epoch:70/100(850) loss:-0.8716285228729248
# Epoch:75/100(900) loss:-0.8652547597885132
# Epoch:79/100(950) loss:-0.8634449243545532
# Epoch:83/100(1000) loss:-0.890191376209259
# Epoch:87/100(1050) loss:-0.8615898489952087
# Epoch:91/100(1100) loss:-0.8868606090545654
# Epoch:95/100(1150) loss:-0.8465275764465332
# =================  Clustering 2  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  76 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=4)]: Done 376 tasks      | elapsed:    9.0s
# [Parallel(n_jobs=4)]: Done 876 tasks      | elapsed:   21.5s
# [Parallel(n_jobs=4)]: Done 1576 tasks      | elapsed:   39.2s
# [Parallel(n_jobs=4)]: Done 2476 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=4)]: Done 2810 out of 2817 | elapsed:  1.2min remaining:    0.2s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:  1.2min finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  76 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=4)]: Done 376 tasks      | elapsed:   12.7s
# [Parallel(n_jobs=4)]: Done 498 out of 498 | elapsed:   16.9s finished
#   -----  Load Model from record/Office31/CUDA1/ad_encoder__2 for clustering  -----
#     -----  Load NMI File from record/Office31/CUDA1/ad_encoder__2  -----
# nmi:0.3586386787639432
# nmi class:0.14276306805924938
# record/Office31/CUDA1/ad_encoder__2
# CPU times: user 4.98 s, sys: 558 ms, total: 5.54 s
# Wall time: 12min 34s

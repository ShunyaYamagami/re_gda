# %%
# %reset -f
# !rm -fr __pycache__
# !rm -fr */__pycache__

# %%
from z_common import *

# ファイル特有変数
CUDA_DIR = 0
N_CUDA = 1
spread_message = LOG_TEXT

# %%
# %%time
PARENT = 'Digit'
DATA_DOMAIN_LIST = [
  # 'svhn_mnist',
  'svhn_synth',
  'svhn_synth',
  'svhn_synth',
#   'svhn_synth_mnist',
#   'svhn_synth_mnist_mnistm',
]
# PARENT = 'Office31'
# DATA_DOMAIN_LIST = [
  # 'amazon_dslr_webcam',
  # 'dslr_webcam',
  # 'amazon_dslr',
  # 'webcam_amazon',
# ]


LAP = 1
NUM_LAPS = 2
log_dir_opt = ''
# log_dir_opt += '__record'

counter=0
for DATA_DOMAIN in DATA_DOMAIN_LIST:
  config, CONFIG_FILE, log_dir = config_to_execute(DATA_DOMAIN, PARENT, CUDA_DIR, log_dir_opt)
  log_dir += f'__{counter}'
  counter += 1

  # !rm -fr */__pycache__
  # !CUDA_VISIBLE_DEVICES=$N_CUDA python3 -B run.py --config=$CONFIG_FILE  --log_dir=$log_dir  --num_laps=$NUM_LAPS  --spread_message=$spread_message  --cuda_dir=$CUDA_DIR
# Out:
# ===============================================
# ==============  svhn_synth  ==============
# ===============================================
# Please install apex for mixed precision training from: https://github.com/NVIDIA/apex
#
#     ===============================================
#     =============== svhn_synth ===================
#     ===============================================
#     ---------------------------------------------------------
#         cuda_dir: 0
#         batch_size: 256,  epochs: 50
#         SSL: simclr,  base_model: encoder
#         jigsaw: True,  fourier: False,  grid: 3
#         num_laps: 2, sampling_num: 3000
#         log_dir: record/Digit/CUDA0/svhn_synth_encoder__0__0
#     ---------------------------------------------------------
#
#
# =================  1/2周目  =================
#   ----- get dataset svhn -----
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
#   ------ Augmentation 未選択 -----
# [Parallel(n_jobs=4)]: Done  68 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=4)]: Done 668 tasks      | elapsed:    8.4s
# [Parallel(n_jobs=4)]: Done 1668 tasks      | elapsed:   31.2s
# [Parallel(n_jobs=4)]: Done 3000 out of 3000 | elapsed:   51.6s finished
#   ----- get dataset synth -----
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
#   ------ Augmentation 未選択 -----
# [Parallel(n_jobs=4)]: Done  76 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=4)]: Done 376 tasks      | elapsed:   11.1s
# [Parallel(n_jobs=4)]: Done 876 tasks      | elapsed:   23.6s
# [Parallel(n_jobs=4)]: Done 1576 tasks      | elapsed:   35.7s
# [Parallel(n_jobs=4)]: Done 2476 tasks      | elapsed:   51.3s
# [Parallel(n_jobs=4)]: Done 3000 out of 3000 | elapsed:   59.2s finished
# Running on: cuda
# Epoch:0/50(0) loss:6.500319480895996
# Epoch:2/50(50) loss:5.949878692626953
# Epoch:4/50(100) loss:5.677826881408691
# Epoch:6/50(150) loss:5.659964561462402
# Epoch:8/50(200) loss:5.529535293579102
# Epoch:10/50(250) loss:5.385498523712158
# Epoch:13/50(300) loss:5.411362648010254
# Epoch:15/50(350) loss:5.431879997253418
# Epoch:17/50(400) loss:5.2231316566467285
# Epoch:19/50(450) loss:5.272191047668457
# Epoch:21/50(500) loss:5.156500339508057
# Epoch:23/50(550) loss:5.114095687866211
# Epoch:26/50(600) loss:5.243801116943359
# Epoch:28/50(650) loss:5.235445022583008
# Epoch:30/50(700) loss:5.1830644607543945
# Epoch:32/50(750) loss:5.086525917053223
# Epoch:34/50(800) loss:5.0899553298950195
# Epoch:36/50(850) loss:5.061526298522949
# Epoch:39/50(900) loss:5.074217796325684
# Epoch:41/50(950) loss:5.050758361816406
# Epoch:43/50(1000) loss:5.051220893859863
# Epoch:45/50(1050) loss:5.049014091491699
# Epoch:47/50(1100) loss:5.0756659507751465
# =================  Clustering 1/2  =================
#   ----- get dataset svhn -----
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
#   ------ Augmentation 未選択 -----
# [Parallel(n_jobs=4)]: Done  68 tasks      | elapsed:    2.9s
# [Parallel(n_jobs=4)]: Done 3000 out of 3000 | elapsed:    7.2s finished
#   ----- get dataset synth -----
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
#   ------ Augmentation 未選択 -----
# [Parallel(n_jobs=4)]: Done 128 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=4)]: Done 728 tasks      | elapsed:    5.9s
# [Parallel(n_jobs=4)]: Done 2584 tasks      | elapsed:   28.8s
# [Parallel(n_jobs=4)]: Done 3000 out of 3000 | elapsed:   35.4s finished
#   -----  Load Model from record/Digit/CUDA0/svhn_synth_encoder__0__0/checkpoints/model.pth for clustering  -----
# nmi:0.37993996486033543
# nmi class:0.012868297419512242
# domain_accuracy:0.8408333333333333
#   ----- get dataset svhn -----
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
#   ------ Augmentation 未選択 -----
# [Parallel(n_jobs=4)]: Done 128 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=4)]: Done 760 tasks      | elapsed:    8.6s
# [Parallel(n_jobs=4)]: Done 2971 tasks      | elapsed:   19.0s
# [Parallel(n_jobs=4)]: Done 3000 out of 3000 | elapsed:   19.1s finished
#   ----- get dataset synth -----
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
#   ------ Augmentation 未選択 -----
# [Parallel(n_jobs=4)]: Done 168 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=4)]: Done 1368 tasks      | elapsed:    6.6s
# [Parallel(n_jobs=4)]: Done 3000 out of 3000 | elapsed:   16.3s finished
#   -----  Load Model from record/Digit/CUDA0/svhn_synth_encoder__0__0/checkpoints/model.pth for clustering  -----
# nmi:0.3345334655538071
# nmi class:0.018093896621393744
# domain_accuracy:0.823
#   ----- get dataset svhn -----
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
#   ------ Augmentation 未選択 -----
# [Parallel(n_jobs=4)]: Done 200 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=4)]: Done 2008 tasks      | elapsed:    7.5s
# [Parallel(n_jobs=4)]: Done 3000 out of 3000 | elapsed:   11.6s finished
#   ----- get dataset synth -----
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
#   ------ Augmentation 未選択 -----
# [Parallel(n_jobs=4)]: Done 200 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=4)]: Done 1400 tasks      | elapsed:    8.3s
# [Parallel(n_jobs=4)]: Done 3000 out of 3000 | elapsed:   17.6s finished
#   -----  Load Model from record/Digit/CUDA0/svhn_synth_encoder__0__0/checkpoints/model.pth for clustering  -----
# nmi:0.6849692626678687
# nmi class:0.026394660207657874
# domain_accuracy:0.9423333333333334
# ===============================================
# ==============  svhn_synth  ==============
# ===============================================
# Please install apex for mixed precision training from: https://github.com/NVIDIA/apex
#
#     ===============================================
#     =============== svhn_synth ===================
#     ===============================================
#     ---------------------------------------------------------
#         cuda_dir: 0
#         batch_size: 256,  epochs: 50
#         SSL: simclr,  base_model: encoder
#         jigsaw: True,  fourier: False,  grid: 3
#         num_laps: 2, sampling_num: 3000
#         log_dir: record/Digit/CUDA0/svhn_synth_encoder__0__1
#     ---------------------------------------------------------
#
#
# =================  1/2周目  =================
#   ----- get dataset svhn -----
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 109 tasks      | elapsed:    1.9s
#   ------ Augmentation 未選択 -----
# [Parallel(n_jobs=4)]: Done 3000 out of 3000 | elapsed:    4.4s finished
#   ----- get dataset synth -----
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
#   ------ Augmentation 未選択 -----
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=4)]: Done 3000 out of 3000 | elapsed:    6.0s finished
# Running on: cuda
# Epoch:0/50(0) loss:6.504733085632324
# Epoch:2/50(50) loss:5.931070327758789
# Epoch:4/50(100) loss:5.664489269256592
# Epoch:6/50(150) loss:5.582156181335449
# Epoch:8/50(200) loss:5.43093729019165
# Epoch:10/50(250) loss:5.542484283447266
# Epoch:13/50(300) loss:5.417497158050537
# Epoch:15/50(350) loss:5.350369930267334
# Epoch:17/50(400) loss:5.33604097366333
# Epoch:19/50(450) loss:5.376213073730469
# Epoch:21/50(500) loss:5.290900230407715
# Epoch:23/50(550) loss:5.2507123947143555
# Epoch:26/50(600) loss:5.347050189971924
# Epoch:28/50(650) loss:5.200510025024414
# Epoch:30/50(700) loss:5.155331611633301
# Epoch:32/50(750) loss:5.0961222648620605
# Epoch:34/50(800) loss:5.101100921630859
# Epoch:36/50(850) loss:5.114536762237549
# Epoch:39/50(900) loss:5.065060138702393
# Epoch:41/50(950) loss:5.0993571281433105
# Epoch:43/50(1000) loss:5.030825138092041
# Epoch:45/50(1050) loss:5.054123401641846
# Epoch:47/50(1100) loss:5.023755073547363
# =================  Clustering 1/2  =================
#   ----- get dataset svhn -----
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
#   ------ Augmentation 未選択 -----
# [Parallel(n_jobs=4)]: Done  95 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=4)]: Done 3000 out of 3000 | elapsed:    5.3s finished
#   ----- get dataset synth -----
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
#   ------ Augmentation 未選択 -----
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=4)]: Done 3000 out of 3000 | elapsed:    7.9s finished
#   -----  Load Model from record/Digit/CUDA0/svhn_synth_encoder__0__1/checkpoints/model.pth for clustering  -----
# nmi:0.31151180678690943
# nmi class:0.012449039842159152
# domain_accuracy:0.8103333333333333
#   ----- get dataset svhn -----
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
#   ------ Augmentation 未選択 -----
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=4)]: Done 3000 out of 3000 | elapsed:    5.0s finished
#   ----- get dataset synth -----
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
#   ------ Augmentation 未選択 -----
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=4)]: Done 2680 tasks      | elapsed:    6.4s
# [Parallel(n_jobs=4)]: Done 3000 out of 3000 | elapsed:    7.1s finished
#   -----  Load Model from record/Digit/CUDA0/svhn_synth_encoder__0__1/checkpoints/model.pth for clustering  -----
# nmi:0.2597970608067572
# nmi class:0.021328845757545525
# domain_accuracy:0.79
#   ----- get dataset svhn -----
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
#   ------ Augmentation 未選択 -----
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=4)]: Done 3000 out of 3000 | elapsed:    3.1s finished
#   ----- get dataset synth -----
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
#   ------ Augmentation 未選択 -----
# [Parallel(n_jobs=4)]: Done 144 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=4)]: Done 2982 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=4)]: Done 2993 out of 3000 | elapsed:    4.7s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done 3000 out of 3000 | elapsed:    4.7s finished
#   -----  Load Model from record/Digit/CUDA0/svhn_synth_encoder__0__1/checkpoints/model.pth for clustering  -----
# nmi:0.2605889470079597
# nmi class:0.014014690785285888
# domain_accuracy:0.7875
# ===============================================
# ==============  svhn_synth  ==============
# ===============================================
# Please install apex for mixed precision training from: https://github.com/NVIDIA/apex
#
#     ===============================================
#     =============== svhn_synth ===================
#     ===============================================
#     ---------------------------------------------------------
#         cuda_dir: 0
#         batch_size: 256,  epochs: 50
#         SSL: simclr,  base_model: encoder
#         jigsaw: True,  fourier: False,  grid: 3
#         num_laps: 2, sampling_num: 3000
#         log_dir: record/Digit/CUDA0/svhn_synth_encoder__0__2
#     ---------------------------------------------------------
#
#
# =================  1/2周目  =================
#   ----- get dataset svhn -----
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
#   ------ Augmentation 未選択 -----
# [Parallel(n_jobs=4)]: Done  95 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=4)]: Done 3000 out of 3000 | elapsed:    6.0s finished
#   ----- get dataset synth -----
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
#   ------ Augmentation 未選択 -----
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=4)]: Done 3000 out of 3000 | elapsed:    4.1s finished
# Running on: cuda
# Epoch:0/50(0) loss:6.479278564453125
# Epoch:2/50(50) loss:5.920269012451172
# Epoch:4/50(100) loss:5.682910919189453
# Epoch:6/50(150) loss:5.580774784088135
# Epoch:8/50(200) loss:5.54831075668335
# Epoch:10/50(250) loss:5.298543453216553
# Epoch:13/50(300) loss:5.410760402679443
# Epoch:15/50(350) loss:5.2876482009887695
# Epoch:17/50(400) loss:5.298496246337891
# Epoch:19/50(450) loss:5.23647403717041
# Epoch:21/50(500) loss:5.177288055419922
# Epoch:23/50(550) loss:5.171141624450684
# Epoch:26/50(600) loss:5.517221927642822
# Epoch:28/50(650) loss:5.387589931488037
# Epoch:30/50(700) loss:5.156630516052246
# Epoch:32/50(750) loss:5.158473014831543
# Epoch:34/50(800) loss:5.0570244789123535
# Epoch:36/50(850) loss:5.10026741027832
# Epoch:39/50(900) loss:5.079627513885498
# Epoch:41/50(950) loss:5.039391040802002
# Epoch:43/50(1000) loss:5.073302745819092
# Epoch:45/50(1050) loss:5.061350345611572
# Epoch:47/50(1100) loss:5.034799098968506
# =================  Clustering 1/2  =================
#   ----- get dataset svhn -----
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
#   ------ Augmentation 未選択 -----
# [Parallel(n_jobs=4)]: Done  71 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=4)]: Done 3000 out of 3000 | elapsed:    6.7s finished
#   ----- get dataset synth -----
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
#   ------ Augmentation 未選択 -----
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=4)]: Done 3000 out of 3000 | elapsed:    5.9s finished
#   -----  Load Model from record/Digit/CUDA0/svhn_synth_encoder__0__2/checkpoints/model.pth for clustering  -----
# nmi:0.325640365196326
# nmi class:0.01639171999586304
# domain_accuracy:0.8198333333333333
#   ----- get dataset svhn -----
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
#   ------ Augmentation 未選択 -----
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=4)]: Done 3000 out of 3000 | elapsed:    2.8s finished
#   ----- get dataset synth -----
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
#   ------ Augmentation 未選択 -----
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=4)]: Done 3000 out of 3000 | elapsed:    5.8s finished
#   -----  Load Model from record/Digit/CUDA0/svhn_synth_encoder__0__2/checkpoints/model.pth for clustering  -----
# nmi:0.2915885986426689
# nmi class:0.0193493856855587
# domain_accuracy:0.8035
#   ----- get dataset svhn -----
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
#   ------ Augmentation 未選択 -----
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=4)]: Done 3000 out of 3000 | elapsed:    2.4s finished
#   ----- get dataset synth -----
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
#   ------ Augmentation 未選択 -----
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=4)]: Done 3000 out of 3000 | elapsed:    2.6s finished
#   -----  Load Model from record/Digit/CUDA0/svhn_synth_encoder__0__2/checkpoints/model.pth for clustering  -----
# nmi:0.2899092852878954
# nmi class:0.02799669615908757
# domain_accuracy:0.8011666666666667
# CPU times: user 10.1 s, sys: 1.2 s, total: 11.3 s
# Wall time: 31min 31s

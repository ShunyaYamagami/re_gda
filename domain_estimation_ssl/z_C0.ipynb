# %%
# %reset -f
# !rm -fr __pycache__
# !rm -fr */__pycache__

# %% [markdown]
# # Domain Estimation

# %%
from z_common import *

# ファイル特有変数
CUDA_DIR = 0
N_CUDA = 0
spread_message = LOG_TEXT

# %%
# %%time
# PARENT = 'Digit'
# DATA_DOMAIN_LIST = [
#   'svhn_mnist',
#   'svhn_synth',
#   'svhn_synth_mnist',
#   'svhn_synth_mnist_mnistm',
# ]
PARENT = 'Office31'
DATA_DOMAIN_LIST = [
  # 'amazon_dslr_webcam',
  # 'dslr_webcam',
  'amazon_dslr',
  # 'webcam_amazon',
]


LAP = 1
NUM_LAPS = 1
log_dir_opt = ''
# log_dir_opt += '__record'


for DATA_DOMAIN in DATA_DOMAIN_LIST:
  config, CONFIG_FILE, log_dir = config_to_execute(DATA_DOMAIN, PARENT, CUDA_DIR, log_dir_opt)

  # !rm -fr */__pycache__
  # !CUDA_VISIBLE_DEVICES=$N_CUDA python3 -B run.py --config=$CONFIG_FILE  --log_dir=$log_dir  --num_laps=$NUM_LAPS  --spread_message=$spread_message
# Out:
# ===============================================
# ==============  amazon_dslr  ==============
# ===============================================
# Please install apex for mixed precision training from: https://github.com/NVIDIA/apex
#       ---------------------------------------------------------
#                 batch_size: 256,  epochs: 150
#                 SSL: simclr,  base_model: encoder
#                 jigsaw: True,  fourier: False,  grid: 3
#                 num_laps: 1
#         ---------------------------------------------------------
#
# =================  1/1周目  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  95 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=4)]: Done 2810 out of 2817 | elapsed:    6.8s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    6.8s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 128 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=4)]: Done 498 out of 498 | elapsed:    4.8s finished
# Running on: cuda
# Epoch:0/150(0) loss:5.484674453735352
# Epoch:4/150(50) loss:4.938369274139404
# Epoch:8/150(100) loss:4.8729424476623535
# Epoch:12/150(150) loss:4.854889869689941
# Epoch:16/150(200) loss:4.773019313812256
# Epoch:20/150(250) loss:4.796658992767334
# Epoch:25/150(300) loss:4.8184123039245605
# Epoch:29/150(350) loss:4.778423309326172
# Epoch:33/150(400) loss:4.794101238250732
# Epoch:37/150(450) loss:4.758000373840332
# Epoch:41/150(500) loss:4.792222499847412
# Epoch:45/150(550) loss:4.815060615539551
# Epoch:50/150(600) loss:4.758828163146973
# Epoch:54/150(650) loss:4.752660751342773
# Epoch:58/150(700) loss:4.738889694213867
# Epoch:62/150(750) loss:4.750555992126465
# Epoch:66/150(800) loss:4.776016712188721
# Epoch:70/150(850) loss:4.7670087814331055
# Epoch:75/150(900) loss:4.775739669799805
# Epoch:79/150(950) loss:4.708251476287842
# Epoch:83/150(1000) loss:4.724318981170654
# Epoch:87/150(1050) loss:4.738173961639404
# Epoch:91/150(1100) loss:4.742154121398926
# Epoch:95/150(1150) loss:4.731680870056152
# Epoch:100/150(1200) loss:4.722112655639648

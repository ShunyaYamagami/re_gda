# %%
# %reset -f
# !rm -fr __pycache__
# !rm -fr */__pycache__

# %% [markdown]
# # Domain Estimation

# %%
from z_common import *

# ファイル特有変数
CUDA_DIR = 0
N_CUDA = 1
spread_message = LOG_TEXT

# %%
# %%time
# PARENT = 'Digit'
# DATA_DOMAIN_LIST = [
#   'svhn_mnist',
#   'svhn_synth',
#   'svhn_synth_mnist',
#   'svhn_synth_mnist_mnistm',
# ]
PARENT = 'Office31'
DATA_DOMAIN_LIST = [
  # 'amazon_dslr_webcam',
  # 'dslr_webcam',
  # 'amazon_dslr',
  'webcam_amazon',
  'webcam_amazon',
  'webcam_amazon',
]


LAP = 1
NUM_LAPS = 2
log_dir_opt = ''
# log_dir_opt += '__record'
# log_dir_opt += '__douse'


for DATA_DOMAIN in DATA_DOMAIN_LIST:
  config, CONFIG_FILE, log_dir = config_to_execute(DATA_DOMAIN, PARENT, CUDA_DIR, log_dir_opt)

  # !rm -fr */__pycache__
  # !CUDA_VISIBLE_DEVICES=$N_CUDA python3 -B run.py --config=$CONFIG_FILE  --log_dir=$log_dir  --num_laps=$NUM_LAPS  --spread_message=$spread_message  --cuda_dir=$CUDA_DIR
# Out:
# ===============================================
# ==============  webcam_amazon  ==============
# ===============================================
# Please install apex for mixed precision training from: https://github.com/NVIDIA/apex
#     ---------------------------------------------------------
#         batch_size: 256,  epochs: 100
#         SSL: simclr,  base_model: encoder
#         jigsaw: True,  fourier: True,  grid: 3
#         num_laps: 2
#     ---------------------------------------------------------
#
#
# =================  1/2周目  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    4.3s
# [Parallel(n_jobs=4)]: Done 308 tasks      | elapsed:   15.9s
# [Parallel(n_jobs=4)]: Done 788 out of 795 | elapsed:   43.3s remaining:    0.4s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:   43.7s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  76 tasks      | elapsed:    4.4s
# [Parallel(n_jobs=4)]: Done 376 tasks      | elapsed:   21.9s
# [Parallel(n_jobs=4)]: Done 876 tasks      | elapsed:   50.5s
# [Parallel(n_jobs=4)]: Done 1576 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=4)]: Done 2476 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=4)]: Done 2810 out of 2817 | elapsed:  2.6min remaining:    0.4s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:  2.6min finished
# Running on: cuda
# Epoch:0/100(0) loss:5.47594690322876
# Epoch:3/100(50) loss:5.054919719696045
# Epoch:7/100(100) loss:5.0501556396484375
# Epoch:10/100(150) loss:4.943391799926758
# Epoch:14/100(200) loss:4.920466899871826
# Epoch:17/100(250) loss:4.921450138092041
# Epoch:21/100(300) loss:4.882721424102783
# Epoch:25/100(350) loss:4.905268669128418
# Epoch:28/100(400) loss:4.881046772003174
# Epoch:32/100(450) loss:4.944364547729492
# Epoch:35/100(500) loss:4.849242687225342
# Epoch:39/100(550) loss:4.903836250305176
# Epoch:42/100(600) loss:4.883684158325195
# Epoch:46/100(650) loss:4.864299297332764
# Epoch:50/100(700) loss:4.866565227508545
# Epoch:53/100(750) loss:4.801149845123291
# Epoch:57/100(800) loss:4.90675687789917
# Epoch:60/100(850) loss:4.8303303718566895
# Epoch:64/100(900) loss:4.833926200866699
# Epoch:67/100(950) loss:4.814693450927734
# Epoch:71/100(1000) loss:4.833350658416748
# Epoch:75/100(1050) loss:4.815535545349121
# Epoch:78/100(1100) loss:4.838589191436768
# Epoch:82/100(1150) loss:4.8405046463012695
# Epoch:85/100(1200) loss:4.83433198928833
# Epoch:89/100(1250) loss:4.806081771850586
# Epoch:92/100(1300) loss:4.767932891845703
# Epoch:96/100(1350) loss:4.822390556335449
# =================  Clustering 1/2  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    6.2s
# [Parallel(n_jobs=4)]: Done 192 tasks      | elapsed:   15.3s
# [Parallel(n_jobs=4)]: Done 442 tasks      | elapsed:   29.8s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:   50.9s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  76 tasks      | elapsed:    4.1s
# [Parallel(n_jobs=4)]: Done 376 tasks      | elapsed:   21.5s
# [Parallel(n_jobs=4)]: Done 876 tasks      | elapsed:   50.1s
# [Parallel(n_jobs=4)]: Done 1576 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=4)]: Done 2476 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=4)]: Done 2810 out of 2817 | elapsed:  2.6min remaining:    0.4s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:  2.6min finished
#   -----  Load Model from record/Office31/CUDA0/wa_encoder for clustering  -----
#   -----  Load NMI File from record/Office31/CUDA0/wa_encoder  -----
# nmi:0.5175838054753246
# nmi class:0.15732864568471053
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  76 tasks      | elapsed:    5.7s
# [Parallel(n_jobs=4)]: Done 376 tasks      | elapsed:   25.1s
# [Parallel(n_jobs=4)]: Done 788 out of 795 | elapsed:   48.4s remaining:    0.4s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:   48.7s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  76 tasks      | elapsed:    4.8s
# [Parallel(n_jobs=4)]: Done 376 tasks      | elapsed:   20.2s
# [Parallel(n_jobs=4)]: Done 876 tasks      | elapsed:   48.3s
# [Parallel(n_jobs=4)]: Done 1576 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=4)]: Done 2476 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=4)]: Done 2810 out of 2817 | elapsed:  2.6min remaining:    0.4s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:  2.6min finished
#   -----  Load Model from record/Office31/CUDA0/wa_encoder for clustering  -----
#   -----  Load NMI File from record/Office31/CUDA0/wa_encoder  -----
# nmi:0.30922938648419623
# nmi class:0.1586246029171795
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  76 tasks      | elapsed:    5.0s
# [Parallel(n_jobs=4)]: Done 376 tasks      | elapsed:   26.3s
# [Parallel(n_jobs=4)]: Done 788 out of 795 | elapsed:   51.4s remaining:    0.5s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:   51.7s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    3.3s
# [Parallel(n_jobs=4)]: Done 192 tasks      | elapsed:   13.5s
# [Parallel(n_jobs=4)]: Done 442 tasks      | elapsed:   30.0s
# [Parallel(n_jobs=4)]: Done 792 tasks      | elapsed:   52.6s
# [Parallel(n_jobs=4)]: Done 1242 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=4)]: Done 1792 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=4)]: Done 2810 out of 2817 | elapsed:  3.0min remaining:    0.4s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:  3.0min finished
#   -----  Load Model from record/Office31/CUDA0/wa_encoder for clustering  -----

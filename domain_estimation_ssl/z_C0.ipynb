# %%
# %reset -f
# !rm -fr __pycache__
# !rm -fr */__pycache__

# %% [markdown]
# # Domain Estimation

# %%
from z_common import *
import sys
sys.dont_write_bytecode = True  # pycacheを作らないようにする

# ファイル特有変数
CUDA_DIR = 0
N_CUDA = 0
spread_message = LOG_TEXT

# %%
# %%time
########## Change here! ##########
# PARENT = 'Digit'
# DATA_DOMAIN_LIST = [
#   'svhn_mnist',
#   'svhn_synth',
#   'svhn_synth_mnist',
#   'svhn_synth_mnist_mnistm',
# ]
PARENT = 'Office31'
DATA_DOMAIN_LIST = [
  # 'amazon_dslr_webcam',
  'dslr_webcam',
  'amazon_dslr',
  'webcam_amazon',
]

LAP = 1
SECOND_FLAG = 1
log_dir_opt = ''
# log_dir_opt += '__record'

try:
  start_time = time()
  for DATA_DOMAIN in DATA_DOMAIN_LIST:
    config, CONFIG_FILE, log_dir = config_to_execute(DATA_DOMAIN, PARENT, CUDA_DIR, log_dir_opt)

    # !rm -fr */__pycache__
    # !CUDA_VISIBLE_DEVICES=$N_CUDA python3 -B run.py --config=$CONFIG_FILE  --log_dir=$log_dir  --lap=$LAP  --second_flag=$SECOND_FLAG

    log_spread_sheet(config, log_dir, DATA_DOMAIN, spread_message)

  end_time = time()
  send_email(not_error=True, body_text=f'実行終了. 実行時間: {(end_time-start_time)/60:.2f} 分', config=config, log_dir=log_dir, DATA_DOMAIN=DATA_DOMAIN)
except:
  error_message=traceback.format_exc()
  send_email(not_error=False, error_message=error_message)
# Out:
# ===============================================
# ==============  dslr_webcam  ==============
# ===============================================
# Please install apex for mixed precision training from: https://github.com/NVIDIA/apex
#     ---------------------------------------------------------
#             batch_size: 512,  epochs: 150
#             SSL: simclr,  base_model: encoder
#             jigsaw: True,  fourier: False
#             lap: 1,  second_flag: 1
#     ---------------------------------------------------------
# ================= 2周目 =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  88 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=4)]: Done 498 out of 498 | elapsed:    3.6s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    2.0s finished
# Running on: cuda
#   -----  Load Model from record/Office31/CUDA0/dw_encoder__edls for SSL  -----
# Loaded pre-trained model with success.
#   ----- Load record/Office31/CUDA0/dw_encoder -----
# Epoch:0/150(0) loss:5.407904624938965
# Epoch:25/150(50) loss:5.395030498504639
# Epoch:50/150(100) loss:5.392204284667969
# Epoch:75/150(150) loss:5.391969203948975
# Epoch:100/150(200) loss:5.341320991516113
# Epoch:125/150(250) loss:5.360981464385986
# ================= Clustering 2 =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 200 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=4)]: Done 498 out of 498 | elapsed:    2.5s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    1.9s finished
#   -----  Load Model from record/Office31/CUDA0/dw_encoder__edls for clustering  -----
# nmi:0.6654102974724212
# nmi class:0.3874994271046426
# ===============================================
# ==============  amazon_dslr  ==============
# ===============================================
# Please install apex for mixed precision training from: https://github.com/NVIDIA/apex
#     ---------------------------------------------------------
#             batch_size: 512,  epochs: 150
#             SSL: simclr,  base_model: encoder
#             jigsaw: True,  fourier: True
#             lap: 1,  second_flag: 1
#     ---------------------------------------------------------
# ================= 2周目 =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  56 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=4)]: Done 356 tasks      | elapsed:    7.9s
# [Parallel(n_jobs=4)]: Done 856 tasks      | elapsed:   17.5s
# [Parallel(n_jobs=4)]: Done 1556 tasks      | elapsed:   30.8s
# [Parallel(n_jobs=4)]: Done 2456 tasks      | elapsed:   47.7s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:   54.6s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  76 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=4)]: Done 376 tasks      | elapsed:    8.5s
# [Parallel(n_jobs=4)]: Done 498 out of 498 | elapsed:   11.2s finished
# Running on: cuda
#   -----  Load Model from record/Office31/CUDA0/ad_encoder__edls for SSL  -----
# Loaded pre-trained model with success.
#   ----- Load record/Office31/CUDA0/ad_encoder -----
# Epoch:0/150(0) loss:5.381200313568115
# Epoch:8/150(50) loss:5.381163597106934
# Epoch:16/150(100) loss:5.38738489151001
# Epoch:25/150(150) loss:5.345395565032959
# Epoch:33/150(200) loss:5.357776165008545
# Epoch:41/150(250) loss:5.354438304901123
# Epoch:50/150(300) loss:5.363226413726807
# Epoch:58/150(350) loss:5.376462459564209
# Epoch:66/150(400) loss:5.338649272918701

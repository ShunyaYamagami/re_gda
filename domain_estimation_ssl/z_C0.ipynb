# %%
# %reset -f
# !rm -fr __pycache__
# !rm -fr */__pycache__

# %% [markdown]
# # Domain Estimation

# %%
from z_common import *

# ファイル特有変数
CUDA_DIR = 0
N_CUDA = 0
spread_message = LOG_TEXT

# %%
# PARENT = 'Digit'
# DATA_DOMAIN_LIST = [
#   'svhn_mnist',
#   'svhn_synth',
#   'svhn_synth_mnist',
#   'svhn_synth_mnist_mnistm',
# ]
PARENT = 'Office31'
DATA_DOMAIN_LIST = [
  # 'amazon_dslr_webcam',
  # 'dslr_webcam',
  # 'amazon_dslr',
  'webcam_amazon',
  'webcam_amazon',
  'webcam_amazon',
]


LAP = 1
NUM_LAPS = 2
log_dir_opt = ''
# log_dir_opt += '__record'
# log_dir_opt += '__douse'


for DATA_DOMAIN in DATA_DOMAIN_LIST:
  config, CONFIG_FILE, log_dir = config_to_execute(DATA_DOMAIN, PARENT, CUDA_DIR, log_dir_opt)

  # !rm -fr */__pycache__
  # !CUDA_VISIBLE_DEVICES=$N_CUDA python3 -B run.py --config=$CONFIG_FILE  --log_dir=$log_dir  --num_laps=$NUM_LAPS  --spread_message=$spread_message  --cuda_dir=$CUDA_DIR
# Out:
# ===============================================
# ==============  webcam_amazon  ==============
# ===============================================
# Please install apex for mixed precision training from: https://github.com/NVIDIA/apex
#     ---------------------------------------------------------
#         cuda_dir: 0
#         batch_size: 256,  epochs: 100
#         SSL: simclr,  base_model: encoder
#         jigsaw: True,  fourier: True,  grid: 3
#         num_laps: 2,
#     ---------------------------------------------------------
#
#
# =================  1/2周目  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  68 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    4.9s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=4)]: Done 2680 tasks      | elapsed:    7.5s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    7.9s finished
# Running on: cuda
# Epoch:0/100(0) loss:5.367345333099365
# Epoch:3/100(50) loss:4.888021945953369
# Epoch:7/100(100) loss:4.817391872406006
# Epoch:10/100(150) loss:4.776425361633301
# Epoch:14/100(200) loss:4.759066581726074
# Epoch:17/100(250) loss:4.768314838409424
# Epoch:21/100(300) loss:4.773324489593506
# Epoch:25/100(350) loss:4.739725112915039
# Epoch:28/100(400) loss:4.736234188079834
# Epoch:32/100(450) loss:4.800896167755127
# Epoch:35/100(500) loss:4.738549709320068
# Epoch:39/100(550) loss:4.710488319396973
# Epoch:42/100(600) loss:4.731989860534668
# Epoch:46/100(650) loss:4.716554164886475
# Epoch:50/100(700) loss:4.731853008270264
# Epoch:53/100(750) loss:4.719075679779053
# Epoch:57/100(800) loss:4.727656841278076
# Epoch:60/100(850) loss:4.685549259185791
# Epoch:64/100(900) loss:4.714818000793457
# Epoch:67/100(950) loss:4.705999374389648
# Epoch:71/100(1000) loss:4.688891887664795
# Epoch:75/100(1050) loss:4.708596706390381
# Epoch:78/100(1100) loss:4.70762825012207
# Epoch:82/100(1150) loss:4.7622151374816895
# Epoch:85/100(1200) loss:4.701231002807617
# Epoch:89/100(1250) loss:4.692707538604736
# Epoch:92/100(1300) loss:4.652543067932129
# Epoch:96/100(1350) loss:4.689173698425293
# =================  Clustering 1/2  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  59 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    6.0s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=4)]: Done 2680 tasks      | elapsed:    7.1s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    7.3s finished
#   -----  Load Model from record/Office31/CUDA0/wa_encoder for clustering  -----
# nmi:0.16446344036056176
# nmi class:0.2307822694954231
# domain_accuracy:0.6558693244739756
# class_accuracy:0.033776301218161685
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    3.9s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=4)]: Done 2680 tasks      | elapsed:    7.3s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    7.6s finished
#   -----  Load Model from record/Office31/CUDA0/wa_encoder for clustering  -----
# nmi:0.16446344036056176
# nmi class:0.23182828871628866
# domain_accuracy:0.6558693244739756
# class_accuracy:0.044850498338870434
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    3.6s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=4)]: Done 2680 tasks      | elapsed:    7.1s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    7.3s finished
#   -----  Load Model from record/Office31/CUDA0/wa_encoder for clustering  -----
# nmi:0.16446344036056176
# nmi class:0.23613485942418622
# domain_accuracy:0.6558693244739756
# class_accuracy:0.021040974529346623
# ===============================================
# ==============  webcam_amazon  ==============
# ===============================================
# Please install apex for mixed precision training from: https://github.com/NVIDIA/apex
#     ---------------------------------------------------------
#         cuda_dir: 0
#         batch_size: 256,  epochs: 100
#         SSL: simclr,  base_model: encoder
#         jigsaw: True,  fourier: True,  grid: 3
#         num_laps: 2,
#     ---------------------------------------------------------
#
#
# =================  1/2周目  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  88 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    5.1s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=4)]: Done 2680 tasks      | elapsed:    6.8s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    7.1s finished
# Running on: cuda
# Epoch:0/100(0) loss:5.367345333099365
# Epoch:3/100(50) loss:4.888289928436279
# Epoch:7/100(100) loss:4.817394733428955
# Epoch:10/100(150) loss:4.774456024169922
# Epoch:14/100(200) loss:4.759549140930176
# Epoch:17/100(250) loss:4.769399166107178
# Epoch:21/100(300) loss:4.772907257080078
# Epoch:25/100(350) loss:4.736583709716797
# Epoch:28/100(400) loss:4.738533020019531
# Epoch:32/100(450) loss:4.800114154815674
# Epoch:35/100(500) loss:4.737796306610107
# Epoch:39/100(550) loss:4.711139678955078
# Epoch:42/100(600) loss:4.732409954071045
# Epoch:46/100(650) loss:4.722277641296387
# Epoch:50/100(700) loss:4.737898349761963
# Epoch:53/100(750) loss:4.721432209014893
# Epoch:57/100(800) loss:4.731505870819092
# Epoch:60/100(850) loss:4.689334869384766
# Epoch:64/100(900) loss:4.710583686828613
# Epoch:67/100(950) loss:4.702276706695557
# Epoch:71/100(1000) loss:4.689521789550781
# Epoch:75/100(1050) loss:4.707956790924072
# Epoch:78/100(1100) loss:4.701822757720947
# Epoch:82/100(1150) loss:4.76099157333374
# Epoch:85/100(1200) loss:4.699295520782471
# Epoch:89/100(1250) loss:4.69296407699585
# Epoch:92/100(1300) loss:4.649594783782959
# Epoch:96/100(1350) loss:4.687331199645996
# =================  Clustering 1/2  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  68 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    5.8s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=4)]: Done 2680 tasks      | elapsed:    6.9s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    7.2s finished
#   -----  Load Model from record/Office31/CUDA0/wa_encoder for clustering  -----
# nmi:0.19733907074205406
# nmi class:0.2344385924328804
# domain_accuracy:0.6730343300110742
# class_accuracy:0.03571428571428571
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 224 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    3.6s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=4)]: Done 2680 tasks      | elapsed:    6.7s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    7.0s finished
#   -----  Load Model from record/Office31/CUDA0/wa_encoder for clustering  -----
# nmi:0.19733907074205406
# nmi class:0.22716384661664774
# domain_accuracy:0.6730343300110742
# class_accuracy:0.031007751937984496
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 200 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    3.6s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    6.6s finished
#   -----  Load Model from record/Office31/CUDA0/wa_encoder for clustering  -----
# nmi:0.1971241671496564
# nmi class:0.23857272027026075
# domain_accuracy:0.3272425249169435
# class_accuracy:0.032668881506090805
# ===============================================
# ==============  webcam_amazon  ==============
# ===============================================
# Please install apex for mixed precision training from: https://github.com/NVIDIA/apex
#     ---------------------------------------------------------
#         cuda_dir: 0
#         batch_size: 256,  epochs: 100
#         SSL: simclr,  base_model: encoder
#         jigsaw: True,  fourier: True,  grid: 3
#         num_laps: 2,
#     ---------------------------------------------------------
#
#
# =================  1/2周目  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  68 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    4.8s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=4)]: Done 2680 tasks      | elapsed:    6.3s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    6.7s finished
# Running on: cuda
# Epoch:0/100(0) loss:5.367345333099365
# Epoch:3/100(50) loss:4.890304088592529
# Epoch:7/100(100) loss:4.816318035125732
# Epoch:10/100(150) loss:4.7768683433532715
# Epoch:14/100(200) loss:4.758714199066162
# Epoch:17/100(250) loss:4.772546768188477
# Epoch:21/100(300) loss:4.774621486663818
# Epoch:25/100(350) loss:4.735596179962158
# Epoch:28/100(400) loss:4.736818313598633
# Epoch:32/100(450) loss:4.797143936157227
# Epoch:35/100(500) loss:4.737349987030029
# Epoch:39/100(550) loss:4.711495876312256
# Epoch:42/100(600) loss:4.732746124267578
# Epoch:46/100(650) loss:4.721238136291504
# Epoch:50/100(700) loss:4.7348737716674805
# Epoch:53/100(750) loss:4.7241010665893555
# Epoch:57/100(800) loss:4.728610038757324
# Epoch:60/100(850) loss:4.6860456466674805
# Epoch:64/100(900) loss:4.713192939758301
# Epoch:67/100(950) loss:4.703457832336426
# Epoch:71/100(1000) loss:4.6907477378845215
# Epoch:75/100(1050) loss:4.708070278167725
# Epoch:78/100(1100) loss:4.702585220336914
# Epoch:82/100(1150) loss:4.7657599449157715
# Epoch:85/100(1200) loss:4.699251174926758
# Epoch:89/100(1250) loss:4.693578243255615
# Epoch:92/100(1300) loss:4.648383140563965
# Epoch:96/100(1350) loss:4.689466953277588
# =================  Clustering 1/2  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  56 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    5.8s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    6.5s finished
#   -----  Load Model from record/Office31/CUDA0/wa_encoder for clustering  -----
# nmi:0.19564377381960893
# nmi class:0.22558424178086675
# domain_accuracy:0.6722037652270211
# class_accuracy:0.03239202657807309
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 152 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    3.6s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=4)]: Done 2680 tasks      | elapsed:    6.4s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    6.6s finished
#   -----  Load Model from record/Office31/CUDA0/wa_encoder for clustering  -----
# nmi:0.19564377381960896
# nmi class:0.23117355833182443
# domain_accuracy:0.327796234772979
# class_accuracy:0.046511627906976744
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 200 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    3.8s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    7.6s finished
#   -----  Load Model from record/Office31/CUDA0/wa_encoder for clustering  -----
# nmi:0.19564377381960896
# nmi class:0.22788932819600174
# domain_accuracy:0.327796234772979
# class_accuracy:0.02159468438538206

# %% [markdown]
# jigsaw + mask + phase const

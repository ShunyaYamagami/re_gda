# %%
# %reset -f
# !rm -fr __pycache__
# !rm -fr */__pycache__

# %% [markdown]
# # Domain Estimation

# %%
from z_common import *

# ファイル特有変数
CUDA_DIR = 0
N_CUDA = 0
spread_message = LOG_TEXT

# %%
# %%time
# PARENT = 'Digit'
# DATA_DOMAIN_LIST = [
#   'svhn_mnist',
#   'svhn_synth',
#   'svhn_synth_mnist',
#   'svhn_synth_mnist_mnistm',
# ]
PARENT = 'Office31'
DATA_DOMAIN_LIST = [
  # 'amazon_dslr_webcam',
  'dslr_webcam',
  # 'amazon_dslr',
  # 'webcam_amazon',
]


LAP = 1
NUM_LAPS = 3
log_dir_opt = ''
# log_dir_opt += '__record'


for DATA_DOMAIN in DATA_DOMAIN_LIST:
  config, CONFIG_FILE, log_dir = config_to_execute(DATA_DOMAIN, PARENT, CUDA_DIR, log_dir_opt)

  # !rm -fr */__pycache__
  # !CUDA_VISIBLE_DEVICES=$N_CUDA python3 -B run.py --config=$CONFIG_FILE  --log_dir=$log_dir  --num_laps=$NUM_LAPS  --spread_message=$spread_message
# Out:
# ===============================================
# ==============  dslr_webcam  ==============
# ===============================================
# Please install apex for mixed precision training from: https://github.com/NVIDIA/apex
#     ---------------------------------------------------------
#         batch_size: 256,  epochs: 100
#         SSL: simclr,  base_model: encoder
#         jigsaw: True,  fourier: False,  grid: 3
#         num_laps: 3
#     ---------------------------------------------------------
#
# =================  2/3周目  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  88 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=4)]: Done 498 out of 498 | elapsed:    3.6s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    2.0s finished
# Running on: cuda
#   ----- Loaded pre-trained model from record/Office31/CUDA0/dw_encoder for SSL  -----
# Epoch:0/100(0) loss:4.689112663269043
# Epoch:10/100(50) loss:4.598536014556885
# Epoch:20/100(100) loss:4.590320110321045
# Epoch:30/100(150) loss:4.596408843994141
# Epoch:40/100(200) loss:4.555199146270752
# Epoch:50/100(250) loss:4.552877902984619
# Epoch:60/100(300) loss:4.602253437042236
# Epoch:70/100(350) loss:4.542793273925781
# Epoch:80/100(400) loss:4.534023761749268
# Epoch:90/100(450) loss:4.539684772491455
# =================  Clustering 2/3  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 128 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=4)]: Done 498 out of 498 | elapsed:    5.9s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 200 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    3.3s finished
#   -----  Load Model from record/Office31/CUDA0/dw_encoder__2 for clustering  -----
#   -----  Load NMI File from record/Office31/CUDA0/dw_encoder__2  -----
# nmi:0.6187136947210073
# nmi class:0.37143327642140483
# =================  3/3周目  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 128 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=4)]: Done 498 out of 498 | elapsed:    3.9s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 216 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    2.7s finished
# Running on: cuda
#   ----- Loaded pre-trained model from record/Office31/CUDA0/dw_encoder__2 for SSL  -----
# Epoch:0/100(0) loss:4.543887615203857
# Epoch:10/100(50) loss:4.538906574249268
# Epoch:20/100(100) loss:4.555092811584473
# Epoch:30/100(150) loss:4.538657188415527
# Epoch:40/100(200) loss:4.562061309814453
# Epoch:50/100(250) loss:4.5646138191223145
# Epoch:60/100(300) loss:4.526108741760254
# Epoch:70/100(350) loss:4.554577827453613
# Epoch:80/100(400) loss:4.521578311920166
# Epoch:90/100(450) loss:4.520655155181885
# =================  Clustering 3/3  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 136 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=4)]: Done 498 out of 498 | elapsed:    4.7s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    2.6s finished
#   -----  Load Model from record/Office31/CUDA0/dw_encoder__2__3 for clustering  -----
#   -----  Load NMI File from record/Office31/CUDA0/dw_encoder__2__3  -----
# nmi:0.5754703473752503
# nmi class:0.39402506543846416
# CPU times: user 2.11 s, sys: 207 ms, total: 2.31 s
# Wall time: 6min 17s

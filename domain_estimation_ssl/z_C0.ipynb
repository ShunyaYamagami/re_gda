# %%
# %reset -f
# !rm -fr __pycache__
# !rm -fr */__pycache__

# %% [markdown]
# # Domain Estimation

# %%
from z_common import *

# ファイル特有変数
CUDA_DIR = 2
N_CUDA = 2
spread_message = LOG_TEXT

# %%
# %%time
# PARENT = 'Digit'
# DATA_DOMAIN_LIST = [
#   'svhn_mnist',
#   'svhn_synth',
#   'svhn_synth_mnist',
#   'svhn_synth_mnist_mnistm',
# ]
PARENT = 'Office31'
DATA_DOMAIN_LIST = [
  # 'amazon_dslr_webcam',
  'dslr_webcam',
  'amazon_dslr',
  'webcam_amazon',
]


LAP = 1
NUM_LAPS = 1
log_dir_opt = ''
# log_dir_opt += '__record'


for DATA_DOMAIN in DATA_DOMAIN_LIST:
  config, CONFIG_FILE, log_dir = config_to_execute(DATA_DOMAIN, PARENT, CUDA_DIR, log_dir_opt)

  # !rm -fr */__pycache__
  # !CUDA_VISIBLE_DEVICES=$N_CUDA python3 -B run.py --config=$CONFIG_FILE  --log_dir=$log_dir  --num_laps=$NUM_LAPS  --spread_message=$spread_message
# Out:
# ===============================================
# ==============  dslr_webcam  ==============
# ===============================================
# Please install apex for mixed precision training from: https://github.com/NVIDIA/apex
#       ---------------------------------------------------------
#                 batch_size: 256,  epochs: 150
#                 SSL: simclr,  base_model: encoder
#                 jigsaw: True,  fourier: False,  grid: 3
#                 num_laps: 1
#         ---------------------------------------------------------
#
# =================  1/1周目  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  88 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=4)]: Done 498 out of 498 | elapsed:    3.7s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    2.3s finished
# Running on: cuda
# Epoch:0/150(0) loss:5.29253625869751
# Epoch:10/150(50) loss:4.8982625007629395
# Epoch:20/150(100) loss:4.846238136291504
# Epoch:30/150(150) loss:4.819129467010498
# Epoch:40/150(200) loss:4.766631126403809
# Epoch:50/150(250) loss:4.76630973815918
# Epoch:60/150(300) loss:4.79314661026001
# Epoch:70/150(350) loss:4.757192611694336
# Epoch:80/150(400) loss:4.73978853225708
# Epoch:90/150(450) loss:4.7349982261657715
# Epoch:100/150(500) loss:4.743641376495361
# Epoch:110/150(550) loss:4.729066371917725
# Epoch:120/150(600) loss:4.706766128540039
# Epoch:130/150(650) loss:4.792259693145752
# Epoch:140/150(700) loss:4.755805015563965
# =================  Clustering 1/1  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 200 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=4)]: Done 498 out of 498 | elapsed:    3.0s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    2.3s finished
#   -----  Load Model from record/Office31/CUDA2/dw_encoder for clustering  -----
#   -----  Load NMI File from record/Office31/CUDA2/dw_encoder  -----
# nmi:0.5254522730784369
# nmi class:0.37910306441143266
# ===============================================
# ==============  amazon_dslr  ==============
# ===============================================
# Please install apex for mixed precision training from: https://github.com/NVIDIA/apex
#       ---------------------------------------------------------
#                 batch_size: 256,  epochs: 150
#                 SSL: simclr,  base_model: encoder
#                 jigsaw: True,  fourier: False,  grid: 3
#                 num_laps: 1
#         ---------------------------------------------------------
#
# =================  1/1周目  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  88 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=4)]: Done 2440 tasks      | elapsed:    6.2s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    6.9s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 200 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=4)]: Done 498 out of 498 | elapsed:    3.0s finished
# Running on: cuda
# Epoch:0/150(0) loss:5.469248294830322
# Epoch:4/150(50) loss:4.967752456665039
# Epoch:8/150(100) loss:4.91867208480835
# Epoch:12/150(150) loss:4.825376510620117
# Epoch:16/150(200) loss:4.830636501312256
# Epoch:20/150(250) loss:4.810488224029541
# Epoch:25/150(300) loss:4.834344863891602
# Epoch:29/150(350) loss:4.787431716918945
# Epoch:33/150(400) loss:4.7662553787231445
# Epoch:37/150(450) loss:4.7759108543396
# Epoch:41/150(500) loss:4.814356803894043
# Epoch:45/150(550) loss:4.804649353027344
# Epoch:50/150(600) loss:4.763235569000244
# Epoch:54/150(650) loss:4.757068157196045
# Epoch:58/150(700) loss:4.725995063781738
# Epoch:62/150(750) loss:4.7657294273376465
# Epoch:66/150(800) loss:4.832027912139893
# Epoch:70/150(850) loss:4.769635200500488
# Epoch:75/150(900) loss:4.722548007965088
# Epoch:79/150(950) loss:4.7039947509765625
# Epoch:83/150(1000) loss:4.776154518127441
# Epoch:87/150(1050) loss:4.715315341949463
# Epoch:91/150(1100) loss:4.7193684577941895
# Epoch:95/150(1150) loss:4.751875400543213
# Epoch:100/150(1200) loss:4.7393646240234375
# Epoch:104/150(1250) loss:4.7000908851623535
# Epoch:108/150(1300) loss:4.708871364593506
# Epoch:112/150(1350) loss:4.706142902374268
# Epoch:116/150(1400) loss:4.761349201202393
# Epoch:120/150(1450) loss:4.713404178619385
# Epoch:125/150(1500) loss:4.698437213897705
# Epoch:129/150(1550) loss:4.686656475067139
# Epoch:133/150(1600) loss:4.70237398147583
# Epoch:137/150(1650) loss:4.7319207191467285
# Epoch:141/150(1700) loss:4.724863529205322
# Epoch:145/150(1750) loss:4.729644298553467
# =================  Clustering 1/1  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    5.7s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 200 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=4)]: Done 498 out of 498 | elapsed:    2.5s finished
#   -----  Load Model from record/Office31/CUDA2/ad_encoder for clustering  -----
#   -----  Load NMI File from record/Office31/CUDA2/ad_encoder  -----
# nmi:0.8556851899345871
# nmi class:0.19105910361033646
# ===============================================
# ==============  webcam_amazon  ==============
# ===============================================
# Please install apex for mixed precision training from: https://github.com/NVIDIA/apex
#       ---------------------------------------------------------
#                 batch_size: 256,  epochs: 150
#                 SSL: simclr,  base_model: encoder
#                 jigsaw: True,  fourier: True,  grid: 3
#                 num_laps: 1
#         ---------------------------------------------------------
#
# =================  1/1周目  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  52 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=4)]: Done 352 tasks      | elapsed:    8.6s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:   17.8s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  76 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=4)]: Done 376 tasks      | elapsed:    7.5s
# [Parallel(n_jobs=4)]: Done 876 tasks      | elapsed:   17.6s

# %%
# %reset -f
# !rm -fr __pycache__
# !rm -fr */__pycache__

# %% [markdown]
# # Domain Estimation

# %%
from z_common import *
import sys
sys.dont_write_bytecode = True  # pycacheを作らないようにする

# ファイル特有変数
CUDA_DIR = 0
N_CUDA = 0
spread_message = LOG_TEXT

# %%
# %%time
# PARENT = 'Digit'
# DATA_DOMAIN_LIST = [
#   'svhn_mnist',
#   'svhn_synth',
#   'svhn_synth_mnist',
#   'svhn_synth_mnist_mnistm',
# ]
PARENT = 'Office31'
DATA_DOMAIN_LIST = [
  # 'amazon_dslr_webcam',
  'dslr_webcam',
  # 'amazon_dslr',
  # 'webcam_amazon',
]


LAP = 1
NUM_LAPS = 2
log_dir_opt = ''
# log_dir_opt += '__record'


for DATA_DOMAIN in DATA_DOMAIN_LIST:
  config, CONFIG_FILE, log_dir = config_to_execute(DATA_DOMAIN, PARENT, CUDA_DIR, log_dir_opt)

  # !rm -fr */__pycache__
  # !CUDA_VISIBLE_DEVICES=$N_CUDA python3 -B run.py --config=$CONFIG_FILE  --log_dir=$log_dir  --num_laps=$NUM_LAPS  --spread_message=$spread_message
# Out:
# ===============================================
# ==============  amazon_dslr  ==============
# ===============================================
# Please install apex for mixed precision training from: https://github.com/NVIDIA/apex
#     ---------------------------------------------------------
#             batch_size: 256,  epochs: 100
#             SSL: simsiam,  base_model: encoder
#             jigsaw: True,  fourier: True,  grid: 3
#             num_laps: 2
#     ---------------------------------------------------------
# =================  1周目  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  52 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=4)]: Done 352 tasks      | elapsed:    9.4s
# [Parallel(n_jobs=4)]: Done 852 tasks      | elapsed:   21.6s
# [Parallel(n_jobs=4)]: Done 1552 tasks      | elapsed:   38.3s
# [Parallel(n_jobs=4)]: Done 2452 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=4)]: Done 2810 out of 2817 | elapsed:  1.2min remaining:    0.2s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:  1.2min finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  76 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=4)]: Done 376 tasks      | elapsed:   13.6s
# [Parallel(n_jobs=4)]: Done 498 out of 498 | elapsed:   18.1s finished
# Running on: cuda
# Epoch:0/100(0) loss:-0.012260383926331997
# Epoch:4/100(50) loss:-0.8558616042137146
# Epoch:8/100(100) loss:-0.8776792883872986
# Epoch:12/100(150) loss:-0.886725902557373
# Epoch:16/100(200) loss:-0.8563534617424011
# Epoch:20/100(250) loss:-0.8559994101524353
# Epoch:25/100(300) loss:-0.8810573220252991
# Epoch:29/100(350) loss:-0.864932656288147
# Epoch:33/100(400) loss:-0.8763829469680786
# Epoch:37/100(450) loss:-0.8853969573974609
# Epoch:41/100(500) loss:-0.8104710578918457
# Epoch:45/100(550) loss:-0.8563403487205505
# Epoch:50/100(600) loss:-0.8648250699043274
# Epoch:54/100(650) loss:-0.8870975971221924
# Epoch:58/100(700) loss:-0.8564472794532776
# Epoch:62/100(750) loss:-0.8486918210983276
# Epoch:66/100(800) loss:-0.8165608644485474
# Epoch:70/100(850) loss:-0.8340189456939697
# Epoch:75/100(900) loss:-0.8420118093490601
# Epoch:79/100(950) loss:-0.8564938306808472
# Epoch:83/100(1000) loss:-0.817924976348877
# Epoch:87/100(1050) loss:-0.8634714484214783
# Epoch:91/100(1100) loss:-0.847174346446991
# Epoch:95/100(1150) loss:-0.8726911544799805
# =================  Clustering 1  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  76 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=4)]: Done 376 tasks      | elapsed:    9.0s
# [Parallel(n_jobs=4)]: Done 876 tasks      | elapsed:   21.3s
# [Parallel(n_jobs=4)]: Done 1576 tasks      | elapsed:   39.8s
# [Parallel(n_jobs=4)]: Done 2476 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=4)]: Done 2810 out of 2817 | elapsed:  1.2min remaining:    0.2s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:  1.2min finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  76 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=4)]: Done 376 tasks      | elapsed:   11.6s
# [Parallel(n_jobs=4)]: Done 498 out of 498 | elapsed:   15.8s finished
#   -----  Load Model from record/Office31/CUDA0/ad_encoder for clustering  -----
#     -----  Load NMI File from record/Office31/CUDA0/ad_encoder  -----
# nmi:0.25893730305904217
# nmi class:0.14896095025698886
# =================  2周目  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  76 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=4)]: Done 376 tasks      | elapsed:    9.9s
# [Parallel(n_jobs=4)]: Done 876 tasks      | elapsed:   23.2s
# [Parallel(n_jobs=4)]: Done 1576 tasks      | elapsed:   43.1s
# [Parallel(n_jobs=4)]: Done 2476 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=4)]: Done 2810 out of 2817 | elapsed:  1.2min remaining:    0.2s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:  1.2min finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  76 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=4)]: Done 376 tasks      | elapsed:   12.1s
# [Parallel(n_jobs=4)]: Done 498 out of 498 | elapsed:   16.5s finished
# Running on: cuda
#   ----- Loaded pre-trained model from record/Office31/CUDA0/ad_encoder for SSL  -----
# Epoch:0/100(0) loss:-0.8490365743637085
# Epoch:4/100(50) loss:-0.840357780456543
# Epoch:8/100(100) loss:-0.8344441652297974
# Epoch:12/100(150) loss:-0.8102303743362427
# Epoch:16/100(200) loss:-0.8731934428215027
# Epoch:20/100(250) loss:-0.8476088047027588
# Epoch:25/100(300) loss:-0.8757960200309753
# Epoch:29/100(350) loss:-0.8488636016845703
# Epoch:33/100(400) loss:-0.8666722178459167
# Epoch:37/100(450) loss:-0.9005601406097412
# Epoch:41/100(500) loss:-0.8263087272644043
# Epoch:45/100(550) loss:-0.8691492080688477
# Epoch:50/100(600) loss:-0.8738583922386169
# Epoch:54/100(650) loss:-0.8820222616195679
# Epoch:58/100(700) loss:-0.869688868522644
# Epoch:62/100(750) loss:-0.8771172165870667
# Epoch:66/100(800) loss:-0.8541324734687805
# Epoch:70/100(850) loss:-0.8676566481590271
# Epoch:75/100(900) loss:-0.8881691098213196
# Epoch:79/100(950) loss:-0.8383594751358032
# Epoch:83/100(1000) loss:-0.8634529709815979
# Epoch:87/100(1050) loss:-0.8533975481987
# Epoch:91/100(1100) loss:-0.8838565349578857
# Epoch:95/100(1150) loss:-0.8508744239807129
# =================  Clustering 2  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  76 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=4)]: Done 376 tasks      | elapsed:    9.3s
# [Parallel(n_jobs=4)]: Done 876 tasks      | elapsed:   21.8s
# [Parallel(n_jobs=4)]: Done 1576 tasks      | elapsed:   39.6s
# [Parallel(n_jobs=4)]: Done 2476 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=4)]: Done 2810 out of 2817 | elapsed:  1.2min remaining:    0.2s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:  1.2min finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  76 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=4)]: Done 376 tasks      | elapsed:   12.0s
# [Parallel(n_jobs=4)]: Done 491 out of 498 | elapsed:   16.1s remaining:    0.2s
# [Parallel(n_jobs=4)]: Done 498 out of 498 | elapsed:   16.2s finished
#   -----  Load Model from record/Office31/CUDA0/ad_encoder__2 for clustering  -----
#     -----  Load NMI File from record/Office31/CUDA0/ad_encoder__2  -----
# nmi:0.029269844566495215
# nmi class:0.1353950002024698
# record/Office31/CUDA0/ad_encoder__2
# CPU times: user 4.84 s, sys: 648 ms, total: 5.48 s
# Wall time: 12min 31s

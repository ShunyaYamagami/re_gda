# %%
# %reset -f
# !rm -fr __pycache__
# !rm -fr */__pycache__

# %% [markdown]
# # Domain Estimation

# %%
from z_common import *

# ファイル特有変数
CUDA_DIR = 0
N_CUDA = 1
spread_message = LOG_TEXT

# %%
# %%time
# PARENT = 'Digit'
# DATA_DOMAIN_LIST = [
#   'svhn_mnist',
#   'svhn_synth',
#   'svhn_synth_mnist',
#   'svhn_synth_mnist_mnistm',
# ]
PARENT = 'Office31'
DATA_DOMAIN_LIST = [
  # 'amazon_dslr_webcam',
  # 'dslr_webcam',
  # 'amazon_dslr',
  'webcam_amazon',
  'webcam_amazon',
]


LAP = 1
NUM_LAPS = 2
log_dir_opt = ''
# log_dir_opt += '__record'
# log_dir_opt += '__douse'


for DATA_DOMAIN in DATA_DOMAIN_LIST:
  config, CONFIG_FILE, log_dir = config_to_execute(DATA_DOMAIN, PARENT, CUDA_DIR, log_dir_opt)

  # !rm -fr */__pycache__
  # !CUDA_VISIBLE_DEVICES=$N_CUDA python3 -B run.py --config=$CONFIG_FILE  --log_dir=$log_dir  --num_laps=$NUM_LAPS  --spread_message=$spread_message  --cuda_dir=$CUDA_DIR
# Out:
# ===============================================
# ==============  webcam_amazon  ==============
# ===============================================
# Please install apex for mixed precision training from: https://github.com/NVIDIA/apex
#     ---------------------------------------------------------
#         cuda_dir: 0
#         batch_size: 256,  epochs: 100
#         SSL: simclr,  base_model: encoder
#         jigsaw: True,  fourier: True,  grid: 3
#         num_laps: 2
#     ---------------------------------------------------------
#
#
# =================  1/2周目  =================
# =================  Clustering 1/2  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  56 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=4)]: Done 356 tasks      | elapsed:    7.6s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:   15.5s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  76 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=4)]: Done 376 tasks      | elapsed:    6.7s
# [Parallel(n_jobs=4)]: Done 876 tasks      | elapsed:   15.4s
# [Parallel(n_jobs=4)]: Done 1576 tasks      | elapsed:   27.9s
# [Parallel(n_jobs=4)]: Done 2476 tasks      | elapsed:   43.5s
# [Parallel(n_jobs=4)]: Done 2810 out of 2817 | elapsed:   49.4s remaining:    0.1s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:   49.5s finished
#   -----  Load Model from record/Office31/CUDA0/wa_encoder for clustering  -----
# nmi:0.0654056980920129
# nmi class:0.19586365230696712
# domain_accuracy:0.6079734219269103
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  76 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=4)]: Done 376 tasks      | elapsed:    7.0s
# [Parallel(n_jobs=4)]: Done 788 out of 795 | elapsed:   14.4s remaining:    0.1s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:   14.6s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  76 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=4)]: Done 376 tasks      | elapsed:    6.7s
# [Parallel(n_jobs=4)]: Done 876 tasks      | elapsed:   15.4s
# [Parallel(n_jobs=4)]: Done 1576 tasks      | elapsed:   27.9s
# [Parallel(n_jobs=4)]: Done 2476 tasks      | elapsed:   43.5s
# [Parallel(n_jobs=4)]: Done 2810 out of 2817 | elapsed:   49.4s remaining:    0.1s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:   49.4s finished
#   -----  Load Model from record/Office31/CUDA0/wa_encoder for clustering  -----
# nmi:0.2944290045929858
# nmi class:0.2000223621090478
# domain_accuracy:0.7475083056478405
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  76 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=4)]: Done 376 tasks      | elapsed:    7.1s
# [Parallel(n_jobs=4)]: Done 788 out of 795 | elapsed:   14.5s remaining:    0.1s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:   14.6s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  76 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=4)]: Done 376 tasks      | elapsed:    6.7s
# [Parallel(n_jobs=4)]: Done 876 tasks      | elapsed:   15.3s
# [Parallel(n_jobs=4)]: Done 1576 tasks      | elapsed:   27.4s
# [Parallel(n_jobs=4)]: Done 2476 tasks      | elapsed:   42.7s
# [Parallel(n_jobs=4)]: Done 2810 out of 2817 | elapsed:   48.4s remaining:    0.1s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:   48.6s finished
#   -----  Load Model from record/Office31/CUDA0/wa_encoder for clustering  -----
# nmi:0.2918061075265661
# nmi class:0.19469798935430296
# domain_accuracy:0.7477851605758582
# ===============================================
# ==============  webcam_amazon  ==============
# ===============================================
# Please install apex for mixed precision training from: https://github.com/NVIDIA/apex
#     ---------------------------------------------------------
#         cuda_dir: 0
#         batch_size: 256,  epochs: 100
#         SSL: simclr,  base_model: encoder
#         jigsaw: True,  fourier: True,  grid: 3
#         num_laps: 2
#     ---------------------------------------------------------
#
#
# =================  1/2周目  =================
# =================  Clustering 1/2  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  56 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=4)]: Done 356 tasks      | elapsed:    7.6s
# [Parallel(n_jobs=4)]: Done 788 out of 795 | elapsed:   15.4s remaining:    0.1s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:   15.5s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  76 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=4)]: Done 376 tasks      | elapsed:    6.7s
# [Parallel(n_jobs=4)]: Done 876 tasks      | elapsed:   15.4s
# [Parallel(n_jobs=4)]: Done 1576 tasks      | elapsed:   27.8s
# [Parallel(n_jobs=4)]: Done 2476 tasks      | elapsed:   43.4s
# [Parallel(n_jobs=4)]: Done 2810 out of 2817 | elapsed:   49.2s remaining:    0.1s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:   49.3s finished
#   -----  Load Model from record/Office31/CUDA0/wa_encoder for clustering  -----
# nmi:0.05952426336458184
# nmi class:0.18745435598078689
# domain_accuracy:0.617109634551495
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  76 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=4)]: Done 376 tasks      | elapsed:    7.1s
# [Parallel(n_jobs=4)]: Done 788 out of 795 | elapsed:   14.5s remaining:    0.1s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:   14.6s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  76 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=4)]: Done 376 tasks      | elapsed:    6.7s
# [Parallel(n_jobs=4)]: Done 876 tasks      | elapsed:   15.4s
# [Parallel(n_jobs=4)]: Done 1576 tasks      | elapsed:   27.8s
# [Parallel(n_jobs=4)]: Done 2476 tasks      | elapsed:   43.4s
# [Parallel(n_jobs=4)]: Done 2810 out of 2817 | elapsed:   49.3s remaining:    0.1s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:   49.3s finished
#   -----  Load Model from record/Office31/CUDA0/wa_encoder for clustering  -----
# nmi:0.5816788975168707
# nmi class:0.19255100335625291
# domain_accuracy:0.9330011074197121
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  76 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=4)]: Done 376 tasks      | elapsed:    7.1s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:   14.7s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 128 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=4)]: Done 728 tasks      | elapsed:   12.9s
# [Parallel(n_jobs=4)]: Done 1728 tasks      | elapsed:   30.6s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:   48.8s finished
#   -----  Load Model from record/Office31/CUDA0/wa_encoder for clustering  -----
# nmi:0.30217300791328605
# nmi class:0.18970129781518238
# domain_accuracy:0.7475083056478405
# CPU times: user 3.1 s, sys: 527 ms, total: 3.63 s
# Wall time: 7min 17s

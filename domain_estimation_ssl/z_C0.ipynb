# %%
# %reset -f
# !rm -fr __pycache__
# !rm -fr */__pycache__

# %% [markdown]
# # Domain Estimation

# %%
from z_common import *
import sys
sys.dont_write_bytecode = True  # pycacheを作らないようにする

# ファイル特有変数
CUDA_DIR = 0
N_CUDA = 0
spread_message = LOG_TEXT

# %%
# %%time
########## Change here! ##########
# PARENT = 'Digit'
# DATA_DOMAIN_LIST = [
#   'svhn_mnist',
#   'svhn_synth',
#   'svhn_synth_mnist',
#   'svhn_synth_mnist_mnistm',
# ]
PARENT = 'Office31'
DATA_DOMAIN_LIST = [
  # 'amazon_dslr_webcam',
  'dslr_webcam',
  # 'amazon_dslr',
  # 'webcam_amazon',
]

LAP = 1
NUM_LAPS = 2
log_dir_opt = ''
# log_dir_opt += '__record'

try:
  start_time = time()
  for DATA_DOMAIN in DATA_DOMAIN_LIST:
    config, CONFIG_FILE, log_dir = config_to_execute(DATA_DOMAIN, PARENT, CUDA_DIR, log_dir_opt)

    # !rm -fr */__pycache__
    # !CUDA_VISIBLE_DEVICES=$N_CUDA python3 -B run.py --config=$CONFIG_FILE  --log_dir=$log_dir  --num_laps=$NUM_LAPS

    log_spread_sheet(config, log_dir, DATA_DOMAIN, spread_message)

  end_time = time()
  send_email(not_error=True, body_text=f'実行終了. 実行時間: {(end_time-start_time)/60:.2f} 分', config=config, log_dir=log_dir, DATA_DOMAIN=DATA_DOMAIN)
except:
  error_message=traceback.format_exc()
  send_email(not_error=False, error_message=error_message)
# Out:
# ===============================================
# ==============  dslr_webcam  ==============
# ===============================================
# Please install apex for mixed precision training from: https://github.com/NVIDIA/apex
#     ---------------------------------------------------------
#             batch_size: 512,  epochs: 150
#             SSL: simclr,  base_model: encoder
#             jigsaw: True,  fourier: False
#             num_laps: 2
#     ---------------------------------------------------------
# =================  1周目  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  88 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=4)]: Done 498 out of 498 | elapsed:    3.5s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    2.0s finished
# Running on: cuda
# Epoch:0/150(0) loss:5.951599597930908
# Epoch:25/150(50) loss:5.4892730712890625
# Epoch:50/150(100) loss:5.460759162902832
# Epoch:75/150(150) loss:5.420637130737305
# Epoch:100/150(200) loss:5.413639068603516
# Epoch:125/150(250) loss:5.409077167510986
# =================  Clustering 1  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 200 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=4)]: Done 498 out of 498 | elapsed:    2.5s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    2.0s finished
#   -----  Load Model from record/Office31/CUDA0/dw_encoder for clustering  -----
# nmi:0.20576902794917468
# nmi class:0.37500272904121057
# =================  2周目  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 200 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=4)]: Done 498 out of 498 | elapsed:    2.5s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    1.9s finished
# Running on: cuda
#   ----- Loaded pre-trained model from record/Office31/CUDA0/dw_encoder for SSL  -----
# Epoch:0/150(0) loss:5.380046844482422
# Epoch:25/150(50) loss:5.380338191986084
# Epoch:50/150(100) loss:5.395023822784424
# Epoch:75/150(150) loss:5.374616622924805
# Epoch:100/150(200) loss:5.384021759033203
# Epoch:125/150(250) loss:5.37053108215332
# =================  Clustering 2  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 200 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=4)]: Done 498 out of 498 | elapsed:    2.5s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    1.9s finished
#   -----  Load Model from record/Office31/CUDA0/dw_encoder__edls for clustering  -----
# nmi:0.12447736329142367
# nmi class:0.3839456534445018
# CPU times: user 2.16 s, sys: 433 ms, total: 2.6 s
# Wall time: 4min 5s

# %%
# %reset -f
# !rm -fr __pycache__
# !rm -fr */__pycache__

# %%
from z_common import *

# ファイル特有変数
CUDA_DIR = 4
N_CUDA = 2
spread_message = LOG_TEXT

# %%
# %%time
# PARENT = 'Digit'
# DATA_DOMAIN_LIST = [
#   'svhn_mnist',
#   'svhn_synth',
#   'svhn_synth_mnist',
#   'svhn_synth_mnist_mnistm',
# ]
PARENT = 'Office31'
DATA_DOMAIN_LIST = [
  # 'amazon_dslr_webcam',
  # 'dslr_webcam',
  # 'dslr_webcam',
  # 'dslr_webcam',
  'amazon_dslr',
  'amazon_dslr',
  'amazon_dslr',
  'webcam_amazon',
  'webcam_amazon',
  'webcam_amazon',
]


LAP = 1
NUM_LAPS = 2
log_dir_opt = ''
# log_dir_opt += '__record'
# log_dir_opt += '__douse'

counter=3
for DATA_DOMAIN in DATA_DOMAIN_LIST:
  config, CONFIG_FILE, log_dir = config_to_execute(DATA_DOMAIN, PARENT, CUDA_DIR, log_dir_opt)
  log_dir += f'__{counter}'
  counter += 1

  # !rm -fr */__pycache__
  # !CUDA_VISIBLE_DEVICES=$N_CUDA python3 -B run.py --config=$CONFIG_FILE  --log_dir=$log_dir  --num_laps=$NUM_LAPS  --spread_message=$spread_message  --cuda_dir=$CUDA_DIR
# Out:
# ===============================================
# ==============  amazon_dslr  ==============
# ===============================================
# Please install apex for mixed precision training from: https://github.com/NVIDIA/apex
#     ---------------------------------------------------------
#         cuda_dir: 4
#         batch_size: 256,  epochs: 100
#         SSL: simclr,  base_model: encoder
#         jigsaw: True,  fourier: True,  grid: 3
#         num_laps: 2,
#         log_dir: record/Office31/CUDA4/ad_encoder__3
#     ---------------------------------------------------------
#
#
# =================  1/2周目  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  88 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=4)]: Done 2792 tasks      | elapsed:    7.0s
# [Parallel(n_jobs=4)]: Done 2810 out of 2817 | elapsed:    7.1s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    7.1s finished
# /home/syamagami/codes/re_gda/domain_estimation_ssl/dataset.py:107: FutureWarning: The input object of type 'Image' is an array-like implementing one of the corresponding protocols (`__array__`, `__array_interface__` or `__array_struct__`); but not a sequence (or 0-D). In the future, this object will be coerced as if it was first converted using `np.array(obj)`. To retain the old behaviour, you have to either modify the type 'Image', or assign to an empty array created with `np.empty(correct_shape, dtype=object)`.
#   self.imgs = np.array([t[1] for t in self.processed])
# /home/syamagami/codes/re_gda/domain_estimation_ssl/dataset.py:107: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   self.imgs = np.array([t[1] for t in self.processed])
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 200 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=4)]: Done 498 out of 498 | elapsed:    5.7s finished
# /home/syamagami/codes/re_gda/domain_estimation_ssl/dataset.py:107: FutureWarning: The input object of type 'Image' is an array-like implementing one of the corresponding protocols (`__array__`, `__array_interface__` or `__array_struct__`); but not a sequence (or 0-D). In the future, this object will be coerced as if it was first converted using `np.array(obj)`. To retain the old behaviour, you have to either modify the type 'Image', or assign to an empty array created with `np.empty(correct_shape, dtype=object)`.
#   self.imgs = np.array([t[1] for t in self.processed])
# /home/syamagami/codes/re_gda/domain_estimation_ssl/dataset.py:107: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   self.imgs = np.array([t[1] for t in self.processed])
# Running on: cuda
# Epoch:0/100(0) loss:5.468273639678955
# Epoch:4/100(50) loss:4.899494171142578
# Epoch:8/100(100) loss:4.799239635467529
# Epoch:12/100(150) loss:4.807890892028809
# Epoch:16/100(200) loss:4.805737018585205
# Epoch:20/100(250) loss:4.800236225128174
# Epoch:25/100(300) loss:4.808540344238281
# Epoch:29/100(350) loss:4.763026237487793
# Epoch:33/100(400) loss:4.776559829711914
# Epoch:37/100(450) loss:4.785932540893555
# Epoch:41/100(500) loss:4.743459224700928
# Epoch:45/100(550) loss:4.800203323364258
# Epoch:50/100(600) loss:4.778082370758057
# Epoch:54/100(650) loss:4.744472503662109
# Epoch:58/100(700) loss:4.723289489746094
# Epoch:62/100(750) loss:4.739297866821289
# Epoch:66/100(800) loss:4.740841865539551
# Epoch:70/100(850) loss:4.756404876708984
# Epoch:75/100(900) loss:4.769125461578369
# Epoch:79/100(950) loss:4.757816791534424
# Epoch:83/100(1000) loss:4.737813949584961
# Epoch:87/100(1050) loss:4.6988725662231445
# Epoch:91/100(1100) loss:4.773569107055664
# Epoch:95/100(1150) loss:4.763301849365234
# =================  Clustering 1/2  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  56 tasks      | elapsed:    3.9s
# [Parallel(n_jobs=4)]: Done 2810 out of 2817 | elapsed:   11.5s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:   11.5s finished
# /home/syamagami/codes/re_gda/domain_estimation_ssl/dataset.py:107: FutureWarning: The input object of type 'Image' is an array-like implementing one of the corresponding protocols (`__array__`, `__array_interface__` or `__array_struct__`); but not a sequence (or 0-D). In the future, this object will be coerced as if it was first converted using `np.array(obj)`. To retain the old behaviour, you have to either modify the type 'Image', or assign to an empty array created with `np.empty(correct_shape, dtype=object)`.
#   self.imgs = np.array([t[1] for t in self.processed])
# /home/syamagami/codes/re_gda/domain_estimation_ssl/dataset.py:107: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   self.imgs = np.array([t[1] for t in self.processed])
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 128 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=4)]: Done 498 out of 498 | elapsed:    7.9s finished
# /home/syamagami/codes/re_gda/domain_estimation_ssl/dataset.py:107: FutureWarning: The input object of type 'Image' is an array-like implementing one of the corresponding protocols (`__array__`, `__array_interface__` or `__array_struct__`); but not a sequence (or 0-D). In the future, this object will be coerced as if it was first converted using `np.array(obj)`. To retain the old behaviour, you have to either modify the type 'Image', or assign to an empty array created with `np.empty(correct_shape, dtype=object)`.
#   self.imgs = np.array([t[1] for t in self.processed])
# /home/syamagami/codes/re_gda/domain_estimation_ssl/dataset.py:107: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   self.imgs = np.array([t[1] for t in self.processed])
#   -----  Load Model from record/Office31/CUDA4/ad_encoder__3 for clustering  -----
# nmi:0.8682565497614757
# nmi class:0.20146036945758244
# domain_accuracy:0.9867269984917044
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    8.5s finished
# /home/syamagami/codes/re_gda/domain_estimation_ssl/dataset.py:107: FutureWarning: The input object of type 'Image' is an array-like implementing one of the corresponding protocols (`__array__`, `__array_interface__` or `__array_struct__`); but not a sequence (or 0-D). In the future, this object will be coerced as if it was first converted using `np.array(obj)`. To retain the old behaviour, you have to either modify the type 'Image', or assign to an empty array created with `np.empty(correct_shape, dtype=object)`.
#   self.imgs = np.array([t[1] for t in self.processed])
# /home/syamagami/codes/re_gda/domain_estimation_ssl/dataset.py:107: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   self.imgs = np.array([t[1] for t in self.processed])
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  76 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=4)]: Done 376 tasks      | elapsed:    7.2s
# [Parallel(n_jobs=4)]: Done 498 out of 498 | elapsed:    9.5s finished
# /home/syamagami/codes/re_gda/domain_estimation_ssl/dataset.py:107: FutureWarning: The input object of type 'Image' is an array-like implementing one of the corresponding protocols (`__array__`, `__array_interface__` or `__array_struct__`); but not a sequence (or 0-D). In the future, this object will be coerced as if it was first converted using `np.array(obj)`. To retain the old behaviour, you have to either modify the type 'Image', or assign to an empty array created with `np.empty(correct_shape, dtype=object)`.
#   self.imgs = np.array([t[1] for t in self.processed])
# /home/syamagami/codes/re_gda/domain_estimation_ssl/dataset.py:107: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   self.imgs = np.array([t[1] for t in self.processed])
#   -----  Load Model from record/Office31/CUDA4/ad_encoder__3 for clustering  -----
# nmi:0.27596718163446776
# nmi class:0.19379379820244255
# domain_accuracy:0.7363499245852188
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=4)]: Done 2680 tasks      | elapsed:    7.2s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    7.6s finished
# /home/syamagami/codes/re_gda/domain_estimation_ssl/dataset.py:107: FutureWarning: The input object of type 'Image' is an array-like implementing one of the corresponding protocols (`__array__`, `__array_interface__` or `__array_struct__`); but not a sequence (or 0-D). In the future, this object will be coerced as if it was first converted using `np.array(obj)`. To retain the old behaviour, you have to either modify the type 'Image', or assign to an empty array created with `np.empty(correct_shape, dtype=object)`.
#   self.imgs = np.array([t[1] for t in self.processed])
# /home/syamagami/codes/re_gda/domain_estimation_ssl/dataset.py:107: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   self.imgs = np.array([t[1] for t in self.processed])
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  76 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=4)]: Done 376 tasks      | elapsed:    7.3s
# [Parallel(n_jobs=4)]: Done 498 out of 498 | elapsed:    9.6s finished
# /home/syamagami/codes/re_gda/domain_estimation_ssl/dataset.py:107: FutureWarning: The input object of type 'Image' is an array-like implementing one of the corresponding protocols (`__array__`, `__array_interface__` or `__array_struct__`); but not a sequence (or 0-D). In the future, this object will be coerced as if it was first converted using `np.array(obj)`. To retain the old behaviour, you have to either modify the type 'Image', or assign to an empty array created with `np.empty(correct_shape, dtype=object)`.
#   self.imgs = np.array([t[1] for t in self.processed])
# /home/syamagami/codes/re_gda/domain_estimation_ssl/dataset.py:107: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   self.imgs = np.array([t[1] for t in self.processed])
#   -----  Load Model from record/Office31/CUDA4/ad_encoder__3 for clustering  -----
# nmi:0.25895354025128436
# nmi class:0.19678829160308514
# domain_accuracy:0.7167420814479638
# ===============================================
# ==============  amazon_dslr  ==============
# ===============================================
# Please install apex for mixed precision training from: https://github.com/NVIDIA/apex
#     ---------------------------------------------------------
#         cuda_dir: 4
#         batch_size: 256,  epochs: 100
#         SSL: simclr,  base_model: encoder
#         jigsaw: True,  fourier: True,  grid: 3
#         num_laps: 2,
#         log_dir: record/Office31/CUDA4/ad_encoder__4
#     ---------------------------------------------------------
#
#
# =================  1/2周目  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  71 tasks      | elapsed:    3.6s
# [Parallel(n_jobs=4)]: Done 2810 out of 2817 | elapsed:   11.0s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:   11.0s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 128 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=4)]: Done 498 out of 498 | elapsed:    7.1s finished
# Running on: cuda
# Epoch:0/100(0) loss:5.482192516326904
# Epoch:4/100(50) loss:4.9384260177612305
# Epoch:8/100(100) loss:4.823493480682373
# Epoch:12/100(150) loss:4.834638595581055
# Epoch:16/100(200) loss:4.826127529144287
# Epoch:20/100(250) loss:4.781580448150635
# Epoch:25/100(300) loss:4.811778545379639
# Epoch:29/100(350) loss:4.779743194580078
# Epoch:33/100(400) loss:4.77578067779541
# Epoch:37/100(450) loss:4.768341541290283
# Epoch:41/100(500) loss:4.7831573486328125
# Epoch:45/100(550) loss:4.8005781173706055
# Epoch:50/100(600) loss:4.7706074714660645
# Epoch:54/100(650) loss:4.761087894439697
# Epoch:58/100(700) loss:4.747801303863525
# Epoch:62/100(750) loss:4.761274814605713
# Epoch:66/100(800) loss:4.748449325561523
# Epoch:70/100(850) loss:4.722177505493164
# Epoch:75/100(900) loss:4.748162746429443
# Epoch:79/100(950) loss:4.740445613861084
# Epoch:83/100(1000) loss:4.727444171905518
# Epoch:87/100(1050) loss:4.702116012573242
# Epoch:91/100(1100) loss:4.763882160186768
# Epoch:95/100(1150) loss:4.740276336669922
# =================  Clustering 1/2  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  74 tasks      | elapsed:    3.5s
# [Parallel(n_jobs=4)]: Done 2380 tasks      | elapsed:   10.6s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:   11.7s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 128 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=4)]: Done 498 out of 498 | elapsed:    7.6s finished
#   -----  Load Model from record/Office31/CUDA4/ad_encoder__4 for clustering  -----
# nmi:0.3647352035375719
# nmi class:0.1956725713428482
# domain_accuracy:0.816289592760181
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=4)]: Done 2680 tasks      | elapsed:    7.2s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    7.6s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 128 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=4)]: Done 491 out of 498 | elapsed:    7.2s remaining:    0.1s
# [Parallel(n_jobs=4)]: Done 498 out of 498 | elapsed:    7.4s finished
#   -----  Load Model from record/Office31/CUDA4/ad_encoder__4 for clustering  -----
# nmi:0.39266491690640204
# nmi class:0.19116584078450297
# domain_accuracy:0.8355957767722474
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 200 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=4)]: Done 2810 out of 2817 | elapsed:    7.7s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    7.7s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 128 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=4)]: Done 491 out of 498 | elapsed:    7.1s remaining:    0.1s
# [Parallel(n_jobs=4)]: Done 498 out of 498 | elapsed:    7.1s finished
#   -----  Load Model from record/Office31/CUDA4/ad_encoder__4 for clustering  -----
# nmi:0.8671066428956249
# nmi class:0.1890854092250836
# domain_accuracy:0.987028657616893
# ===============================================
# ==============  amazon_dslr  ==============
# ===============================================
# Please install apex for mixed precision training from: https://github.com/NVIDIA/apex
#     ---------------------------------------------------------
#         cuda_dir: 4
#         batch_size: 256,  epochs: 100
#         SSL: simclr,  base_model: encoder
#         jigsaw: True,  fourier: True,  grid: 3
#         num_laps: 2,
#         log_dir: record/Office31/CUDA4/ad_encoder__5
#     ---------------------------------------------------------
#
#
# =================  1/2周目  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  74 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=4)]: Done 2380 tasks      | elapsed:    8.4s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    9.5s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 128 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=4)]: Done 498 out of 498 | elapsed:    7.6s finished
# Running on: cuda
# Epoch:0/100(0) loss:5.452422618865967
# Epoch:4/100(50) loss:4.903266429901123
# Epoch:8/100(100) loss:4.834397315979004
# Epoch:12/100(150) loss:4.814138889312744
# Epoch:16/100(200) loss:4.8352556228637695
# Epoch:20/100(250) loss:4.807677268981934
# Epoch:25/100(300) loss:4.8375654220581055
# Epoch:29/100(350) loss:4.757535934448242
# Epoch:33/100(400) loss:4.791888236999512
# Epoch:37/100(450) loss:4.776628017425537
# Epoch:41/100(500) loss:4.781762599945068
# Epoch:45/100(550) loss:4.7948689460754395
# Epoch:50/100(600) loss:4.7873077392578125
# Epoch:54/100(650) loss:4.7455620765686035
# Epoch:58/100(700) loss:4.754685401916504
# Epoch:62/100(750) loss:4.743933200836182
# Epoch:66/100(800) loss:4.733650207519531
# Epoch:70/100(850) loss:4.740771770477295
# Epoch:75/100(900) loss:4.719339370727539
# Epoch:79/100(950) loss:4.751340389251709
# Epoch:83/100(1000) loss:4.706363677978516
# Epoch:87/100(1050) loss:4.716127872467041
# Epoch:91/100(1100) loss:4.720579147338867
# Epoch:95/100(1150) loss:4.728699207305908
# =================  Clustering 1/2  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  56 tasks      | elapsed:    4.5s
# [Parallel(n_jobs=4)]: Done 2810 out of 2817 | elapsed:   12.0s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:   12.1s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  76 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=4)]: Done 498 out of 498 | elapsed:    8.2s finished
#   -----  Load Model from record/Office31/CUDA4/ad_encoder__5 for clustering  -----
# nmi:0.42365660318219706
# nmi class:0.18073240859209477
# domain_accuracy:0.8546003016591251
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=4)]: Done 2680 tasks      | elapsed:    7.8s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    8.2s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 128 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=4)]: Done 498 out of 498 | elapsed:    8.1s finished
#   -----  Load Model from record/Office31/CUDA4/ad_encoder__5 for clustering  -----
# nmi:0.375692042713141
# nmi class:0.17180411280604577
# domain_accuracy:0.8241327300150829
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=4)]: Done 2680 tasks      | elapsed:    8.0s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    8.4s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  80 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=4)]: Done 498 out of 498 | elapsed:    9.0s finished
#   -----  Load Model from record/Office31/CUDA4/ad_encoder__5 for clustering  -----
# nmi:0.37397307677396424
# nmi class:0.17685043139227408
# domain_accuracy:0.8229260935143288
# ===============================================
# ==============  webcam_amazon  ==============
# ===============================================
# Please install apex for mixed precision training from: https://github.com/NVIDIA/apex
#     ---------------------------------------------------------
#         cuda_dir: 4
#         batch_size: 256,  epochs: 100
#         SSL: simclr,  base_model: encoder
#         jigsaw: True,  fourier: True,  grid: 3
#         num_laps: 2,
#         log_dir: record/Office31/CUDA4/wa_encoder__6
#     ---------------------------------------------------------
#
#
# =================  1/2周目  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  44 tasks      | elapsed:    4.2s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    8.5s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=4)]: Done 2680 tasks      | elapsed:    7.2s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    7.5s finished
# Running on: cuda
# Epoch:0/100(0) loss:5.391512393951416
# Epoch:3/100(50) loss:4.935019493103027
# Epoch:7/100(100) loss:4.878652095794678
# Epoch:10/100(150) loss:4.855159282684326
# Epoch:14/100(200) loss:4.842445373535156
# Epoch:17/100(250) loss:4.831619739532471
# Epoch:21/100(300) loss:4.782506942749023
# Epoch:25/100(350) loss:4.803514003753662
# Epoch:28/100(400) loss:4.823432445526123
# Epoch:32/100(450) loss:4.793222427368164
# Epoch:35/100(500) loss:4.7811279296875
# Epoch:39/100(550) loss:4.779367923736572
# Epoch:42/100(600) loss:4.724104404449463
# Epoch:46/100(650) loss:4.7724175453186035
# Epoch:50/100(700) loss:4.748691082000732
# Epoch:53/100(750) loss:4.721424579620361
# Epoch:57/100(800) loss:4.7287917137146
# Epoch:60/100(850) loss:4.756354808807373
# Epoch:64/100(900) loss:4.761694431304932
# Epoch:67/100(950) loss:4.712453365325928
# Epoch:71/100(1000) loss:4.69830322265625
# Epoch:75/100(1050) loss:4.720879554748535
# Epoch:78/100(1100) loss:4.735437870025635
# Epoch:82/100(1150) loss:4.735287666320801
# Epoch:85/100(1200) loss:4.719954013824463
# Epoch:89/100(1250) loss:4.72974967956543
# Epoch:92/100(1300) loss:4.728196620941162
# Epoch:96/100(1350) loss:4.748873233795166
# =================  Clustering 1/2  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  56 tasks      | elapsed:    4.2s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    8.0s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=4)]: Done 2680 tasks      | elapsed:    6.5s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    7.0s finished
#   -----  Load Model from record/Office31/CUDA4/wa_encoder__6 for clustering  -----
# nmi:0.5093879081948306
# nmi class:0.19483673274886787
# domain_accuracy:0.8726467331118494
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 200 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    4.9s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=4)]: Done 2680 tasks      | elapsed:    7.8s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    8.2s finished
#   -----  Load Model from record/Office31/CUDA4/wa_encoder__6 for clustering  -----
# nmi:0.4342053768387867
# nmi class:0.1842328041889806
# domain_accuracy:0.829734219269103
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 200 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    4.2s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    7.8s finished
#   -----  Load Model from record/Office31/CUDA4/wa_encoder__6 for clustering  -----
# nmi:0.421613183399988
# nmi class:0.18514570892101168
# domain_accuracy:0.8214285714285714
# ===============================================
# ==============  webcam_amazon  ==============
# ===============================================
# Please install apex for mixed precision training from: https://github.com/NVIDIA/apex
#     ---------------------------------------------------------
#         cuda_dir: 4
#         batch_size: 256,  epochs: 100
#         SSL: simclr,  base_model: encoder
#         jigsaw: True,  fourier: True,  grid: 3
#         num_laps: 2,
#         log_dir: record/Office31/CUDA4/wa_encoder__7
#     ---------------------------------------------------------
#
#
# =================  1/2周目  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  56 tasks      | elapsed:    4.3s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    7.9s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=4)]: Done 2680 tasks      | elapsed:    6.5s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    6.9s finished
# Running on: cuda
# Epoch:0/100(0) loss:5.435468673706055
# Epoch:3/100(50) loss:4.937963008880615
# Epoch:7/100(100) loss:4.898907661437988
# Epoch:10/100(150) loss:4.853975296020508
# Epoch:14/100(200) loss:4.861089706420898
# Epoch:17/100(250) loss:4.834321022033691
# Epoch:21/100(300) loss:4.788546085357666
# Epoch:25/100(350) loss:4.785079479217529
# Epoch:28/100(400) loss:4.795604228973389
# Epoch:32/100(450) loss:4.779965877532959
# Epoch:35/100(500) loss:4.792981147766113
# Epoch:39/100(550) loss:4.7676310539245605
# Epoch:42/100(600) loss:4.762003421783447
# Epoch:46/100(650) loss:4.804512977600098
# Epoch:50/100(700) loss:4.774724960327148
# Epoch:53/100(750) loss:4.734162330627441
# Epoch:57/100(800) loss:4.729537487030029
# Epoch:60/100(850) loss:4.754367351531982
# Epoch:64/100(900) loss:4.797341346740723
# Epoch:67/100(950) loss:4.727936267852783
# Epoch:71/100(1000) loss:4.688358783721924
# Epoch:75/100(1050) loss:4.735644817352295
# Epoch:78/100(1100) loss:4.750236511230469
# Epoch:82/100(1150) loss:4.744969844818115
# Epoch:85/100(1200) loss:4.698366641998291
# Epoch:89/100(1250) loss:4.698794364929199
# Epoch:92/100(1300) loss:4.736275672912598
# Epoch:96/100(1350) loss:4.739922046661377
# =================  Clustering 1/2  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  56 tasks      | elapsed:    4.9s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    9.5s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=4)]: Done 2680 tasks      | elapsed:    8.7s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    9.0s finished
#   -----  Load Model from record/Office31/CUDA4/wa_encoder__7 for clustering  -----
# nmi:0.5435920638650907
# nmi class:0.18048921905244522
# domain_accuracy:0.8889811738648948
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 200 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    4.5s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=4)]: Done 2680 tasks      | elapsed:    8.7s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    9.0s finished
#   -----  Load Model from record/Office31/CUDA4/wa_encoder__7 for clustering  -----
# nmi:0.5670539497878039
# nmi class:0.17946545361853775
# domain_accuracy:0.8992248062015504
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 200 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    4.7s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=4)]: Done 2680 tasks      | elapsed:    8.8s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    9.2s finished
#   -----  Load Model from record/Office31/CUDA4/wa_encoder__7 for clustering  -----
# nmi:0.5670539497878039
# nmi class:0.17807630300293878
# domain_accuracy:0.8992248062015504
# ===============================================
# ==============  webcam_amazon  ==============
# ===============================================
# Please install apex for mixed precision training from: https://github.com/NVIDIA/apex
#     ---------------------------------------------------------
#         cuda_dir: 4
#         batch_size: 256,  epochs: 100
#         SSL: simclr,  base_model: encoder
#         jigsaw: True,  fourier: True,  grid: 3
#         num_laps: 2,
#         log_dir: record/Office31/CUDA4/wa_encoder__8
#     ---------------------------------------------------------
#
#
# =================  1/2周目  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    4.2s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    8.1s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=4)]: Done 2680 tasks      | elapsed:    8.2s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    8.6s finished
# Running on: cuda
# Epoch:0/100(0) loss:5.4037275314331055
# Epoch:3/100(50) loss:4.951521396636963
# Epoch:7/100(100) loss:4.905012607574463
# Epoch:10/100(150) loss:4.855961799621582
# Epoch:14/100(200) loss:4.815943241119385
# Epoch:17/100(250) loss:4.826286315917969
# Epoch:21/100(300) loss:4.768466949462891
# Epoch:25/100(350) loss:4.791408538818359
# Epoch:28/100(400) loss:4.806247234344482
# Epoch:32/100(450) loss:4.799336910247803
# Epoch:35/100(500) loss:4.768211364746094
# Epoch:39/100(550) loss:4.766113758087158
# Epoch:42/100(600) loss:4.7221150398254395
# Epoch:46/100(650) loss:4.754147052764893
# Epoch:50/100(700) loss:4.743556022644043
# Epoch:53/100(750) loss:4.727952003479004
# Epoch:57/100(800) loss:4.712400913238525
# Epoch:60/100(850) loss:4.7504072189331055
# Epoch:64/100(900) loss:4.76484489440918
# Epoch:67/100(950) loss:4.716275215148926
# Epoch:71/100(1000) loss:4.727329254150391
# Epoch:75/100(1050) loss:4.7492241859436035
# Epoch:78/100(1100) loss:4.7314019203186035
# Epoch:82/100(1150) loss:4.737802982330322
# Epoch:85/100(1200) loss:4.7124247550964355
# Epoch:89/100(1250) loss:4.736704349517822
# Epoch:92/100(1300) loss:4.701454162597656
# Epoch:96/100(1350) loss:4.713322162628174
# =================  Clustering 1/2  =================
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  68 tasks      | elapsed:    5.2s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    9.4s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=4)]: Done 2680 tasks      | elapsed:    8.5s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    8.9s finished
#   -----  Load Model from record/Office31/CUDA4/wa_encoder__8 for clustering  -----
# nmi:0.17553133610621888
# nmi class:0.19416651883561728
# domain_accuracy:0.6990586932447398
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 200 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    4.2s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=4)]: Done 2680 tasks      | elapsed:    8.0s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    8.4s finished
#   -----  Load Model from record/Office31/CUDA4/wa_encoder__8 for clustering  -----
# nmi:0.21047826703442724
# nmi class:0.19110792488472
# domain_accuracy:0.6223698781838317
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 216 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=4)]: Done 795 out of 795 | elapsed:    3.9s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=4)]: Done 2680 tasks      | elapsed:    8.3s
# [Parallel(n_jobs=4)]: Done 2817 out of 2817 | elapsed:    8.7s finished
#   -----  Load Model from record/Office31/CUDA4/wa_encoder__8 for clustering  -----
# nmi:0.17442323180461683
# nmi class:0.19340070103259274
# domain_accuracy:0.6060354374307863
# CPU times: user 28 s, sys: 2.77 s, total: 30.8 s
# Wall time: 1h 13min 59s

# %%
# import os
# os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID" 
# os.environ["CUDA_VISIBLE_DEVICES"] = str(N_CUDA)

# from clustering import run_clustering
# from dataset import get_datasets
# from simclr import SimCLR
# from log_functions import *
# config.config_path = CONFIG_FILE
# config.log_dir = log_dir
# config.num_laps = 2
# config.spread_message = ""
# config.cuda_dir = CUDA_DIR
# config.lap = 1
# config.pseudo_out_dim = 8

# dataset = get_datasets(config, 'train')
# simclr = SimCLR(dataset, config)
# simclr.train()
# run_clustering(config)
